# %% [markdown]
# <a href="https://colab.research.google.com/github/yakkunn7422/public_colab/blob/main/2024_AIC2_thema1_main3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Googleドライブのマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -fr /content/sample_data/new_train_images
# !rm -fr /content/sample_data/test_images.zip
# !rm -fr /content/sample_data/train_images.zip
# !rm -fr /content/sample_data/train_master.tsv
# !rm -fr /content/sample_data/sample_submit.tsv
# !rm -fr /content/sample_data/resnet18-5c106cde.pth
# !rm -fr /content/sample_data/label_master.tsv

# %%
import os
print("カレントワーキングディレクトリは[" + os.getcwd() + "]です")
# Out:
# カレントワーキングディレクトリは[/content]です

# %%
# sample_data 配下にResnet18使う際のデータ一式を持ってくるコード

import os
import pandas as pd
import zipfile
import shutil
import numpy as np

#パラメータ
TRAIN_RATIO = 0.8



#trainイメージファイル、testイメージファイル等のファイル格納先
input_dir = '/content/drive/MyDrive/2024_AIContest2/Thema1'
work_dir =  '/content/sample_data'

#trainデータの解凍・成形先のディレクトリ
output_dir = os.path.join(work_dir, 'new_train_images')

#trainデータファイル名
zip_file_path = os.path.join(work_dir, 'train_images.zip')
#trainデータのラベルまとめファイル名
tsv_file_path = os.path.join(work_dir, 'train_master.tsv')

# ファイルをCOPYする
def simple_copy_files(src_dir, dst_dir):
    os.makedirs(dst_dir, exist_ok=True)  # コピー先ディレクトリを作成（既に存在する場合は何もしない）

    for file_name in os.listdir(src_dir):
        full_file_name = os.path.join(src_dir, file_name)
        if os.path.isfile(full_file_name):
            shutil.copy2(full_file_name, dst_dir)  # ファイルのコピー

# トレインとバリデーション用のディレクトリおよびその中のラベルごとのサブディレクトリを作成する
def create_directories(base_dir, labels):

    train_dir = os.path.join(base_dir, 'train')
    val_dir = os.path.join(base_dir, 'val')

    for dir_path in [train_dir, val_dir]:
        if not os.path.exists(dir_path):
            os.makedirs(dir_path)

    for label in labels:
        os.makedirs(os.path.join(train_dir, str(label)), exist_ok=True)
        os.makedirs(os.path.join(val_dir, str(label)), exist_ok=True)

    return train_dir, val_dir

# ZIPファイルを解凍する
def extract_zip(zip_file_path, extract_to):

    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)

# TSVファイルを読み込み、1行目を削除してデータフレームを準備する
def load_and_prepare_data(tsv_file_path):

    df = pd.read_csv(tsv_file_path, sep='\t', names=['filename', 'label_id'])
    df = df.iloc[1:].reset_index(drop=True)

    return df

# 画像ファイルをディレクトリに分配する
def distribute_images(df, image_dir, train_dir, val_dir, train_ratio=0.8):

    for label in df['label_id'].unique():
        label_images = df[df['label_id'] == label]['filename'].tolist()
        # シャッフルして分割

        np.random.shuffle(label_images)
        train_size = int(len(label_images) * train_ratio)
        train_images = label_images[:train_size]
        val_images = label_images[train_size:]

        for image_name in train_images:
            src_path = os.path.join(image_dir, image_name)
            dst_path = os.path.join(train_dir, str(label), image_name)
            shutil.copy(src_path, dst_path)

        for image_name in val_images:
            src_path = os.path.join(image_dir, image_name)
            dst_path = os.path.join(val_dir, str(label), image_name)
            shutil.copy(src_path, dst_path)

# ディレクトリ内のアイテムを探索し数を表示する
def count_files_recursive(directory):
    total_files = 0

    for root, dirs, files in os.walk(directory):
        files_count = len(files)
        subdir_relative = os.path.relpath(root, directory)
        print(f"Directory '{subdir_relative}' contains {files_count} files.")

        total_files += files_count

    print(f"Total files in '{directory}': {total_files}")

# メイン処理を実行する関数
def main(zip_file_path, tsv_file_path, output_dir, train_ratio=0.8):

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    df = load_and_prepare_data(tsv_file_path)

    extract_zip(zip_file_path, output_dir)

    labels = df['label_id'].unique()

    train_dir, val_dir = create_directories(output_dir, labels)
    image_dir = os.path.join(output_dir, 'train_images')

    distribute_images(df, image_dir, train_dir, val_dir, train_ratio)

    # 解凍後のディレクトリを削除
    if os.path.exists(image_dir):
        shutil.rmtree(image_dir)
        print(f"Deleted temporary directory: {image_dir}")

# 実行
# INPUTディレクトリのファイルをOUTPUTディレクトリにすべてCOPY
simple_copy_files(input_dir,work_dir)
# Train.zipファイル内の画像をtrain、val毎(割合い0.8)かつラベル毎のディレクトリに配置
main(zip_file_path, tsv_file_path, output_dir, train_ratio = TRAIN_RATIO)

count_files_recursive(output_dir)
# Out:
# Deleted temporary directory: /content/sample_data/new_train_images/train_images
# Directory '.' contains 0 files.
# Directory 'train' contains 0 files.
# Directory 'train/8' contains 400 files.
# Directory 'train/4' contains 400 files.
# Directory 'train/0' contains 400 files.
# Directory 'train/5' contains 400 files.
# Directory 'train/6' contains 400 files.
# Directory 'train/7' contains 400 files.
# Directory 'train/1' contains 400 files.
# Directory 'train/2' contains 400 files.
# Directory 'train/3' contains 400 files.
# Directory 'train/9' contains 400 files.
# Directory 'val' contains 0 files.
# Directory 'val/8' contains 100 files.
# Directory 'val/4' contains 100 files.
# Directory 'val/0' contains 100 files.
# Directory 'val/5' contains 100 files.
# Directory 'val/6' contains 100 files.
# Directory 'val/7' contains 100 files.
# Directory 'val/1' contains 100 files.
# Directory 'val/2' contains 100 files.
# Directory 'val/3' contains 100 files.
# Directory 'val/9' contains 100 files.
# Total files in '/content/sample_data/new_train_images': 5000

# %%
# Resnet18で学習
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import zipfile
import torch
import torch.nn as nn
import torch.optim as optim
import albumentations
from torch.utils.data import Dataset
from torchvision import datasets, models, transforms
from PIL import Image, ImageFilter

input_dir = '/content/drive/MyDrive/2024_AIContest2/Thema1'
work_dir =  '/content/sample_data'


#定数設定
DEVICE= "cuda"
TARGET_NUM = 10
BATCH_SIZE = 128
LEARNING_RATE = 0.005
EPOCH = 25
TRANSFER_LEARNING = False
MODEL_LEARNING = True

#transforms定義
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(256),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
}

#dataset作成
image_datasets = {
    'train': datasets.ImageFolder('/content/sample_data/new_train_images/train',data_transforms['train']),
    'val': datasets.ImageFolder('/content/sample_data/new_train_images/val',data_transforms['val'])
}

#dataloaders作成
image_dataloaders = {
    'train': torch.utils.data.DataLoader(image_datasets['train'], batch_size=BATCH_SIZE, shuffle=True, num_workers=0, drop_last=True),
    'val': torch.utils.data.DataLoader(image_datasets['val'], batch_size=BATCH_SIZE, shuffle=False, num_workers=0, drop_last=True),
}

#dataサイズ定義
dataset_sizes= {
    'train':len(image_datasets['train']),
    'val':len(image_datasets['val'])
}

if not MODEL_LEARNING:
    print("処理を停止します。")
    sys.exit()  # プログラムを終了

#ResNet18モデル定義
def get_model(target_num,isPretrained=False):

    if(isPretrained):
        model_ft = models.resnet18(pretrained=False)
        model_ft.load_state_dict(torch.load(os.path.join(work_dir, 'resnet18-5c106cde.pth'), map_location=lambda storage, loc: storage), strict=True)
    else:
        model_ft = models.resnet18(pretrained=False)

    model_ft.fc = nn.Linear(512, target_num)
    model_ft = model_ft.to(DEVICE)
    return model_ft

#モデルのインスタンス作成 転移学習なし（FALSE）
model_ft = get_model(target_num=TARGET_NUM,isPretrained=TRANSFER_LEARNING)

#最適化関数定義
optimizer = optim.SGD(model_ft.parameters(),lr=LEARNING_RATE, momentum=0.9)

#loss関数定義
criterion = nn.CrossEntropyLoss()

#モデル訓練用関数
def train_model(model, criterion, optimizer, num_epochs=5,is_saved = False):
    best_acc = 0.0


    train_arr1 = np.zeros(EPOCH)
    val_arr1   = np.zeros(EPOCH)

    # エポック数だけ下記工程の繰り返し
    for epoch in range(num_epochs):

        for phase in ['train', 'val']:
            print('{}:フェイズ'.format(phase))

            # 訓練フェイズと検証フェイズの切り替え
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            # dataloadersからバッチサイズだけデータ取り出し、下記工程（1−5）の繰り返し
            for i,(inputs, labels) in enumerate(image_dataloaders[phase]):
                inputs = inputs.to(DEVICE)
                labels = labels.to(DEVICE)

                # 1. optimizerの勾配初期化
                optimizer.zero_grad()

                # 2.モデルに入力データをinputし、outputを取り出す
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)

                # 3. outputと正解ラベルから、lossを算出
                loss = criterion(outputs, labels)
                print('   loaders:{}回目'.format(i+1)  ,'   loss:{}'.format(loss))

                if phase == 'train':
                    # 4. 誤差逆伝播法により勾配の算出
                    loss.backward()
                    # 5. optimizerのパラメータ更新
                    optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            print('EPOCH{}回目 {} Loss: {:.4f} Acc: {:.4f}'.format(epoch, phase, epoch_loss, epoch_acc))

            if phase == 'train':
                train_arr1[epoch]=epoch_acc
            else:
                val_arr1[epoch]=epoch_acc

            # C. 今までのエポックでの精度よりも高い場合はモデルの保存
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                if(is_saved):
                    print('Save File original_model_{}.pth'.format(epoch))
                    torch.save(model.state_dict(), '/content/drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_{}.pth'.format(epoch))


    print('Best val Acc: {:4f}'.format(best_acc))
    print(train_arr1)
    print(val_arr1)
    train_ser1 = pd.Series(train_arr1,name='train_acc')
    result_data = pd.DataFrame(train_ser1)
    result_data['val_acc']=val_arr1
    result_data.plot()
    plt.show()

train_model(model = model_ft,criterion = criterion,optimizer = optimizer,num_epochs=EPOCH,is_saved = True)
# Out:
# train:フェイズ
#    loaders:1回目    loss:2.335444927215576
#    loaders:2回目    loss:2.295555591583252
#    loaders:3回目    loss:2.35013484954834
#    loaders:4回目    loss:2.2921509742736816
#    loaders:5回目    loss:2.284841775894165
#    loaders:6回目    loss:2.292595624923706
#    loaders:7回目    loss:2.2567896842956543
#    loaders:8回目    loss:2.273574113845825
#    loaders:9回目    loss:2.225623846054077
#    loaders:10回目    loss:2.208064556121826
#    loaders:11回目    loss:2.1526405811309814
#    loaders:12回目    loss:2.149407148361206
#    loaders:13回目    loss:2.1316776275634766
#    loaders:14回目    loss:2.0571346282958984
#    loaders:15回目    loss:2.167074680328369
#    loaders:16回目    loss:2.034034252166748
#    loaders:17回目    loss:2.016758441925049
#    loaders:18回目    loss:1.9754977226257324
#    loaders:19回目    loss:1.9609496593475342
#    loaders:20回目    loss:1.9250402450561523
#    loaders:21回目    loss:1.9821984767913818
#    loaders:22回目    loss:1.9402722120285034
#    loaders:23回目    loss:1.817001461982727
#    loaders:24回目    loss:1.9114197492599487
#    loaders:25回目    loss:1.8844000101089478
#    loaders:26回目    loss:1.7440857887268066
#    loaders:27回目    loss:1.8953802585601807
#    loaders:28回目    loss:1.9009850025177002
#    loaders:29回目    loss:1.8660461902618408
#    loaders:30回目    loss:1.7249748706817627
#    loaders:31回目    loss:1.9106260538101196
# EPOCH0回目 train Loss: 2.0468 Acc: 0.2130
# val:フェイズ
#    loaders:15回目    loss:1.0237690210342407
#    loaders:16回目    loss:1.0621980428695679
#    loaders:17回目    loss:1.0009194612503052
#    loaders:18回目    loss:1.0131618976593018
#    loaders:19回目    loss:0.9773229360580444
#    loaders:20回目    loss:0.9578123688697815
#    loaders:21回目    loss:0.860554575920105
#    loaders:22回目    loss:1.1702438592910767
#    loaders:23回目    loss:0.9881999492645264
#    loaders:24回目    loss:0.9250359535217285
#    loaders:25回目    loss:1.118908405303955
#    loaders:26回目    loss:1.0080779790878296
#    loaders:27回目    loss:1.1076918840408325
#    loaders:28回目    loss:1.0207693576812744
#    loaders:29回目    loss:1.079033613204956
#    loaders:30回目    loss:1.0029444694519043
#    loaders:31回目    loss:1.1459132432937622
# EPOCH9回目 train Loss: 1.0232 Acc: 0.6125
# val:フェイズ
#    loaders:1回目    loss:0.7732018828392029
#    loaders:2回目    loss:0.6487820744514465
#    loaders:3回目    loss:1.2272826433181763
#    loaders:4回目    loss:1.9984652996063232
#    loaders:5回目    loss:1.9092810153961182
#    loaders:6回目    loss:1.6724488735198975
#    loaders:7回目    loss:2.064155340194702
# EPOCH9回目 val Loss: 1.3176 Acc: 0.4470
# Save File original_model_9.pth
# train:フェイズ
#    loaders:1回目    loss:0.8688651919364929
#    loaders:2回目    loss:0.9913291335105896
#    loaders:3回目    loss:0.9494680166244507
#    loaders:4回目    loss:0.9091047644615173
#    loaders:5回目    loss:1.0809084177017212
#    loaders:6回目    loss:0.9440581798553467
#    loaders:7回目    loss:1.0271483659744263
#    loaders:8回目    loss:0.9093185067176819
#    loaders:9回目    loss:1.0261784791946411
#    loaders:10回目    loss:0.9981196522712708
#    loaders:11回目    loss:0.9850900173187256
#    loaders:12回目    loss:0.9618755578994751
#    loaders:13回目    loss:1.0717613697052002
#    loaders:14回目    loss:0.9365277290344238
#    loaders:15回目    loss:1.0392684936523438
#    loaders:16回目    loss:0.9247647523880005
#    loaders:17回目    loss:0.9306569695472717
#    loaders:18回目    loss:1.1176172494888306
#    loaders:19回目    loss:1.0328586101531982
#    loaders:20回目    loss:0.9975669980049133
#    loaders:21回目    loss:1.014281153678894
#    loaders:22回目    loss:0.9616382122039795
#    loaders:23回目    loss:1.011353611946106
#    loaders:24回目    loss:0.9684000015258789
#    loaders:25回目    loss:0.992720365524292
#    loaders:26回目    loss:0.9618406295776367
#    loaders:27回目    loss:0.8143889904022217
#    loaders:28回目    loss:0.9502143859863281
#    loaders:29回目    loss:1.0562442541122437
#    loaders:30回目    loss:0.9506700038909912
#    loaders:31回目    loss:1.0209804773330688
# EPOCH10回目 train Loss: 0.9730 Acc: 0.6385
# val:フェイズ
#    loaders:1回目    loss:0.964969277381897
#    loaders:2回目    loss:0.947735607624054
#    loaders:3回目    loss:1.6376941204071045
#    loaders:4回目    loss:1.5600308179855347
#    loaders:5回目    loss:1.424357533454895
#    loaders:6回目    loss:1.185633897781372
#    loaders:7回目    loss:1.3364266157150269
# EPOCH10回目 val Loss: 1.1593 Acc: 0.4770
# Save File original_model_10.pth
# train:フェイズ
#    loaders:1回目    loss:0.7802003026008606
#    loaders:2回目    loss:0.8394867777824402
#    loaders:3回目    loss:0.9348703622817993
#    loaders:4回目    loss:1.0092687606811523
#    loaders:5回目    loss:0.8644841909408569
#    loaders:6回目    loss:0.9161405563354492
#    loaders:7回目    loss:0.9700404405593872
#    loaders:8回目    loss:0.8649643063545227
#    loaders:9回目    loss:0.8964529633522034
#    loaders:10回目    loss:0.9447449445724487
#    loaders:11回目    loss:0.9145686626434326
#    loaders:12回目    loss:0.7865220904350281
#    loaders:13回目    loss:0.9169384837150574
#    loaders:14回目    loss:0.8845364451408386
#    loaders:15回目    loss:0.8790106177330017
#    loaders:16回目    loss:0.9068416953086853
#    loaders:17回目    loss:0.9105647206306458
#    loaders:18回目    loss:0.8074721097946167
#    loaders:19回目    loss:0.908437192440033
#    loaders:20回目    loss:0.8472392559051514
#    loaders:21回目    loss:0.817818284034729
#    loaders:22回目    loss:0.9264401197433472
#    loaders:23回目    loss:1.0150164365768433
#    loaders:24回目    loss:0.8155320286750793
#    loaders:25回目    loss:0.9489892721176147
#    loaders:26回目    loss:0.7683957815170288
#    loaders:27回目    loss:0.9370629191398621
#    loaders:28回目    loss:1.0565305948257446
#    loaders:29回目    loss:0.7463363409042358
#    loaders:30回目    loss:0.8532362580299377
#    loaders:31回目    loss:0.8265857696533203
# EPOCH11回目 train Loss: 0.8798 Acc: 0.6723
# val:フェイズ
#    loaders:1回目    loss:0.8953478336334229
#    loaders:2回目    loss:0.9666688442230225
#    loaders:3回目    loss:1.5644207000732422
#    loaders:4回目    loss:1.9318758249282837
#    loaders:5回目    loss:1.6670461893081665
#    loaders:6回目    loss:1.3146384954452515
#    loaders:7回目    loss:2.2683441638946533
# EPOCH11回目 val Loss: 1.3579 Acc: 0.4580
# train:フェイズ
#    loaders:1回目    loss:0.7322766780853271
#    loaders:2回目    loss:0.7937034368515015
#    loaders:3回目    loss:0.9518346786499023
#    loaders:4回目    loss:0.9610580801963806
#    loaders:5回目    loss:0.9203711748123169
#    loaders:6回目    loss:0.8203251957893372
#    loaders:7回目    loss:0.8387630581855774
#    loaders:8回目    loss:0.8878532648086548
#    loaders:9回目    loss:0.6920655965805054
#    loaders:10回目    loss:0.8295486569404602
#    loaders:11回目    loss:0.8100001811981201
#    loaders:12回目    loss:0.8564979434013367
#    loaders:13回目    loss:0.7961957454681396
#    loaders:14回目    loss:0.786566436290741
#    loaders:15回目    loss:0.8336487412452698
#    loaders:16回目    loss:0.817624032497406
#    loaders:17回目    loss:0.8802934885025024
#    loaders:18回目    loss:0.9177044034004211
#    loaders:19回目    loss:0.7988364100456238
#    loaders:20回目    loss:0.897760808467865
#    loaders:21回目    loss:0.7957899570465088
#    loaders:22回目    loss:0.8479318022727966
#    loaders:23回目    loss:0.7609026432037354
#    loaders:24回目    loss:0.7794486284255981
#    loaders:25回目    loss:0.80926114320755
#    loaders:26回目    loss:0.9632883667945862
#    loaders:27回目    loss:0.8476287722587585
#    loaders:28回目    loss:1.1084952354431152
#    loaders:29回目    loss:0.795684814453125
#    loaders:30回目    loss:0.8257231712341309
#    loaders:31回目    loss:1.008157730102539
# EPOCH12回目 train Loss: 0.8437 Acc: 0.6877
# val:フェイズ
#    loaders:1回目    loss:1.0744504928588867
#    loaders:2回目    loss:1.5989246368408203
#    loaders:3回目    loss:2.1681151390075684
#    loaders:4回目    loss:1.7905421257019043
#    loaders:5回目    loss:1.4488004446029663
#    loaders:6回目    loss:0.932172417640686
#    loaders:7回目    loss:2.8574535846710205
# EPOCH12回目 val Loss: 1.5194 Acc: 0.3780
# train:フェイズ
#    loaders:1回目    loss:0.6445520520210266
#    loaders:2回目    loss:0.7824383974075317
#    loaders:3回目    loss:0.7564007639884949
#    loaders:4回目    loss:0.8469220995903015
#    loaders:5回目    loss:0.6773229241371155
#    loaders:6回目    loss:0.7786679863929749
#    loaders:7回目    loss:0.7237280607223511
#    loaders:8回目    loss:0.7634401917457581
#    loaders:9回目    loss:0.8334207534790039
#    loaders:10回目    loss:0.7654743790626526
#    loaders:11回目    loss:0.8006938099861145
#    loaders:12回目    loss:0.7476221323013306
#    loaders:13回目    loss:0.7302525043487549
#    loaders:14回目    loss:0.7147294878959656
#    loaders:15回目    loss:0.8391565084457397
#    loaders:16回目    loss:0.736475944519043
#    loaders:17回目    loss:0.7098760604858398
#    loaders:18回目    loss:0.9522191882133484
#    loaders:19回目    loss:0.7152028679847717
#    loaders:20回目    loss:0.8022503852844238
#    loaders:21回目    loss:0.844103991985321
#    loaders:22回目    loss:0.7778071761131287
#    loaders:23回目    loss:0.5865609049797058
#    loaders:24回目    loss:0.770753026008606
#    loaders:25回目    loss:0.8197729587554932
#    loaders:26回目    loss:0.7450370192527771
#    loaders:27回目    loss:0.8078676462173462
#    loaders:28回目    loss:0.8265162706375122
#    loaders:29回目    loss:0.9269887804985046
#    loaders:30回目    loss:0.8136786222457886
#    loaders:31回目    loss:0.7948147058486938
# EPOCH13回目 train Loss: 0.7691 Acc: 0.7183
# val:フェイズ
#    loaders:1回目    loss:0.9952709674835205
#    loaders:2回目    loss:0.9224370121955872
#    loaders:3回目    loss:1.2408733367919922
#    loaders:4回目    loss:1.5744295120239258
#    loaders:5回目    loss:1.5821559429168701
#    loaders:6回目    loss:1.3921149969100952
#    loaders:7回目    loss:1.5029144287109375
# EPOCH13回目 val Loss: 1.1789 Acc: 0.4890
# Save File original_model_13.pth
# train:フェイズ
#    loaders:1回目    loss:0.6397668719291687
#    loaders:2回目    loss:0.7599757313728333
#    loaders:3回目    loss:0.7077749967575073
#    loaders:4回目    loss:0.7163321375846863
#    loaders:5回目    loss:0.7719385623931885
#    loaders:6回目    loss:0.7591585516929626
#    loaders:7回目    loss:0.7158695459365845
#    loaders:8回目    loss:0.7203454971313477
#    loaders:9回目    loss:0.7065219283103943
#    loaders:10回目    loss:0.6322152018547058
#    loaders:11回目    loss:0.7230249047279358
#    loaders:12回目    loss:0.7444298267364502
#    loaders:13回目    loss:0.7541149854660034
#    loaders:14回目    loss:0.658389151096344
#    loaders:15回目    loss:0.6324564218521118
#    loaders:16回目    loss:0.776032567024231
#    loaders:17回目    loss:0.7204204201698303
#    loaders:18回目    loss:0.6982329487800598
#    loaders:19回目    loss:0.5840843319892883
#    loaders:20回目    loss:0.7379021048545837
#    loaders:21回目    loss:0.7570124268531799
#    loaders:22回目    loss:0.7464203238487244
#    loaders:23回目    loss:0.733375072479248
#    loaders:24回目    loss:0.8103987574577332
#    loaders:25回目    loss:0.6096246838569641
#    loaders:26回目    loss:0.7712371945381165
#    loaders:27回目    loss:0.7390192747116089
#    loaders:28回目    loss:0.5760725736618042
#    loaders:29回目    loss:0.7497296929359436
#    loaders:30回目    loss:0.7075331211090088
#    loaders:31回目    loss:0.709927499294281
# EPOCH14回目 train Loss: 0.7062 Acc: 0.7428
# val:フェイズ
#    loaders:1回目    loss:0.681799590587616
#    loaders:2回目    loss:1.3251203298568726
#    loaders:3回目    loss:1.6999154090881348
#    loaders:4回目    loss:1.1266282796859741
#    loaders:5回目    loss:1.8727768659591675
#    loaders:6回目    loss:1.36896812915802
#    loaders:7回目    loss:2.2010130882263184
# EPOCH14回目 val Loss: 1.3154 Acc: 0.4340
# train:フェイズ
#    loaders:1回目    loss:0.6581971049308777
#    loaders:2回目    loss:0.6034383773803711
#    loaders:3回目    loss:0.6517794728279114
#    loaders:4回目    loss:0.6316604614257812
#    loaders:5回目    loss:0.5370668768882751
#    loaders:6回目    loss:0.5349751114845276
#    loaders:7回目    loss:0.6518135070800781
#    loaders:8回目    loss:0.6259028911590576
#    loaders:9回目    loss:0.5201703310012817
#    loaders:10回目    loss:0.6136425733566284
#    loaders:11回目    loss:0.5457351207733154
#    loaders:12回目    loss:0.6610523462295532
#    loaders:13回目    loss:0.661431610584259
#    loaders:14回目    loss:0.5794037580490112
#    loaders:15回目    loss:0.5628457069396973
#    loaders:16回目    loss:0.7418310046195984
#    loaders:17回目    loss:0.6311622262001038
#    loaders:18回目    loss:0.6160518527030945
#    loaders:19回目    loss:0.5257432460784912
#    loaders:20回目    loss:0.5378263592720032
#    loaders:21回目    loss:0.4494335353374481
#    loaders:22回目    loss:0.709610104560852
#    loaders:23回目    loss:0.6364812254905701
#    loaders:24回目    loss:0.6009513735771179
#    loaders:25回目    loss:0.6281610131263733
#    loaders:26回目    loss:0.65760338306427
#    loaders:27回目    loss:0.8192211389541626
#    loaders:28回目    loss:0.6240876913070679
#    loaders:29回目    loss:0.5302874445915222
#    loaders:30回目    loss:0.8701962828636169
#    loaders:31回目    loss:0.7244566679000854
# EPOCH15回目 train Loss: 0.6190 Acc: 0.7818
# val:フェイズ
#    loaders:1回目    loss:0.6371087431907654
#    loaders:2回目    loss:0.8647555708885193
#    loaders:3回目    loss:1.9632707834243774
#    loaders:4回目    loss:1.6806758642196655
#    loaders:5回目    loss:1.4904861450195312
#    loaders:6回目    loss:1.1592106819152832
#    loaders:7回目    loss:2.1233553886413574
# EPOCH15回目 val Loss: 1.2696 Acc: 0.4760
# train:フェイズ
#    loaders:1回目    loss:0.5994213819503784
#    loaders:2回目    loss:0.5765775442123413
#    loaders:3回目    loss:0.4812370538711548
#    loaders:4回目    loss:0.5836299061775208
#    loaders:5回目    loss:0.6028430461883545
#    loaders:6回目    loss:0.6561566591262817
#    loaders:7回目    loss:0.5001265406608582
#    loaders:8回目    loss:0.5654968023300171
#    loaders:9回目    loss:0.49522000551223755
#    loaders:10回目    loss:0.5716236233711243
#    loaders:11回目    loss:0.6057177186012268
#    loaders:12回目    loss:0.5480570793151855
#    loaders:13回目    loss:0.547250509262085
#    loaders:14回目    loss:0.5489347577095032
#    loaders:15回目    loss:0.5190646648406982
#    loaders:16回目    loss:0.6371979117393494
#    loaders:17回目    loss:0.6376550197601318
#    loaders:18回目    loss:0.5011532306671143
#    loaders:19回目    loss:0.5362768769264221
#    loaders:20回目    loss:0.5027066469192505
#    loaders:21回目    loss:0.47335755825042725
#    loaders:22回目    loss:0.5427016615867615
#    loaders:23回目    loss:0.5360540747642517
#    loaders:24回目    loss:0.6331575512886047
#    loaders:25回目    loss:0.6207361221313477
#    loaders:26回目    loss:0.6780042052268982
#    loaders:27回目    loss:0.6715331077575684
#    loaders:28回目    loss:0.5458118915557861
#    loaders:29回目    loss:0.6627401113510132
#    loaders:30回目    loss:0.5163736343383789
#    loaders:31回目    loss:0.4940440356731415
# EPOCH16回目 train Loss: 0.5629 Acc: 0.7968
# val:フェイズ
#    loaders:1回目    loss:1.2093204259872437
#    loaders:2回目    loss:1.3323252201080322
#    loaders:3回目    loss:1.3865770101547241
#    loaders:4回目    loss:1.5112040042877197
#    loaders:5回目    loss:1.6995079517364502
#    loaders:6回目    loss:1.7356882095336914
#    loaders:7回目    loss:1.0846271514892578
# EPOCH16回目 val Loss: 1.2748 Acc: 0.4670
# train:フェイズ
#    loaders:1回目    loss:0.3987177908420563
#    loaders:2回目    loss:0.4276770055294037
#    loaders:3回目    loss:0.42641299962997437
#    loaders:4回目    loss:0.5269628167152405
#    loaders:5回目    loss:0.5094367861747742
#    loaders:6回目    loss:0.5445652008056641
#    loaders:7回目    loss:0.4292340576648712
#    loaders:8回目    loss:0.6231604814529419
#    loaders:9回目    loss:0.5027613043785095
#    loaders:10回目    loss:0.5061712861061096
#    loaders:11回目    loss:0.46071356534957886
#    loaders:12回目    loss:0.45534080266952515
#    loaders:13回目    loss:0.47281211614608765
#    loaders:14回目    loss:0.5667738914489746
#    loaders:15回目    loss:0.4798845946788788
#    loaders:16回目    loss:0.652611255645752
#    loaders:17回目    loss:0.4703250229358673
#    loaders:18回目    loss:0.48755353689193726
#    loaders:19回目    loss:0.6357640624046326
#    loaders:20回目    loss:0.4797002673149109
#    loaders:21回目    loss:0.5260457992553711
#    loaders:22回目    loss:0.5113442540168762
#    loaders:23回目    loss:0.3376878798007965
#    loaders:24回目    loss:0.48840633034706116
#    loaders:25回目    loss:0.4754945635795593
#    loaders:26回目    loss:0.5047382712364197
#    loaders:27回目    loss:0.5963631272315979
#    loaders:28回目    loss:0.6498897075653076
#    loaders:29回目    loss:0.5834228992462158
#    loaders:30回目    loss:0.5872211456298828
#    loaders:31回目    loss:0.5450419783592224
# EPOCH17回目 train Loss: 0.5076 Acc: 0.8220
# val:フェイズ
#    loaders:1回目    loss:0.6643220782279968
#    loaders:2回目    loss:0.9444401264190674
#    loaders:3回目    loss:1.783642053604126
#    loaders:4回目    loss:1.5193766355514526
#    loaders:5回目    loss:2.7876946926116943
#    loaders:6回目    loss:2.364323616027832
#    loaders:7回目    loss:1.2379868030548096
# EPOCH17回目 val Loss: 1.4466 Acc: 0.4560
# train:フェイズ
#    loaders:1回目    loss:0.45313990116119385
#    loaders:2回目    loss:0.4026479423046112
#    loaders:3回目    loss:0.5300506353378296
#    loaders:4回目    loss:0.39871641993522644
#    loaders:5回目    loss:0.525362491607666
#    loaders:6回目    loss:0.44602030515670776
#    loaders:7回目    loss:0.6082165837287903
#    loaders:8回目    loss:0.4281701445579529
#    loaders:9回目    loss:0.5253918766975403
#    loaders:10回目    loss:0.6031500101089478
#    loaders:11回目    loss:0.4049326181411743
#    loaders:12回目    loss:0.4537326991558075
#    loaders:13回目    loss:0.4782828390598297
#    loaders:14回目    loss:0.4985373616218567
#    loaders:15回目    loss:0.4106760323047638
#    loaders:16回目    loss:0.4071391224861145
#    loaders:17回目    loss:0.4826900064945221
#    loaders:18回目    loss:0.5107913017272949
#    loaders:19回目    loss:0.5432868003845215
#    loaders:20回目    loss:0.474702388048172
#    loaders:21回目    loss:0.3699285686016083
#    loaders:22回目    loss:0.4019085764884949
#    loaders:23回目    loss:0.3497009873390198
#    loaders:24回目    loss:0.494575560092926
#    loaders:25回目    loss:0.44275110960006714
#    loaders:26回目    loss:0.4540485739707947
#    loaders:27回目    loss:0.44619128108024597
#    loaders:28回目    loss:0.45108383893966675
#    loaders:29回目    loss:0.48274165391921997
#    loaders:30回目    loss:0.48416200280189514
#    loaders:31回目    loss:0.37983429431915283
# EPOCH18回目 train Loss: 0.4590 Acc: 0.8413
# val:フェイズ
#    loaders:1回目    loss:0.8404079079627991
#    loaders:2回目    loss:0.9572416543960571
#    loaders:3回目    loss:1.2581919431686401
#    loaders:4回目    loss:1.812614917755127
#    loaders:5回目    loss:1.494378685951233
#    loaders:6回目    loss:1.922684669494629
#    loaders:7回目    loss:1.9213794469833374
# EPOCH18回目 val Loss: 1.3065 Acc: 0.4680
# train:フェイズ
#    loaders:1回目    loss:0.4095816910266876
#    loaders:2回目    loss:0.33433470129966736
#    loaders:3回目    loss:0.3615269958972931
#    loaders:4回目    loss:0.3422199487686157
#    loaders:5回目    loss:0.5325897932052612
#    loaders:6回目    loss:0.3771796226501465
#    loaders:7回目    loss:0.37752652168273926
#    loaders:8回目    loss:0.3708733320236206
#    loaders:9回目    loss:0.42543643712997437
#    loaders:10回目    loss:0.32593443989753723
#    loaders:11回目    loss:0.30682551860809326
#    loaders:12回目    loss:0.3603232204914093
#    loaders:13回目    loss:0.6987637877464294
#    loaders:14回目    loss:0.4118439555168152
#    loaders:15回目    loss:0.3655652701854706
#    loaders:16回目    loss:0.4291810691356659
#    loaders:17回目    loss:0.41802483797073364
#    loaders:18回目    loss:0.5441741943359375
#    loaders:19回目    loss:0.4102516770362854
#    loaders:20回目    loss:0.37525472044944763
#    loaders:21回目    loss:0.3775639533996582
#    loaders:22回目    loss:0.4771183133125305
#    loaders:23回目    loss:0.363537460565567
#    loaders:24回目    loss:0.4499821662902832
#    loaders:25回目    loss:0.4881528317928314
#    loaders:26回目    loss:0.4634454846382141
#    loaders:27回目    loss:0.35994771122932434
#    loaders:28回目    loss:0.4144439995288849
#    loaders:29回目    loss:0.5071948170661926
#    loaders:30回目    loss:0.44832146167755127
#    loaders:31回目    loss:0.4143052101135254
# EPOCH19回目 train Loss: 0.4141 Acc: 0.8525
# val:フェイズ
#    loaders:1回目    loss:1.0952656269073486
#    loaders:2回目    loss:1.6857341527938843
#    loaders:3回目    loss:2.5883662700653076
#    loaders:4回目    loss:1.865971326828003
#    loaders:5回目    loss:1.8331093788146973
#    loaders:6回目    loss:1.489315152168274
#    loaders:7回目    loss:2.402620792388916
# EPOCH19回目 val Loss: 1.6589 Acc: 0.4420
# train:フェイズ
#    loaders:1回目    loss:0.3835813105106354
#    loaders:2回目    loss:0.40736669301986694
#    loaders:3回目    loss:0.45074892044067383
#    loaders:4回目    loss:0.37846773862838745
#    loaders:5回目    loss:0.218775674700737
#    loaders:6回目    loss:0.2627880871295929
#    loaders:7回目    loss:0.30670690536499023
#    loaders:8回目    loss:0.2751111388206482
#    loaders:9回目    loss:0.5589728355407715
#    loaders:10回目    loss:0.41189542412757874
#    loaders:11回目    loss:0.33463090658187866
#    loaders:12回目    loss:0.39513328671455383
#    loaders:13回目    loss:0.3278758227825165
#    loaders:14回目    loss:0.46098601818084717
#    loaders:15回目    loss:0.36036109924316406
#    loaders:16回目    loss:0.3252093493938446
#    loaders:17回目    loss:0.44766131043434143
#    loaders:18回目    loss:0.39507052302360535
#    loaders:19回目    loss:0.27966782450675964
#    loaders:20回目    loss:0.40328654646873474
#    loaders:21回目    loss:0.4253603518009186
#    loaders:22回目    loss:0.3605547845363617
#    loaders:23回目    loss:0.23175837099552155
#    loaders:24回目    loss:0.4664376974105835
#    loaders:25回目    loss:0.377883642911911
#    loaders:26回目    loss:0.29741090536117554
#    loaders:27回目    loss:0.3964313566684723
#    loaders:28回目    loss:0.4016612768173218
#    loaders:29回目    loss:0.33602866530418396
#    loaders:30回目    loss:0.29062139987945557
#    loaders:31回目    loss:0.4247429668903351
# EPOCH20回目 train Loss: 0.3646 Acc: 0.8795
# val:フェイズ
#    loaders:1回目    loss:1.3246210813522339
#    loaders:2回目    loss:1.5274871587753296
#    loaders:3回目    loss:1.4733672142028809
#    loaders:4回目    loss:1.809622049331665
#    loaders:5回目    loss:1.7378801107406616
#    loaders:6回目    loss:1.5243037939071655
#    loaders:7回目    loss:1.0353801250457764
# EPOCH20回目 val Loss: 1.3354 Acc: 0.4780
# train:フェイズ
#    loaders:1回目    loss:0.2245875746011734
#    loaders:2回目    loss:0.21321122348308563
#    loaders:3回目    loss:0.23670101165771484
#    loaders:4回目    loss:0.24523338675498962
#    loaders:5回目    loss:0.385660320520401
#    loaders:6回目    loss:0.29127079248428345
#    loaders:7回目    loss:0.2419719398021698
#    loaders:8回目    loss:0.33883076906204224
#    loaders:9回目    loss:0.21892951428890228
#    loaders:10回目    loss:0.22552210092544556
#    loaders:11回目    loss:0.23574130237102509
#    loaders:12回目    loss:0.2985418140888214
#    loaders:13回目    loss:0.28361499309539795
#    loaders:14回目    loss:0.26180899143218994
#    loaders:15回目    loss:0.1903836578130722
#    loaders:16回目    loss:0.27498432993888855
#    loaders:17回目    loss:0.27005842328071594
#    loaders:18回目    loss:0.23148246109485626
#    loaders:19回目    loss:0.20537778735160828
#    loaders:20回目    loss:0.20946583151817322
#    loaders:21回目    loss:0.2195015400648117
#    loaders:22回目    loss:0.2371489405632019
#    loaders:23回目    loss:0.43768835067749023
#    loaders:24回目    loss:0.26426610350608826
#    loaders:25回目    loss:0.1993994116783142
#    loaders:26回目    loss:0.2524094581604004
#    loaders:27回目    loss:0.29938212037086487
#    loaders:28回目    loss:0.28072142601013184
#    loaders:29回目    loss:0.31660550832748413
#    loaders:30回目    loss:0.31400877237319946
#    loaders:31回目    loss:0.2745346128940582
# EPOCH21回目 train Loss: 0.2617 Acc: 0.9148
# val:フェイズ
#    loaders:1回目    loss:1.0590077638626099
#    loaders:2回目    loss:0.8420313000679016
#    loaders:3回目    loss:1.7531803846359253
#    loaders:4回目    loss:1.9904190301895142
#    loaders:5回目    loss:1.7671984434127808
#    loaders:6回目    loss:1.2926632165908813
#    loaders:7回目    loss:2.1939542293548584
# EPOCH21回目 val Loss: 1.3950 Acc: 0.5000
# Save File original_model_21.pth
# train:フェイズ
#    loaders:1回目    loss:0.19849468767642975
#    loaders:2回目    loss:0.20491890609264374
#    loaders:3回目    loss:0.1710973083972931
#    loaders:4回目    loss:0.22512565553188324
#    loaders:5回目    loss:0.18032874166965485
#    loaders:6回目    loss:0.241615891456604
#    loaders:7回目    loss:0.21389497816562653
#    loaders:8回目    loss:0.219943568110466
#    loaders:9回目    loss:0.18566572666168213
#    loaders:10回目    loss:0.2620336711406708
#    loaders:11回目    loss:0.21133214235305786
#    loaders:12回目    loss:0.23591066896915436
#    loaders:13回目    loss:0.23778246343135834
#    loaders:14回目    loss:0.17792758345603943
#    loaders:15回目    loss:0.1717071682214737
#    loaders:16回目    loss:0.20764616131782532
#    loaders:17回目    loss:0.2533814311027527
#    loaders:18回目    loss:0.28055885434150696
#    loaders:19回目    loss:0.2789643406867981
#    loaders:20回目    loss:0.20939606428146362
#    loaders:21回目    loss:0.18269938230514526
#    loaders:22回目    loss:0.17040278017520905
#    loaders:23回目    loss:0.17827679216861725
#    loaders:24回目    loss:0.3089666962623596
#    loaders:25回目    loss:0.188407301902771
#    loaders:26回目    loss:0.24311332404613495
#    loaders:27回目    loss:0.1820879727602005
#    loaders:28回目    loss:0.27172356843948364
#    loaders:29回目    loss:0.30782896280288696
#    loaders:30回目    loss:0.24393902719020844
#    loaders:31回目    loss:0.17838767170906067
# EPOCH22回目 train Loss: 0.2184 Acc: 0.9317
# val:フェイズ
#    loaders:1回目    loss:0.6893857717514038
#    loaders:2回目    loss:1.9228192567825317
#    loaders:3回目    loss:3.1989803314208984
#    loaders:4回目    loss:1.4293731451034546
#    loaders:5回目    loss:1.227516770362854
#    loaders:6回目    loss:2.3072707653045654
#    loaders:7回目    loss:1.7356685400009155
# EPOCH22回目 val Loss: 1.6014 Acc: 0.4510
# train:フェイズ
#    loaders:1回目    loss:0.12813162803649902
#    loaders:2回目    loss:0.15217526257038116
#    loaders:3回目    loss:0.22872930765151978
#    loaders:4回目    loss:0.17446893453598022
#    loaders:5回目    loss:0.1624106764793396
#    loaders:6回目    loss:0.15114934742450714
#    loaders:7回目    loss:0.21213677525520325
#    loaders:8回目    loss:0.14443229138851166
#    loaders:9回目    loss:0.12562498450279236
#    loaders:10回目    loss:0.166221022605896
#    loaders:11回目    loss:0.146903395652771
#    loaders:12回目    loss:0.20589810609817505
#    loaders:13回目    loss:0.12896645069122314
#    loaders:14回目    loss:0.15279656648635864
#    loaders:15回目    loss:0.1789090633392334
#    loaders:16回目    loss:0.19306664168834686
#    loaders:17回目    loss:0.15969012677669525
#    loaders:18回目    loss:0.15668068826198578
#    loaders:19回目    loss:0.14594607055187225
#    loaders:20回目    loss:0.1902686059474945
#    loaders:21回目    loss:0.20996129512786865
#    loaders:22回目    loss:0.11583078652620316
#    loaders:23回目    loss:0.14568635821342468
#    loaders:24回目    loss:0.17001058161258698
#    loaders:25回目    loss:0.2455257773399353
#    loaders:26回目    loss:0.1657482534646988
#    loaders:27回目    loss:0.14705397188663483
#    loaders:28回目    loss:0.21248719096183777
#    loaders:29回目    loss:0.1747845858335495
#    loaders:30回目    loss:0.15628443658351898
#    loaders:31回目    loss:0.1547388732433319
# EPOCH23回目 train Loss: 0.1665 Acc: 0.9513
# val:フェイズ
#    loaders:1回目    loss:1.1078351736068726
#    loaders:2回目    loss:1.1424578428268433
#    loaders:3回目    loss:1.3884892463684082
#    loaders:4回目    loss:2.101774215698242
#    loaders:5回目    loss:2.2515318393707275
#    loaders:6回目    loss:1.8538697957992554
#    loaders:7回目    loss:0.7785468101501465
# EPOCH23回目 val Loss: 1.3599 Acc: 0.5070
# Save File original_model_23.pth
# train:フェイズ
#    loaders:1回目    loss:0.1981460154056549
#    loaders:2回目    loss:0.1134410873055458
#    loaders:3回目    loss:0.1164303570985794
#    loaders:4回目    loss:0.10838388651609421
#    loaders:5回目    loss:0.1318470686674118
#    loaders:6回目    loss:0.13737492263317108
#    loaders:7回目    loss:0.12104665488004684
#    loaders:8回目    loss:0.11812568455934525
#    loaders:9回目    loss:0.12166496366262436
#    loaders:10回目    loss:0.10791406035423279
#    loaders:11回目    loss:0.14513525366783142
#    loaders:12回目    loss:0.1547958105802536
#    loaders:13回目    loss:0.14974795281887054
#    loaders:14回目    loss:0.1257391721010208
#    loaders:15回目    loss:0.1773669719696045
#    loaders:16回目    loss:0.16218456625938416
#    loaders:17回目    loss:0.11076989769935608
#    loaders:18回目    loss:0.17838019132614136
#    loaders:19回目    loss:0.09321367740631104
#    loaders:20回目    loss:0.13858115673065186
#    loaders:21回目    loss:0.17499200999736786
#    loaders:22回目    loss:0.12578845024108887
#    loaders:23回目    loss:0.14743804931640625
#    loaders:24回目    loss:0.1864704042673111
#    loaders:25回目    loss:0.19439353048801422
#    loaders:26回目    loss:0.1384473294019699
#    loaders:27回目    loss:0.14094887673854828
#    loaders:28回目    loss:0.17109739780426025
#    loaders:29回目    loss:0.25835758447647095
#    loaders:30回目    loss:0.1650395393371582
#    loaders:31回目    loss:0.13357879221439362
# EPOCH24回目 train Loss: 0.1455 Acc: 0.9520
# val:フェイズ
#    loaders:1回目    loss:1.3295258283615112
#    loaders:2回目    loss:1.4353888034820557
#    loaders:3回目    loss:2.7680182456970215
#    loaders:4回目    loss:2.3446075916290283
#    loaders:5回目    loss:2.183257579803467
#    loaders:6回目    loss:1.190116047859192
#    loaders:7回目    loss:1.5080662965774536
# EPOCH24回目 val Loss: 1.6331 Acc: 0.4830
# Best val Acc: 0.507000
# [0.213   0.32675 0.3765  0.4135  0.45725 0.4965  0.52675 0.564   0.601
#  0.6125  0.6385  0.67225 0.68775 0.71825 0.74275 0.78175 0.79675 0.822
#  0.84125 0.8525  0.8795  0.91475 0.93175 0.95125 0.952  ]
# [0.241 0.294 0.326 0.341 0.385 0.371 0.347 0.421 0.399 0.447 0.477 0.458
#  0.378 0.489 0.434 0.476 0.467 0.456 0.468 0.442 0.478 0.5   0.451 0.507
#  0.483]

# %%
#学習したモデルを使ってtestデータの推論を実施
import pandas as pd
import os
import zipfile
import torch
import torch.nn as nn
import torch.optim as optim
import albumentations
from torch.utils.data import Dataset
from torchvision import datasets, models, transforms
from PIL import Image, ImageFilter

work_dir           = '/content/sample_data'
save_dir           = '/content/drive/MyDrive/2024_AIContest2/Thema1/'
test_zip_file_path = '/content/sample_data/test_images.zip'
test_file_dir      = os.path.join(work_dir, 'test_images')
report_format_tsv  = os.path.join(work_dir, 'sample_submit.tsv')
best_model_path    = os.path.join(save_dir, 'pth/20250317_original_model_14.pth')
output_file        = os.path.join(save_dir, 'output/20250317_out_submit_14.tsv')

TARGET_NUM = 10

# ZIPファイルを解凍する
def extract_zip(zip_file_path, extract_to):

    if not os.path.exists(test_file_dir):
        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            zip_ref.extractall(extract_to)

extract_zip(test_zip_file_path, work_dir)

#dataサイズ定義
dataset_sizes= {
    'train':len(image_datasets['train']),
    'val':len(image_datasets['val'])
}

#submit用dataset定義
class For_Submission_Datasets(Dataset):

    def __init__(self, data_transform):
        self.df = pd.read_csv(report_format_tsv ,sep='\t',names=['filename','target'])
        self.data_transform = data_transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):
        file = self.df['filename'][index]
        image = Image.open(test_file_dir +'/'+ file)
        image = self.data_transform(image)

        return image,file

#submit用dataset作成
subdataset = For_Submission_Datasets(data_transform=data_transforms['val'])

#submit用dataloaders作成
subdataloader = torch.utils.data.DataLoader(subdataset, batch_size=1, shuffle=False, num_workers=0, drop_last=True)

#精度の最も高いモデルをロード
#モデルの名前を適宜変更して、最も精度の高いモデルをロードしましょう
best_model = get_model(target_num = TARGET_NUM)
best_model.load_state_dict(torch.load(best_model_path, map_location=lambda storage, loc: storage), strict=True)

submit = pd.read_csv(report_format_tsv,sep='\t', header=None)
#print(submit)
#テストデータに対しての推論
pred = []
for i,(inputs, labels) in enumerate(subdataloader):
    inputs = inputs.to(DEVICE)
    best_model.eval()
    outputs = best_model(inputs)
    _, preds = torch.max(outputs, 1)
    pred.append(preds.item())

df_test = pd.read_csv(report_format_tsv ,sep='\t',names=['filename','target'])

df_test['pred'] = pred
#print(df_test)
submit[1] = pred

submit.to_csv(output_file ,sep='\t', index=False, header=False)
print(submit)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#                   0  1
# 0        test_0.jpg  6
# 1        test_1.jpg  5
# 2        test_2.jpg  0
# 3        test_3.jpg  8
# 4        test_4.jpg  7
# ...             ... ..
# 7995  test_7995.jpg  2
# 7996  test_7996.jpg  6
# 7997  test_7997.jpg  8
# 7998  test_7998.jpg  8
# 7999  test_7999.jpg  8
#
# [8000 rows x 2 columns]

# %% [markdown]
# <a href="https://colab.research.google.com/github/yakkunn7422/public_colab/blob/main/2024_AIC2_thema1_main7_resnet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Googleドライブのマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -fr /content/sample_data/new_train_images
# !rm -fr /content/sample_data/test_images.zip
# !rm -fr /content/sample_data/train_images.zip
# !rm -fr /content/sample_data/train_master.tsv
# !rm -fr /content/sample_data/sample_submit.tsv
# !rm -fr /content/sample_data/resnet18-5c106cde.pth
# !rm -fr /content/sample_data/resnet50-19c8e357.pth
# !rm -fr /content/sample_data/label_master.tsv

# %%
import os
print("カレントワーキングディレクトリは[" + os.getcwd() + "]です")
# Out:
# カレントワーキングディレクトリは[/content]です

# %%
# sample_data 配下にResnet18使う際のデータ一式を持ってくるコード

import os
import pandas as pd
import zipfile
import shutil
import numpy as np

#パラメータ
TRAIN_RATIO = 0.8



#trainイメージファイル、testイメージファイル等のファイル格納先
input_dir = '/content/drive/MyDrive/2024_AIContest2/Thema1'
work_dir =  '/content/sample_data'

#trainデータの解凍・成形先のディレクトリ
output_dir = os.path.join(work_dir, 'new_train_images')

#trainデータファイル名
zip_file_path = os.path.join(work_dir, 'train_images.zip')
#trainデータのラベルまとめファイル名
tsv_file_path = os.path.join(work_dir, 'train_master.tsv')

# ファイルをCOPYする
def simple_copy_files(src_dir, dst_dir):
    os.makedirs(dst_dir, exist_ok=True)  # コピー先ディレクトリを作成（既に存在する場合は何もしない）

    for file_name in os.listdir(src_dir):
        full_file_name = os.path.join(src_dir, file_name)
        if os.path.isfile(full_file_name):
            shutil.copy2(full_file_name, dst_dir)  # ファイルのコピー

# トレインとバリデーション用のディレクトリおよびその中のラベルごとのサブディレクトリを作成する
def create_directories(base_dir, labels):

    train_dir = os.path.join(base_dir, 'train')
    val_dir = os.path.join(base_dir, 'val')

    for dir_path in [train_dir, val_dir]:
        if not os.path.exists(dir_path):
            os.makedirs(dir_path)

    for label in labels:
        os.makedirs(os.path.join(train_dir, str(label)), exist_ok=True)
        os.makedirs(os.path.join(val_dir, str(label)), exist_ok=True)

    return train_dir, val_dir

# ZIPファイルを解凍する
def extract_zip(zip_file_path, extract_to):

    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)

# TSVファイルを読み込み、1行目を削除してデータフレームを準備する
def load_and_prepare_data(tsv_file_path):

    df = pd.read_csv(tsv_file_path, sep='\t', names=['filename', 'label_id'])
    df = df.iloc[1:].reset_index(drop=True)

    return df

# 画像ファイルをディレクトリに分配する
def distribute_images(df, image_dir, train_dir, val_dir, train_ratio=0.8):

    for label in df['label_id'].unique():
        label_images = df[df['label_id'] == label]['filename'].tolist()
        # シャッフルして分割

        np.random.shuffle(label_images)
        train_size = int(len(label_images) * train_ratio)
        train_images = label_images[:train_size]
        val_images = label_images[train_size:]

        for image_name in train_images:
            src_path = os.path.join(image_dir, image_name)
            dst_path = os.path.join(train_dir, str(label), image_name)
            shutil.copy(src_path, dst_path)

        for image_name in val_images:
            src_path = os.path.join(image_dir, image_name)
            dst_path = os.path.join(val_dir, str(label), image_name)
            shutil.copy(src_path, dst_path)

# ディレクトリ内のアイテムを探索し数を表示する
def count_files_recursive(directory):
    total_files = 0

    for root, dirs, files in os.walk(directory):
        files_count = len(files)
        subdir_relative = os.path.relpath(root, directory)
        print(f"Directory '{subdir_relative}' contains {files_count} files.")

        total_files += files_count

    print(f"Total files in '{directory}': {total_files}")

# メイン処理を実行する関数
def main(zip_file_path, tsv_file_path, output_dir, train_ratio=0.8):

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    df = load_and_prepare_data(tsv_file_path)

    extract_zip(zip_file_path, output_dir)

    labels = df['label_id'].unique()

    train_dir, val_dir = create_directories(output_dir, labels)
    image_dir = os.path.join(output_dir, 'train_images')

    distribute_images(df, image_dir, train_dir, val_dir, train_ratio)

    # 解凍後のディレクトリを削除
    if os.path.exists(image_dir):
        shutil.rmtree(image_dir)
        print(f"Deleted temporary directory: {image_dir}")

# 実行
# INPUTディレクトリのファイルをOUTPUTディレクトリにすべてCOPY
simple_copy_files(input_dir,work_dir)
# Train.zipファイル内の画像をtrain、val毎(割合い0.8)かつラベル毎のディレクトリに配置
main(zip_file_path, tsv_file_path, output_dir, train_ratio = TRAIN_RATIO)

count_files_recursive(output_dir)
# Out:
# Deleted temporary directory: /content/sample_data/new_train_images/train_images
# Directory '.' contains 0 files.
# Directory 'train' contains 0 files.
# Directory 'train/6' contains 400 files.
# Directory 'train/7' contains 400 files.
# Directory 'train/2' contains 400 files.
# Directory 'train/3' contains 400 files.
# Directory 'train/9' contains 400 files.
# Directory 'train/0' contains 400 files.
# Directory 'train/5' contains 400 files.
# Directory 'train/8' contains 400 files.
# Directory 'train/4' contains 400 files.
# Directory 'train/1' contains 400 files.
# Directory 'val' contains 0 files.
# Directory 'val/6' contains 100 files.
# Directory 'val/7' contains 100 files.
# Directory 'val/2' contains 100 files.
# Directory 'val/3' contains 100 files.
# Directory 'val/9' contains 100 files.
# Directory 'val/0' contains 100 files.
# Directory 'val/5' contains 100 files.
# Directory 'val/8' contains 100 files.
# Directory 'val/4' contains 100 files.
# Directory 'val/1' contains 100 files.
# Total files in '/content/sample_data/new_train_images': 5000

# %%
# Resnet50で学習
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import zipfile
import torch
import torch.nn as nn
import torch.optim as optim
import albumentations
from torch.utils.data import Dataset, ConcatDataset
from torchvision import datasets, models, transforms
from PIL import Image, ImageFilter

input_dir = '/content/drive/MyDrive/2024_AIContest2/Thema1'
work_dir =  '/content/sample_data'


#定数設定
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
TARGET_NUM = 10
BATCH_SIZE = 64
LEARNING_RATE = 0.005
EPOCH = 25
TRANSFER_LEARNING = True
MODEL_LEARNING = True

#transforms定義
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(256),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.GaussianBlur(kernel_size=7),
        transforms.RandomRotation(degrees=(-15, 15)),
#        transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
}

#dataset作成(旧)
image_datasets = {
    'train': datasets.ImageFolder('/content/sample_data/new_train_images/train',data_transforms['train']),
    'val': datasets.ImageFolder('/content/sample_data/new_train_images/val',data_transforms['val'])
}

#dataloaders作成
image_dataloaders = {
    'train': torch.utils.data.DataLoader(image_datasets['train'], batch_size=BATCH_SIZE, shuffle=True, num_workers=0, drop_last=True),
    'val': torch.utils.data.DataLoader(image_datasets['val'], batch_size=BATCH_SIZE, shuffle=False, num_workers=0, drop_last=True),
}

#dataサイズ定義
dataset_sizes= {
    'train':len(image_datasets['train']),
    'val':len(image_datasets['val'])
}

#ResNet50モデル定義
def get_model(target_num,isPretrained=False):

    if(isPretrained):
        model_ft = models.resnet50(pretrained=False)
        model_ft.load_state_dict(torch.load(os.path.join(work_dir, '/content/sample_data/resnet50-19c8e357.pth'), map_location=lambda storage, loc: storage,weights_only=False), strict=True)
    else:
        model_ft = models.resnet50(pretrained=False)

    model_ft.fc = nn.Linear(2048, target_num)
    model_ft = model_ft.to(DEVICE)
    return model_ft

if not MODEL_LEARNING:
    print("処理を停止します。")
    sys.exit()  # プログラムを終了

#モデルのインスタンス作成 転移学習なし（FALSE）
model_ft = get_model(target_num=TARGET_NUM,isPretrained=TRANSFER_LEARNING)

#最適化関数定義
optimizer = optim.SGD(model_ft.parameters(),lr=LEARNING_RATE, momentum=0.9)

#loss関数定義
criterion = nn.CrossEntropyLoss()

#モデル訓練用関数
def train_model(model, criterion, optimizer, num_epochs=5,is_saved = False):
    best_acc = 0.0


    train_arr1 = np.zeros(EPOCH)
    val_arr1   = np.zeros(EPOCH)

    # エポック数だけ下記工程の繰り返し
    for epoch in range(num_epochs):

        for phase in ['train', 'val']:
            print('{}:フェイズ'.format(phase))

            # 訓練フェイズと検証フェイズの切り替え
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            # dataloadersからバッチサイズだけデータ取り出し、下記工程（1−5）の繰り返し
            for i,(inputs, labels) in enumerate(image_dataloaders[phase]):
                inputs = inputs.to(DEVICE)
                labels = labels.to(DEVICE)

                # 1. optimizerの勾配初期化
                optimizer.zero_grad()

                # 2.モデルに入力データをinputし、outputを取り出す
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)

                # 3. outputと正解ラベルから、lossを算出
                loss = criterion(outputs, labels)
                print('   loaders:{}回目'.format(i+1)  ,'   loss:{}'.format(loss))

                if phase == 'train':
                    # 4. 誤差逆伝播法により勾配の算出
                    loss.backward()
                    # 5. optimizerのパラメータ更新
                    optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            print('EPOCH{}回目 {} Loss: {:.4f} Acc: {:.4f}'.format(epoch, phase, epoch_loss, epoch_acc))

            if phase == 'train':
                train_arr1[epoch]=epoch_acc
            else:
                val_arr1[epoch]=epoch_acc

            # C. 今までのエポックでの精度よりも高い場合はモデルの保存
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                if(is_saved):
                    print('Save File original_model_{}.pth'.format(epoch))
                    torch.save(model.state_dict(), '/content/drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_{}.pth'.format(epoch))


    print('Best val Acc: {:4f}'.format(best_acc))
    print(train_arr1)
    print(val_arr1)
    train_ser1 = pd.Series(train_arr1,name='train_acc')
    result_data = pd.DataFrame(train_ser1)
    result_data['val_acc']=val_arr1
    result_data.plot()
    plt.show()

train_model(model = model_ft,criterion = criterion,optimizer = optimizer,num_epochs=EPOCH,is_saved = True)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# train:フェイズ
#    loaders:1回目    loss:2.3254687786102295
#    loaders:2回目    loss:2.350421905517578
#    loaders:3回目    loss:2.2672836780548096
#    loaders:4回目    loss:2.2029314041137695
#    loaders:5回目    loss:2.107774257659912
#    loaders:6回目    loss:2.1413986682891846
#    loaders:7回目    loss:2.0033657550811768
#    loaders:8回目    loss:2.035670280456543
#    loaders:9回目    loss:1.8997787237167358
#    loaders:10回目    loss:1.7267355918884277
#    loaders:11回目    loss:1.7052147388458252
#    loaders:12回目    loss:1.5760384798049927
#    loaders:13回目    loss:1.4089280366897583
#    loaders:14回目    loss:1.3160934448242188
#    loaders:15回目    loss:1.3447203636169434
#    loaders:16回目    loss:1.0211273431777954
#    loaders:17回目    loss:0.9724791049957275
#    loaders:18回目    loss:0.8579730987548828
#    loaders:19回目    loss:0.9685153365135193
#    loaders:20回目    loss:0.953373908996582
#    loaders:21回目    loss:0.7772527933120728
#    loaders:22回目    loss:0.7449462413787842
#    loaders:23回目    loss:0.57547926902771
#    loaders:24回目    loss:0.6765803694725037
#    loaders:25回目    loss:0.6131938695907593
#    loaders:26回目    loss:0.48972705006599426
#    loaders:27回目    loss:0.5230750441551208
#    loaders:28回目    loss:0.5616850256919861
#    loaders:29回目    loss:0.44492703676223755
#    loaders:30回目    loss:0.2736566960811615
#    loaders:31回目    loss:0.33646273612976074
#    loaders:32回目    loss:0.3264193534851074
#    loaders:33回目    loss:0.37278369069099426
#    loaders:34回目    loss:0.3341512382030487
#    loaders:35回目    loss:0.36018601059913635
#    loaders:36回目    loss:0.45787590742111206
#    loaders:37回目    loss:0.2152440994977951
#    loaders:38回目    loss:0.304899126291275
#    loaders:39回目    loss:0.27173346281051636
#    loaders:40回目    loss:0.3532664477825165
#    loaders:41回目    loss:0.24993930757045746
#    loaders:42回目    loss:0.3426198363304138
#    loaders:43回目    loss:0.22610320150852203
#    loaders:44回目    loss:0.22576165199279785
#    loaders:45回目    loss:0.46122661232948303
#    loaders:46回目    loss:0.2884722948074341
#    loaders:47回目    loss:0.1462157666683197
#    loaders:48回目    loss:0.23228491842746735
#    loaders:49回目    loss:0.24919405579566956
#    loaders:50回目    loss:0.3547559380531311
#    loaders:51回目    loss:0.24836337566375732
#    loaders:52回目    loss:0.2205570936203003
#    loaders:53回目    loss:0.3020685613155365
#    loaders:54回目    loss:0.21533730626106262
#    loaders:55回目    loss:0.18516087532043457
#    loaders:56回目    loss:0.23619236052036285
#    loaders:57回目    loss:0.2502247393131256
#    loaders:58回目    loss:0.27692532539367676
#    loaders:59回目    loss:0.34833478927612305
#    loaders:60回目    loss:0.17717060446739197
#    loaders:61回目    loss:0.23438163101673126
#    loaders:62回目    loss:0.22969278693199158
# EPOCH0回目 train Loss: 0.7664 Acc: 0.7515
# val:フェイズ
#    loaders:1回目    loss:0.1062648743391037
#    loaders:2回目    loss:0.10457594692707062
#    loaders:3回目    loss:0.05177813395857811
#    loaders:4回目    loss:0.10515479743480682
#    loaders:5回目    loss:0.2152871936559677
#    loaders:6回目    loss:0.1474345475435257
#    loaders:7回目    loss:0.19050762057304382
#    loaders:8回目    loss:0.41740909218788147
#    loaders:9回目    loss:0.3703036606311798
#    loaders:10回目    loss:0.16699649393558502
#    loaders:11回目    loss:0.20625293254852295
#    loaders:12回目    loss:0.3697246313095093
#    loaders:13回目    loss:0.2780476212501526
#    loaders:14回目    loss:0.011296032927930355
#    loaders:15回目    loss:0.34150218963623047
# EPOCH0回目 val Loss: 0.1973 Acc: 0.8990
# Save File original_model_0.pth
# train:フェイズ
#    loaders:1回目    loss:0.1596008986234665
#    loaders:2回目    loss:0.14696407318115234
#    loaders:3回目    loss:0.1269906461238861
#    loaders:4回目    loss:0.22699585556983948
#    loaders:5回目    loss:0.17606689035892487
#    loaders:6回目    loss:0.20566020905971527
#    loaders:7回目    loss:0.31287452578544617
#    loaders:8回目    loss:0.18940576910972595
#    loaders:9回目    loss:0.18151643872261047
#    loaders:10回目    loss:0.3265479803085327
#    loaders:11回目    loss:0.14202329516410828
#    loaders:12回目    loss:0.17044904828071594
#    loaders:13回目    loss:0.08395163714885712
#    loaders:14回目    loss:0.13006159663200378
#    loaders:15回目    loss:0.37012779712677
#    loaders:16回目    loss:0.1904192566871643
#    loaders:17回目    loss:0.10857820510864258
#    loaders:18回目    loss:0.10791195929050446
#    loaders:19回目    loss:0.193410724401474
#    loaders:20回目    loss:0.14394477009773254
#    loaders:21回目    loss:0.1684669703245163
#    loaders:22回目    loss:0.17529001832008362
#    loaders:23回目    loss:0.14935830235481262
#    loaders:24回目    loss:0.12187862396240234
#    loaders:25回目    loss:0.1569340080022812
#    loaders:26回目    loss:0.21378980576992035
#    loaders:27回目    loss:0.0892031267285347
#    loaders:28回目    loss:0.1083880141377449
#    loaders:29回目    loss:0.24665682017803192
#    loaders:30回目    loss:0.16564103960990906
#    loaders:31回目    loss:0.20318034291267395
#    loaders:32回目    loss:0.17681941390037537
#    loaders:33回目    loss:0.23553015291690826
#    loaders:34回目    loss:0.12439984828233719
#    loaders:35回目    loss:0.1994379162788391
#    loaders:36回目    loss:0.2124919891357422
#    loaders:37回目    loss:0.04015234112739563
#    loaders:38回目    loss:0.16355235874652863
#    loaders:39回目    loss:0.3245975375175476
#    loaders:40回目    loss:0.29508912563323975
#    loaders:41回目    loss:0.29615798592567444
#    loaders:42回目    loss:0.1471216231584549
#    loaders:43回目    loss:0.1875046193599701
#    loaders:44回目    loss:0.09990885108709335
#    loaders:45回目    loss:0.20459768176078796
#    loaders:46回目    loss:0.08580060303211212
#    loaders:47回目    loss:0.12469936907291412
#    loaders:48回目    loss:0.12140139937400818
#    loaders:49回目    loss:0.37707841396331787
#    loaders:50回目    loss:0.2134276181459427
#    loaders:51回目    loss:0.24609345197677612
#    loaders:52回目    loss:0.19872687757015228
#    loaders:53回目    loss:0.2343536764383316
#    loaders:54回目    loss:0.1695524901151657
#    loaders:55回目    loss:0.12315534055233002
#    loaders:56回目    loss:0.22108250856399536
#    loaders:57回目    loss:0.10854468494653702
#    loaders:58回目    loss:0.360090047121048
#    loaders:59回目    loss:0.23284126818180084
#    loaders:60回目    loss:0.321810781955719
#    loaders:61回目    loss:0.04406687617301941
#    loaders:62回目    loss:0.047537099570035934
# EPOCH1回目 train Loss: 0.1829 Acc: 0.9320
# val:フェイズ
#    loaders:1回目    loss:0.2545692026615143
#    loaders:2回目    loss:0.22935977578163147
#    loaders:3回目    loss:0.13680320978164673
#    loaders:4回目    loss:0.07100053876638412
#    loaders:5回目    loss:0.3064896762371063
#    loaders:6回目    loss:0.5296760201454163
#    loaders:7回目    loss:0.22789764404296875
#    loaders:8回目    loss:0.21763408184051514
#    loaders:9回目    loss:0.06318727135658264
#    loaders:10回目    loss:0.18419498205184937
#    loaders:11回目    loss:0.13550947606563568
#    loaders:12回目    loss:0.03627921640872955
#    loaders:13回目    loss:0.4385204315185547
#    loaders:14回目    loss:0.36898431181907654
#    loaders:15回目    loss:0.153103306889534
# EPOCH1回目 val Loss: 0.2146 Acc: 0.8890
# train:フェイズ
#    loaders:1回目    loss:0.17656663060188293
#    loaders:2回目    loss:0.11183474212884903
#    loaders:3回目    loss:0.10378982871770859
#    loaders:4回目    loss:0.08687254786491394
#    loaders:5回目    loss:0.15335670113563538
#    loaders:6回目    loss:0.098915234208107
#    loaders:7回目    loss:0.14303258061408997
#    loaders:8回目    loss:0.1492181271314621
#    loaders:9回目    loss:0.15362709760665894
#    loaders:10回目    loss:0.11269214004278183
#    loaders:11回目    loss:0.15244732797145844
#    loaders:12回目    loss:0.04250996187329292
#    loaders:13回目    loss:0.14297188818454742
#    loaders:14回目    loss:0.19552522897720337
#    loaders:15回目    loss:0.08714231103658676
#    loaders:16回目    loss:0.09295336157083511
#    loaders:17回目    loss:0.10117543488740921
#    loaders:18回目    loss:0.1963995397090912
#    loaders:19回目    loss:0.1437622755765915
#    loaders:20回目    loss:0.15931157767772675
#    loaders:21回目    loss:0.12784898281097412
#    loaders:22回目    loss:0.0885564535856247
#    loaders:23回目    loss:0.13567769527435303
#    loaders:24回目    loss:0.07033954560756683
#    loaders:25回目    loss:0.11245428770780563
#    loaders:26回目    loss:0.07106751948595047
#    loaders:27回目    loss:0.036034803837537766
#    loaders:28回目    loss:0.0889735147356987
#    loaders:29回目    loss:0.19866013526916504
#    loaders:30回目    loss:0.09834695607423782
#    loaders:31回目    loss:0.08283481746912003
#    loaders:32回目    loss:0.180368572473526
#    loaders:33回目    loss:0.1835830807685852
#    loaders:34回目    loss:0.056012872606515884
#    loaders:35回目    loss:0.14692546427249908
#    loaders:36回目    loss:0.24774053692817688
#    loaders:37回目    loss:0.04595641791820526
#    loaders:38回目    loss:0.15090934932231903
#    loaders:39回目    loss:0.09896890819072723
#    loaders:40回目    loss:0.12563994526863098
#    loaders:41回目    loss:0.10660220682621002
#    loaders:42回目    loss:0.19317461550235748
#    loaders:43回目    loss:0.08199162781238556
#    loaders:44回目    loss:0.19479051232337952
#    loaders:45回目    loss:0.16409389674663544
#    loaders:46回目    loss:0.09066745638847351
#    loaders:47回目    loss:0.18253830075263977
#    loaders:48回目    loss:0.13164536654949188
#    loaders:49回目    loss:0.08207093924283981
#    loaders:50回目    loss:0.11896732449531555
#    loaders:51回目    loss:0.19462236762046814
#    loaders:52回目    loss:0.04235915467143059
#    loaders:53回目    loss:0.1604381501674652
#    loaders:54回目    loss:0.08693301677703857
#    loaders:55回目    loss:0.13613057136535645
#    loaders:56回目    loss:0.061735883355140686
#    loaders:57回目    loss:0.08955462276935577
#    loaders:58回目    loss:0.11014793813228607
#    loaders:59回目    loss:0.10964658111333847
#    loaders:60回目    loss:0.13862237334251404
#    loaders:61回目    loss:0.12372176349163055
#    loaders:62回目    loss:0.16414543986320496
# EPOCH2回目 train Loss: 0.1234 Acc: 0.9517
# val:フェイズ
#    loaders:1回目    loss:0.2708023488521576
#    loaders:2回目    loss:0.17880135774612427
#    loaders:3回目    loss:0.1020311638712883
#    loaders:4回目    loss:0.18030476570129395
#    loaders:5回目    loss:0.2359679490327835
#    loaders:6回目    loss:0.262218713760376
#    loaders:7回目    loss:0.07915408164262772
#    loaders:8回目    loss:0.14894866943359375
#    loaders:9回目    loss:0.13932213187217712
#    loaders:10回目    loss:0.19922176003456116
#    loaders:11回目    loss:0.15671218931674957
#    loaders:12回目    loss:0.06410203129053116
#    loaders:13回目    loss:0.17179740965366364
#    loaders:14回目    loss:0.02215488627552986
#    loaders:15回目    loss:0.16787637770175934
# EPOCH2回目 val Loss: 0.1523 Acc: 0.9180
# Save File original_model_2.pth
# train:フェイズ
#    loaders:1回目    loss:0.10296472907066345
#    loaders:2回目    loss:0.03989984467625618
#    loaders:3回目    loss:0.10222498327493668
#    loaders:4回目    loss:0.030542470514774323
#    loaders:5回目    loss:0.06053955480456352
#    loaders:6回目    loss:0.08705788105726242
#    loaders:7回目    loss:0.037084102630615234
#    loaders:8回目    loss:0.05830893665552139
#    loaders:9回目    loss:0.05864577740430832
#    loaders:10回目    loss:0.03028067573904991
#    loaders:11回目    loss:0.08726657927036285
#    loaders:12回目    loss:0.06658776849508286
#    loaders:13回目    loss:0.05984799191355705
#    loaders:14回目    loss:0.041739463806152344
#    loaders:15回目    loss:0.06494421511888504
#    loaders:16回目    loss:0.04581456258893013
#    loaders:17回目    loss:0.021754417568445206
#    loaders:18回目    loss:0.024044793099164963
#    loaders:19回目    loss:0.02439437061548233
#    loaders:20回目    loss:0.08334105461835861
#    loaders:21回目    loss:0.09699627757072449
#    loaders:22回目    loss:0.12318357825279236
#    loaders:23回目    loss:0.060074422508478165
#    loaders:24回目    loss:0.055178023874759674
#    loaders:25回目    loss:0.05911971256136894
#    loaders:26回目    loss:0.023891085758805275
#    loaders:27回目    loss:0.026767203584313393
#    loaders:28回目    loss:0.10058338940143585
#    loaders:29回目    loss:0.043695930391550064
#    loaders:30回目    loss:0.09292977303266525
#    loaders:31回目    loss:0.09761493653059006
#    loaders:32回目    loss:0.0319506898522377
#    loaders:33回目    loss:0.03293459117412567
#    loaders:34回目    loss:0.03835946321487427
#    loaders:35回目    loss:0.06596682965755463
#    loaders:36回目    loss:0.020559724420309067
#    loaders:37回目    loss:0.07716579735279083
#    loaders:38回目    loss:0.025923334062099457
#    loaders:39回目    loss:0.03073125332593918
#    loaders:40回目    loss:0.07861130684614182
#    loaders:41回目    loss:0.04748506844043732
#    loaders:42回目    loss:0.03536587208509445
#    loaders:43回目    loss:0.04789648950099945
#    loaders:44回目    loss:0.13488568365573883
#    loaders:45回目    loss:0.06955745071172714
#    loaders:46回目    loss:0.13927142322063446
#    loaders:47回目    loss:0.08045442402362823
#    loaders:48回目    loss:0.02357391081750393
#    loaders:49回目    loss:0.053191039711236954
#    loaders:50回目    loss:0.022888345643877983
#    loaders:51回目    loss:0.06648529320955276
#    loaders:52回目    loss:0.10401559621095657
#    loaders:53回目    loss:0.031223969534039497
#    loaders:54回目    loss:0.08376850187778473
#    loaders:55回目    loss:0.06447652727365494
#    loaders:56回目    loss:0.1324925273656845
#    loaders:57回目    loss:0.02451837994158268
#    loaders:58回目    loss:0.047847796231508255
#    loaders:59回目    loss:0.09393057227134705
#    loaders:60回目    loss:0.07142999023199081
#    loaders:61回目    loss:0.046621136367321014
#    loaders:62回目    loss:0.03930877149105072
# EPOCH3回目 train Loss: 0.0603 Acc: 0.9755
# val:フェイズ
#    loaders:1回目    loss:0.17889724671840668
#    loaders:2回目    loss:0.07464934140443802
#    loaders:3回目    loss:0.024754393845796585
#    loaders:4回目    loss:0.053098008036613464
#    loaders:5回目    loss:0.27584537863731384
#    loaders:6回目    loss:0.43548792600631714
#    loaders:7回目    loss:0.24917572736740112
#    loaders:8回目    loss:0.21519365906715393
#    loaders:9回目    loss:0.07208329439163208
#    loaders:10回目    loss:0.2946320176124573
#    loaders:11回目    loss:0.30821865797042847
#    loaders:12回目    loss:0.05093462020158768
#    loaders:13回目    loss:0.06655091047286987
#    loaders:14回目    loss:0.01183860469609499
#    loaders:15回目    loss:0.2514587938785553
# EPOCH3回目 val Loss: 0.1640 Acc: 0.9030
# train:フェイズ
#    loaders:1回目    loss:0.0265362486243248
#    loaders:2回目    loss:0.11967466026544571
#    loaders:3回目    loss:0.04414839297533035
#    loaders:4回目    loss:0.0585402250289917
#    loaders:5回目    loss:0.03342113271355629
#    loaders:6回目    loss:0.047540511935949326
#    loaders:7回目    loss:0.04122476279735565
#    loaders:8回目    loss:0.03753487765789032
#    loaders:9回目    loss:0.054562218487262726
#    loaders:10回目    loss:0.05732666328549385
#    loaders:11回目    loss:0.0152444401755929
#    loaders:12回目    loss:0.10197343677282333
#    loaders:13回目    loss:0.029826216399669647
#    loaders:14回目    loss:0.06210746243596077
#    loaders:15回目    loss:0.1143459901213646
#    loaders:16回目    loss:0.022568246349692345
#    loaders:17回目    loss:0.11870396137237549
#    loaders:18回目    loss:0.064703069627285
#    loaders:19回目    loss:0.0967269018292427
#    loaders:20回目    loss:0.033556487411260605
#    loaders:21回目    loss:0.013238559477031231
#    loaders:22回目    loss:0.03437849134206772
#    loaders:23回目    loss:0.016743073239922523
#    loaders:24回目    loss:0.07154479622840881
#    loaders:25回目    loss:0.15557962656021118
#    loaders:26回目    loss:0.04433201253414154
#    loaders:27回目    loss:0.04246733710169792
#    loaders:28回目    loss:0.09068834036588669
#    loaders:29回目    loss:0.014560949057340622
#    loaders:30回目    loss:0.046774230897426605
#    loaders:31回目    loss:0.018425749614834785
#    loaders:32回目    loss:0.012661075219511986
#    loaders:33回目    loss:0.07690262049436569
#    loaders:34回目    loss:0.0752163976430893
#    loaders:35回目    loss:0.056386373937129974
#    loaders:36回目    loss:0.04302097484469414
#    loaders:37回目    loss:0.017516041174530983
#    loaders:38回目    loss:0.06818794459104538
#    loaders:39回目    loss:0.02314787730574608
#    loaders:40回目    loss:0.019532151520252228
#    loaders:41回目    loss:0.07154928892850876
#    loaders:42回目    loss:0.08761332184076309
#    loaders:43回目    loss:0.03788142651319504
#    loaders:44回目    loss:0.02177632413804531
#    loaders:45回目    loss:0.0800531879067421
#    loaders:46回目    loss:0.0671696588397026
#    loaders:47回目    loss:0.009193973615765572
#    loaders:48回目    loss:0.02240791544318199
#    loaders:49回目    loss:0.07752808928489685
#    loaders:50回目    loss:0.009736817330121994
#    loaders:51回目    loss:0.007413450628519058
#    loaders:52回目    loss:0.04140446335077286
#    loaders:53回目    loss:0.04201940447092056
#    loaders:54回目    loss:0.04741179943084717
#    loaders:55回目    loss:0.09727010130882263
#    loaders:56回目    loss:0.024261150509119034
#    loaders:57回目    loss:0.03730002045631409
#    loaders:58回目    loss:0.015304521657526493
#    loaders:59回目    loss:0.05057058110833168
#    loaders:60回目    loss:0.015155442990362644
#    loaders:61回目    loss:0.04747455194592476
#    loaders:62回目    loss:0.012155557051301003
# EPOCH4回目 train Loss: 0.0487 Acc: 0.9780
# val:フェイズ
#    loaders:1回目    loss:0.15612207353115082
#    loaders:2回目    loss:0.06981371343135834
#    loaders:3回目    loss:0.02626252919435501
#    loaders:4回目    loss:0.06509702652692795
#    loaders:5回目    loss:0.2796032428741455
#    loaders:6回目    loss:0.1712847501039505
#    loaders:7回目    loss:0.08468831330537796
#    loaders:8回目    loss:0.17397138476371765
#    loaders:9回目    loss:0.01633778214454651
#    loaders:10回目    loss:0.156241312623024
#    loaders:11回目    loss:0.07539866119623184
#    loaders:12回目    loss:0.17647764086723328
#    loaders:13回目    loss:0.17522987723350525
#    loaders:14回目    loss:0.0033980938605964184
#    loaders:15回目    loss:0.2953077554702759
# EPOCH4回目 val Loss: 0.1232 Acc: 0.9280
# Save File original_model_4.pth
# train:フェイズ
#    loaders:1回目    loss:0.11526178568601608
#    loaders:2回目    loss:0.008290741592645645
#    loaders:3回目    loss:0.025818996131420135
#    loaders:4回目    loss:0.005959898233413696
#    loaders:5回目    loss:0.02391335926949978
#    loaders:6回目    loss:0.015738850459456444
#    loaders:7回目    loss:0.060663141310214996
#    loaders:8回目    loss:0.034036606550216675
#    loaders:9回目    loss:0.06272329390048981
#    loaders:10回目    loss:0.03736475855112076
#    loaders:11回目    loss:0.007364816498011351
#    loaders:12回目    loss:0.0060598356649279594
#    loaders:13回目    loss:0.008623919449746609
#    loaders:14回目    loss:0.01337376981973648
#    loaders:15回目    loss:0.0048586539924144745
#    loaders:16回目    loss:0.006389578338712454
#    loaders:17回目    loss:0.08779840171337128
#    loaders:18回目    loss:0.018902122974395752
#    loaders:19回目    loss:0.028057565912604332
#    loaders:20回目    loss:0.029113976284861565
#    loaders:21回目    loss:0.019875209778547287
#    loaders:22回目    loss:0.00833907350897789
#    loaders:23回目    loss:0.010425209999084473
#    loaders:24回目    loss:0.04155668988823891
#    loaders:25回目    loss:0.0478719063103199
#    loaders:26回目    loss:0.039010368287563324
#    loaders:27回目    loss:0.02360399439930916
#    loaders:28回目    loss:0.05238663777709007
#    loaders:29回目    loss:0.019212355837225914
#    loaders:30回目    loss:0.022119849920272827
#    loaders:31回目    loss:0.022587182000279427
#    loaders:32回目    loss:0.01212455052882433
#    loaders:33回目    loss:0.013072025030851364
#    loaders:34回目    loss:0.04964182525873184
#    loaders:35回目    loss:0.07229944318532944
#    loaders:36回目    loss:0.016795992851257324
#    loaders:37回目    loss:0.015809565782546997
#    loaders:38回目    loss:0.02590435929596424
#    loaders:39回目    loss:0.00836389884352684
#    loaders:40回目    loss:0.02420853078365326
#    loaders:41回目    loss:0.016690338030457497
#    loaders:42回目    loss:0.01423657312989235
#    loaders:43回目    loss:0.032878562808036804
#    loaders:44回目    loss:0.021687233820557594
#    loaders:45回目    loss:0.020017577335238457
#    loaders:46回目    loss:0.01925545372068882
#    loaders:47回目    loss:0.05846381559967995
#    loaders:48回目    loss:0.018895724788308144
#    loaders:49回目    loss:0.006282264366745949
#    loaders:50回目    loss:0.021708402782678604
#    loaders:51回目    loss:0.06338979303836823
#    loaders:52回目    loss:0.0864153727889061
#    loaders:53回目    loss:0.011492705903947353
#    loaders:54回目    loss:0.010521146468818188
#    loaders:55回目    loss:0.007407374680042267
#    loaders:56回目    loss:0.009362681768834591
#    loaders:57回目    loss:0.016064006835222244
#    loaders:58回目    loss:0.04876561462879181
#    loaders:59回目    loss:0.0278911329805851
#    loaders:60回目    loss:0.021805154159665108
#    loaders:61回目    loss:0.004183175042271614
#    loaders:62回目    loss:0.08273185789585114
# EPOCH5回目 train Loss: 0.0283 Acc: 0.9840
# val:フェイズ
#    loaders:1回目    loss:0.11436235904693604
#    loaders:2回目    loss:0.09362815320491791
#    loaders:3回目    loss:0.02318131923675537
#    loaders:4回目    loss:0.09972789883613586
#    loaders:5回目    loss:0.32903608679771423
#    loaders:6回目    loss:0.38545435667037964
#    loaders:7回目    loss:0.201128289103508
#    loaders:8回目    loss:0.21856310963630676
#    loaders:9回目    loss:0.06396505981683731
#    loaders:10回目    loss:0.15192992985248566
#    loaders:11回目    loss:0.040952153503894806
#    loaders:12回目    loss:0.15026438236236572
#    loaders:13回目    loss:0.16886334121227264
#    loaders:14回目    loss:0.02760748192667961
#    loaders:15回目    loss:0.24843183159828186
# EPOCH5回目 val Loss: 0.1483 Acc: 0.9150
# train:フェイズ
#    loaders:1回目    loss:0.005981478840112686
#    loaders:2回目    loss:0.024338046088814735
#    loaders:3回目    loss:0.0120360367000103
#    loaders:4回目    loss:0.0248603206127882
#    loaders:5回目    loss:0.007544258143752813
#    loaders:6回目    loss:0.015902159735560417
#    loaders:7回目    loss:0.024352245032787323
#    loaders:8回目    loss:0.015724755823612213
#    loaders:9回目    loss:0.029557229951024055
#    loaders:10回目    loss:0.003827134147286415
#    loaders:11回目    loss:0.01763741485774517
#    loaders:12回目    loss:0.0445929616689682
#    loaders:13回目    loss:0.01190435141324997
#    loaders:14回目    loss:0.018698779866099358
#    loaders:15回目    loss:0.006936245132237673
#    loaders:16回目    loss:0.01526506058871746
#    loaders:17回目    loss:0.013317792676389217
#    loaders:18回目    loss:0.03400282561779022
#    loaders:19回目    loss:0.002934905933216214
#    loaders:20回目    loss:0.016128724440932274
#    loaders:21回目    loss:0.047115545719861984
#    loaders:22回目    loss:0.014576137997210026
#    loaders:23回目    loss:0.021490968763828278
#    loaders:24回目    loss:0.012445196509361267
#    loaders:25回目    loss:0.017983926460146904
#    loaders:26回目    loss:0.009727077558636665
#    loaders:27回目    loss:0.030332431197166443
#    loaders:28回目    loss:0.02139434590935707
#    loaders:29回目    loss:0.016126472502946854
#    loaders:30回目    loss:0.07649111747741699
#    loaders:31回目    loss:0.004969933535903692
#    loaders:32回目    loss:0.009164322167634964
#    loaders:33回目    loss:0.006388618145138025
#    loaders:34回目    loss:0.026827694848179817
#    loaders:35回目    loss:0.07502185553312302
#    loaders:36回目    loss:0.02609056606888771
#    loaders:37回目    loss:0.013221094384789467
#    loaders:38回目    loss:0.00495357858017087
#    loaders:39回目    loss:0.02201339229941368
#    loaders:40回目    loss:0.011600671336054802
#    loaders:41回目    loss:0.01114015281200409
#    loaders:42回目    loss:0.10534794628620148
#    loaders:43回目    loss:0.014072071760892868
#    loaders:44回目    loss:0.027927465736865997
#    loaders:45回目    loss:0.025415224954485893
#    loaders:46回目    loss:0.016544323414564133
#    loaders:47回目    loss:0.013599388301372528
#    loaders:48回目    loss:0.03746490553021431
#    loaders:49回目    loss:0.04184434935450554
#    loaders:50回目    loss:0.028982387855648994
#    loaders:51回目    loss:0.016588818281888962
#    loaders:52回目    loss:0.02192501164972782
#    loaders:53回目    loss:0.0438346303999424
#    loaders:54回目    loss:0.007521301042288542
#    loaders:55回目    loss:0.01448087114840746
#    loaders:56回目    loss:0.018238073214888573
#    loaders:57回目    loss:0.006412157788872719
#    loaders:58回目    loss:0.03365606442093849
#    loaders:59回目    loss:0.09864530712366104
#    loaders:60回目    loss:0.017665162682533264
#    loaders:61回目    loss:0.010597467422485352
#    loaders:62回目    loss:0.011715627275407314
# EPOCH6回目 train Loss: 0.0230 Acc: 0.9860
# val:フェイズ
#    loaders:1回目    loss:0.09374310821294785
#    loaders:2回目    loss:0.09231781214475632
#    loaders:3回目    loss:0.05960274487733841
#    loaders:4回目    loss:0.14900155365467072
#    loaders:5回目    loss:0.19522973895072937
#    loaders:6回目    loss:0.20768414437770844
#    loaders:7回目    loss:0.11952908337116241
#    loaders:8回目    loss:0.2102397233247757
#    loaders:9回目    loss:0.18412740528583527
#    loaders:10回目    loss:0.33135178685188293
#    loaders:11回目    loss:0.10338028520345688
#    loaders:12回目    loss:0.20269674062728882
#    loaders:13回目    loss:0.1508568823337555
#    loaders:14回目    loss:0.01833140105009079
#    loaders:15回目    loss:0.1410842388868332
# EPOCH6回目 val Loss: 0.1446 Acc: 0.9130
# train:フェイズ
#    loaders:1回目    loss:0.13564008474349976
#    loaders:2回目    loss:0.008572990074753761
#    loaders:3回目    loss:0.031507641077041626
#    loaders:4回目    loss:0.01430132333189249
#    loaders:5回目    loss:0.004321559797972441
#    loaders:6回目    loss:0.04349469020962715
#    loaders:7回目    loss:0.010140858590602875
#    loaders:8回目    loss:0.01620667055249214
#    loaders:9回目    loss:0.025027262046933174
#    loaders:10回目    loss:0.026211760938167572
#    loaders:11回目    loss:0.018826674669981003
#    loaders:12回目    loss:0.0023155836388468742
#    loaders:13回目    loss:0.003948161378502846
#    loaders:14回目    loss:0.003458080580458045
#    loaders:15回目    loss:0.030280256643891335
#    loaders:16回目    loss:0.012956458143889904
#    loaders:17回目    loss:0.026271317154169083
#    loaders:18回目    loss:0.008537151850759983
#    loaders:19回目    loss:0.018438884988427162
#    loaders:20回目    loss:0.017082465812563896
#    loaders:21回目    loss:0.03188212588429451
#    loaders:22回目    loss:0.07205115258693695
#    loaders:23回目    loss:0.04732028767466545
#    loaders:24回目    loss:0.03394898772239685
#    loaders:25回目    loss:0.014522717334330082
#    loaders:26回目    loss:0.037256062030792236
#    loaders:27回目    loss:0.005912076216191053
#    loaders:28回目    loss:0.013628704473376274
#    loaders:29回目    loss:0.09577327221632004
#    loaders:30回目    loss:0.006524502765387297
#    loaders:31回目    loss:0.08171119540929794
#    loaders:32回目    loss:0.02650933898985386
#    loaders:33回目    loss:0.029432805255055428
#    loaders:34回目    loss:0.02242845483124256
#    loaders:35回目    loss:0.011877980083227158
#    loaders:36回目    loss:0.013336066156625748
#    loaders:37回目    loss:0.013437471352517605
#    loaders:38回目    loss:0.011065850965678692
#    loaders:39回目    loss:0.015580223873257637
#    loaders:40回目    loss:0.026446087285876274
#    loaders:41回目    loss:0.051948532462120056
#    loaders:42回目    loss:0.03596632182598114
#    loaders:43回目    loss:0.04735708609223366
#    loaders:44回目    loss:0.027743464335799217
#    loaders:45回目    loss:0.019376328215003014
#    loaders:46回目    loss:0.02138177677989006
#    loaders:47回目    loss:0.08353030681610107
#    loaders:48回目    loss:0.028225690126419067
#    loaders:49回目    loss:0.010308110155165195
#    loaders:50回目    loss:0.021494492888450623
#    loaders:51回目    loss:0.009845935739576817
#    loaders:52回目    loss:0.004930306226015091
#    loaders:53回目    loss:0.04648883640766144
#    loaders:54回目    loss:0.060952626168727875
#    loaders:55回目    loss:0.020173585042357445
#    loaders:56回目    loss:0.017285794019699097
#    loaders:57回目    loss:0.07532531023025513
#    loaders:58回目    loss:0.02246755361557007
#    loaders:59回目    loss:0.01253468543291092
#    loaders:60回目    loss:0.022240212187170982
#    loaders:61回目    loss:0.023058412596583366
#    loaders:62回目    loss:0.03543713316321373
# EPOCH7回目 train Loss: 0.0283 Acc: 0.9848
# val:フェイズ
#    loaders:1回目    loss:0.11541850119829178
#    loaders:2回目    loss:0.07309971004724503
#    loaders:3回目    loss:0.012241773307323456
#    loaders:4回目    loss:0.11328548938035965
#    loaders:5回目    loss:0.18248887360095978
#    loaders:6回目    loss:0.28277313709259033
#    loaders:7回目    loss:0.0987691655755043
#    loaders:8回目    loss:0.21655327081680298
#    loaders:9回目    loss:0.23389790952205658
#    loaders:10回目    loss:0.20639261603355408
#    loaders:11回目    loss:0.0876740887761116
#    loaders:12回目    loss:0.16528663039207458
#    loaders:13回目    loss:0.15197935700416565
#    loaders:14回目    loss:0.07080541551113129
#    loaders:15回目    loss:0.15040642023086548
# EPOCH7回目 val Loss: 0.1383 Acc: 0.9180
# train:フェイズ
#    loaders:1回目    loss:0.02424386516213417
#    loaders:2回目    loss:0.01326589472591877
#    loaders:3回目    loss:0.007848886772990227
#    loaders:4回目    loss:0.03373662754893303
#    loaders:5回目    loss:0.006170835345983505
#    loaders:6回目    loss:0.023065704852342606
#    loaders:7回目    loss:0.07332569360733032
#    loaders:8回目    loss:0.01069432869553566
#    loaders:9回目    loss:0.02273632399737835
#    loaders:10回目    loss:0.010231508873403072
#    loaders:11回目    loss:0.08410527557134628
#    loaders:12回目    loss:0.013643982820212841
#    loaders:13回目    loss:0.04997945576906204
#    loaders:14回目    loss:0.028905536979436874
#    loaders:15回目    loss:0.017880607396364212
#    loaders:16回目    loss:0.010018965229392052
#    loaders:17回目    loss:0.03413602337241173
#    loaders:18回目    loss:0.03266429156064987
#    loaders:19回目    loss:0.02303784154355526
#    loaders:20回目    loss:0.021677494049072266
#    loaders:21回目    loss:0.008547217585146427
#    loaders:22回目    loss:0.020793508738279343
#    loaders:23回目    loss:0.020650269463658333
#    loaders:24回目    loss:0.0069219134747982025
#    loaders:25回目    loss:0.011757601983845234
#    loaders:26回目    loss:0.04691147059202194
#    loaders:27回目    loss:0.0026375644374638796
#    loaders:28回目    loss:0.016200337558984756
#    loaders:29回目    loss:0.014411036856472492
#    loaders:30回目    loss:0.05663934350013733
#    loaders:31回目    loss:0.021268660202622414
#    loaders:32回目    loss:0.04136030748486519
#    loaders:33回目    loss:0.006545888725668192
#    loaders:34回目    loss:0.005570863839238882
#    loaders:35回目    loss:0.013816271908581257
#    loaders:36回目    loss:0.009025550447404385
#    loaders:37回目    loss:0.030415255576372147
#    loaders:38回目    loss:0.007032269611954689
#    loaders:39回目    loss:0.0064124129712581635
#    loaders:40回目    loss:0.004500434268265963
#    loaders:41回目    loss:0.04459063336253166
#    loaders:42回目    loss:0.04758904501795769
#    loaders:43回目    loss:0.008458263240754604
#    loaders:44回目    loss:0.03606659546494484
#    loaders:45回目    loss:0.02770313434302807
#    loaders:46回目    loss:0.22585876286029816
#    loaders:47回目    loss:0.01047118566930294
#    loaders:48回目    loss:0.02467825822532177
#    loaders:49回目    loss:0.014396507292985916
#    loaders:50回目    loss:0.11611279100179672
#    loaders:51回目    loss:0.013619247823953629
#    loaders:52回目    loss:0.0034110683482140303
#    loaders:53回目    loss:0.05951215326786041
#    loaders:54回目    loss:0.05049940571188927
#    loaders:55回目    loss:0.06230153143405914
#    loaders:56回目    loss:0.032564204186201096
#    loaders:57回目    loss:0.001804481609724462
#    loaders:58回目    loss:0.027143988758325577
#    loaders:59回目    loss:0.008538613095879555
#    loaders:60回目    loss:0.007390717044472694
#    loaders:61回目    loss:0.014060474932193756
#    loaders:62回目    loss:0.06935867667198181
# EPOCH8回目 train Loss: 0.0288 Acc: 0.9838
# val:フェイズ
#    loaders:1回目    loss:0.07838981598615646
#    loaders:2回目    loss:0.07991566509008408
#    loaders:3回目    loss:0.010807862505316734
#    loaders:4回目    loss:0.13209547102451324
#    loaders:5回目    loss:0.20679214596748352
#    loaders:6回目    loss:0.2335556000471115
#    loaders:7回目    loss:0.08809518814086914
#    loaders:8回目    loss:0.3246710002422333
#    loaders:9回目    loss:0.2839086055755615
#    loaders:10回目    loss:0.16519930958747864
#    loaders:11回目    loss:0.06138690933585167
#    loaders:12回目    loss:0.2304469496011734
#    loaders:13回目    loss:0.10913015902042389
#    loaders:14回目    loss:0.005797830410301685
#    loaders:15回目    loss:0.41674402356147766
# EPOCH8回目 val Loss: 0.1553 Acc: 0.9110
# train:フェイズ
#    loaders:1回目    loss:0.05708913505077362
#    loaders:2回目    loss:0.03950590640306473
#    loaders:3回目    loss:0.005943837109953165
#    loaders:4回目    loss:0.019378753378987312
#    loaders:5回目    loss:0.023484747856855392
#    loaders:6回目    loss:0.011320151388645172
#    loaders:7回目    loss:0.007286397740244865
#    loaders:8回目    loss:0.05971677973866463
#    loaders:9回目    loss:0.003653277177363634
#    loaders:10回目    loss:0.05033279210329056
#    loaders:11回目    loss:0.014688880182802677
#    loaders:12回目    loss:0.029454121366143227
#    loaders:13回目    loss:0.03138107806444168
#    loaders:14回目    loss:0.007185945753008127
#    loaders:15回目    loss:0.04888402298092842
#    loaders:16回目    loss:0.007401654496788979
#    loaders:17回目    loss:0.01356001477688551
#    loaders:18回目    loss:0.016801828518509865
#    loaders:19回目    loss:0.016127347946166992
#    loaders:20回目    loss:0.006752271670848131
#    loaders:21回目    loss:0.002202986739575863
#    loaders:22回目    loss:0.003836281830444932
#    loaders:23回目    loss:0.0056650517508387566
#    loaders:24回目    loss:0.0023339958861470222
#    loaders:25回目    loss:0.0356806181371212
#    loaders:26回目    loss:0.008556502871215343
#    loaders:27回目    loss:0.00631109531968832
#    loaders:28回目    loss:0.09937157481908798
#    loaders:29回目    loss:0.00539591396227479
#    loaders:30回目    loss:0.008537116460502148
#    loaders:31回目    loss:0.018822457641363144
#    loaders:32回目    loss:0.02684050053358078
#    loaders:33回目    loss:0.0046562571078538895
#    loaders:34回目    loss:0.018272629007697105
#    loaders:35回目    loss:0.022773046046495438
#    loaders:36回目    loss:0.016810154542326927
#    loaders:37回目    loss:0.015736842527985573
#    loaders:38回目    loss:0.008188346400856972
#    loaders:39回目    loss:0.002833317033946514
#    loaders:40回目    loss:0.006623071618378162
#    loaders:41回目    loss:0.018411654978990555
#    loaders:42回目    loss:0.030578158795833588
#    loaders:43回目    loss:0.026750847697257996
#    loaders:44回目    loss:0.013425365090370178
#    loaders:45回目    loss:0.04215780273079872
#    loaders:46回目    loss:0.07519062608480453
#    loaders:47回目    loss:0.029006410390138626
#    loaders:48回目    loss:0.00507311848923564
#    loaders:49回目    loss:0.01209543738514185
#    loaders:50回目    loss:0.014121930114924908
#    loaders:51回目    loss:0.026838283985853195
#    loaders:52回目    loss:0.0037117868196219206
#    loaders:53回目    loss:0.043500591069459915
#    loaders:54回目    loss:0.013728066347539425
#    loaders:55回目    loss:0.001938102301210165
#    loaders:56回目    loss:0.026518438011407852
#    loaders:57回目    loss:0.06139187887310982
#    loaders:58回目    loss:0.025042103603482246
#    loaders:59回目    loss:0.011236613616347313
#    loaders:60回目    loss:0.016890091821551323
#    loaders:61回目    loss:0.008113536983728409
#    loaders:62回目    loss:0.03960985317826271
# EPOCH9回目 train Loss: 0.0214 Acc: 0.9850
# val:フェイズ
#    loaders:1回目    loss:0.09155836701393127
#    loaders:2回目    loss:0.09984852373600006
#    loaders:3回目    loss:0.025724004954099655
#    loaders:4回目    loss:0.0982055813074112
#    loaders:5回目    loss:0.23980121314525604
#    loaders:6回目    loss:0.28014105558395386
#    loaders:7回目    loss:0.07728175073862076
#    loaders:8回目    loss:0.22403544187545776
#    loaders:9回目    loss:0.031487446278333664
#    loaders:10回目    loss:0.2578808665275574
#    loaders:11回目    loss:0.25629884004592896
#    loaders:12回目    loss:0.21284490823745728
#    loaders:13回目    loss:0.1204412430524826
#    loaders:14回目    loss:0.020073484629392624
#    loaders:15回目    loss:0.16703802347183228
# EPOCH9回目 val Loss: 0.1410 Acc: 0.9230
# train:フェイズ
#    loaders:1回目    loss:0.023159030824899673
#    loaders:2回目    loss:0.03634442016482353
#    loaders:3回目    loss:0.005331318825483322
#    loaders:4回目    loss:0.003038590308278799
#    loaders:5回目    loss:0.02431831695139408
#    loaders:6回目    loss:0.0013228063471615314
#    loaders:7回目    loss:0.003343236166983843
#    loaders:8回目    loss:0.03643514961004257
#    loaders:9回目    loss:0.04104553535580635
#    loaders:10回目    loss:0.0027016685344278812
#    loaders:11回目    loss:0.003164330031722784
#    loaders:12回目    loss:0.0065789734944701195
#    loaders:13回目    loss:0.007868620567023754
#    loaders:14回目    loss:0.00260176626034081
#    loaders:15回目    loss:0.009238828904926777
#    loaders:16回目    loss:0.0057111321948468685
#    loaders:17回目    loss:0.005624073091894388
#    loaders:18回目    loss:0.06199748441576958
#    loaders:19回目    loss:0.01111388485878706
#    loaders:20回目    loss:0.002003088826313615
#    loaders:21回目    loss:0.06426435708999634
#    loaders:22回目    loss:0.03916352987289429
#    loaders:23回目    loss:0.014842113479971886
#    loaders:24回目    loss:0.0080586988478899
#    loaders:25回目    loss:0.10502719134092331
#    loaders:26回目    loss:0.004881842527538538
#    loaders:27回目    loss:0.0032845758832991123
#    loaders:28回目    loss:0.013265935704112053
#    loaders:29回目    loss:0.00817046407610178
#    loaders:30回目    loss:0.014315072447061539
#    loaders:31回目    loss:0.03341640159487724
#    loaders:32回目    loss:0.009301645681262016
#    loaders:33回目    loss:0.012718120589852333
#    loaders:34回目    loss:0.02138044498860836
#    loaders:35回目    loss:0.028176458552479744
#    loaders:36回目    loss:0.00825850386172533
#    loaders:37回目    loss:0.010928718373179436
#    loaders:38回目    loss:0.007183093577623367
#    loaders:39回目    loss:0.0036549551878124475
#    loaders:40回目    loss:0.007167907431721687
#    loaders:41回目    loss:0.006796360015869141
#    loaders:42回目    loss:0.026363877579569817
#    loaders:43回目    loss:0.00858572032302618
#    loaders:44回目    loss:0.00830873567610979
#    loaders:45回目    loss:0.018649524077773094
#    loaders:46回目    loss:0.02148536406457424
#    loaders:47回目    loss:0.0142768369987607
#    loaders:48回目    loss:0.030136220157146454
#    loaders:49回目    loss:0.0047339219599962234
#    loaders:50回目    loss:0.01388055831193924
#    loaders:51回目    loss:0.026468224823474884
#    loaders:52回目    loss:0.007017239928245544
#    loaders:53回目    loss:0.059273190796375275
#    loaders:54回目    loss:0.005863883066922426
#    loaders:55回目    loss:0.013818662613630295
#    loaders:56回目    loss:0.00878484919667244
#    loaders:57回目    loss:0.028275759890675545
#    loaders:58回目    loss:0.002013556193560362
#    loaders:59回目    loss:0.00615309365093708
#    loaders:60回目    loss:0.007492201402783394
#    loaders:61回目    loss:0.004545303992927074
#    loaders:62回目    loss:0.003609041916206479
# EPOCH10回目 train Loss: 0.0166 Acc: 0.9878
# val:フェイズ
#    loaders:1回目    loss:0.23081976175308228
#    loaders:2回目    loss:0.14171725511550903
#    loaders:3回目    loss:0.04938780143857002
#    loaders:4回目    loss:0.0631089136004448
#    loaders:5回目    loss:0.13217978179454803
#    loaders:6回目    loss:0.23058505356311798
#    loaders:7回目    loss:0.04268614202737808
#    loaders:8回目    loss:0.21981661021709442
#    loaders:9回目    loss:0.14138618111610413
#    loaders:10回目    loss:0.1481972485780716
#    loaders:11回目    loss:0.11697332561016083
#    loaders:12回目    loss:0.0927359014749527
#    loaders:13回目    loss:0.11196878552436829
#    loaders:14回目    loss:0.0011804808164015412
#    loaders:15回目    loss:0.38160648941993713
# EPOCH10回目 val Loss: 0.1347 Acc: 0.9220
# train:フェイズ
#    loaders:1回目    loss:0.02531963773071766
#    loaders:2回目    loss:0.044286053627729416
#    loaders:3回目    loss:0.006819266360253096
#    loaders:4回目    loss:0.00346580077894032
#    loaders:5回目    loss:0.011302977800369263
#    loaders:6回目    loss:0.00199518958106637
#    loaders:7回目    loss:0.007500234059989452
#    loaders:8回目    loss:0.13680458068847656
#    loaders:9回目    loss:0.011989003047347069
#    loaders:10回目    loss:0.007685155142098665
#    loaders:11回目    loss:0.025560803711414337
#    loaders:12回目    loss:0.0017317843157798052
#    loaders:13回目    loss:0.0010722047882154584
#    loaders:14回目    loss:0.017502184957265854
#    loaders:15回目    loss:0.0033740964718163013
#    loaders:16回目    loss:0.017743753269314766
#    loaders:17回目    loss:0.008430161513388157
#    loaders:18回目    loss:0.005577997304499149
#    loaders:19回目    loss:0.005800807382911444
#    loaders:20回目    loss:0.0812297984957695
#    loaders:21回目    loss:0.028708307072520256
#    loaders:22回目    loss:0.009698453359305859
#    loaders:23回目    loss:0.007652695290744305
#    loaders:24回目    loss:0.0036781381350010633
#    loaders:25回目    loss:0.011694217100739479
#    loaders:26回目    loss:0.06425261497497559
#    loaders:27回目    loss:0.0035758644808083773
#    loaders:28回目    loss:0.0053138118237257
#    loaders:29回目    loss:0.014379465952515602
#    loaders:30回目    loss:0.013044705614447594
#    loaders:31回目    loss:0.02755916304886341
#    loaders:32回目    loss:0.02076520211994648
#    loaders:33回目    loss:0.0249280147254467
#    loaders:34回目    loss:0.0142191331833601
#    loaders:35回目    loss:0.005119768436998129
#    loaders:36回目    loss:0.003948320169001818
#    loaders:37回目    loss:0.005811708979308605
#    loaders:38回目    loss:0.020595114678144455
#    loaders:39回目    loss:0.05778932571411133
#    loaders:40回目    loss:0.004593989346176386
#    loaders:41回目    loss:0.006720162928104401
#    loaders:42回目    loss:0.010565390810370445
#    loaders:43回目    loss:0.0012349506141617894
#    loaders:44回目    loss:0.002662194427102804
#    loaders:45回目    loss:0.006550284568220377
#    loaders:46回目    loss:0.007508607115596533
#    loaders:47回目    loss:0.027459971606731415
#    loaders:48回目    loss:0.003954810556024313
#    loaders:49回目    loss:0.007824670523405075
#    loaders:50回目    loss:0.003704950213432312
#    loaders:51回目    loss:0.018054930493235588
#    loaders:52回目    loss:0.012507762759923935
#    loaders:53回目    loss:0.006193841807544231
#    loaders:54回目    loss:0.027343865483999252
#    loaders:55回目    loss:0.008480846881866455
#    loaders:56回目    loss:0.003818136639893055
#    loaders:57回目    loss:0.0030593471601605415
#    loaders:58回目    loss:0.006637865677475929
#    loaders:59回目    loss:0.0034244582056999207
#    loaders:60回目    loss:0.01123378612101078
#    loaders:61回目    loss:0.021046869456768036
#    loaders:62回目    loss:0.02118825353682041
# EPOCH11回目 train Loss: 0.0159 Acc: 0.9878
# val:フェイズ
#    loaders:1回目    loss:0.13487420976161957
#    loaders:2回目    loss:0.12222147732973099
#    loaders:3回目    loss:0.020392246544361115
#    loaders:4回目    loss:0.1184711903333664
#    loaders:5回目    loss:0.059491679072380066
#    loaders:6回目    loss:0.10914618521928787
#    loaders:7回目    loss:0.13637639582157135
#    loaders:8回目    loss:0.2560690641403198
#    loaders:9回目    loss:0.12310311943292618
#    loaders:10回目    loss:0.1986536830663681
#    loaders:11回目    loss:0.1724904626607895
#    loaders:12回目    loss:0.11672399193048477
#    loaders:13回目    loss:0.19428569078445435
#    loaders:14回目    loss:0.026267237961292267
#    loaders:15回目    loss:0.22112447023391724
# EPOCH11回目 val Loss: 0.1286 Acc: 0.9240
# train:フェイズ
#    loaders:1回目    loss:0.0026803503278642893
#    loaders:2回目    loss:0.003424039576202631
#    loaders:3回目    loss:0.010519536212086678
#    loaders:4回目    loss:0.0025714687071740627
#    loaders:5回目    loss:0.005698694381862879
#    loaders:6回目    loss:0.0020911626052111387
#    loaders:7回目    loss:0.0013468930264934897
#    loaders:8回目    loss:0.004556338768452406
#    loaders:9回目    loss:0.024228505790233612
#    loaders:10回目    loss:0.017867321148514748
#    loaders:11回目    loss:0.0018176703015342355
#    loaders:12回目    loss:0.0043671648018062115
#    loaders:13回目    loss:0.01895100437104702
#    loaders:14回目    loss:0.0011639766162261367
#    loaders:15回目    loss:0.010226354002952576
#    loaders:16回目    loss:0.0032859717030078173
#    loaders:17回目    loss:0.02939794771373272
#    loaders:18回目    loss:0.001658909604884684
#    loaders:19回目    loss:0.0070613776333630085
#    loaders:20回目    loss:0.0017818022752180696
#    loaders:21回目    loss:0.002417386742308736
#    loaders:22回目    loss:0.016165170818567276
#    loaders:23回目    loss:0.009101088158786297
#    loaders:24回目    loss:0.011336557567119598
#    loaders:25回目    loss:0.0033459593541920185
#    loaders:26回目    loss:0.028883889317512512
#    loaders:27回目    loss:0.007073918357491493
#    loaders:28回目    loss:0.014977941289544106
#    loaders:29回目    loss:0.002482445677742362
#    loaders:30回目    loss:0.039950303733348846
#    loaders:31回目    loss:0.0024427471216768026
#    loaders:32回目    loss:0.0019018573220819235
#    loaders:33回目    loss:0.016061585396528244
#    loaders:34回目    loss:0.005740673281252384
#    loaders:35回目    loss:0.006800954230129719
#    loaders:36回目    loss:0.04999041557312012
#    loaders:37回目    loss:0.0023881166707724333
#    loaders:38回目    loss:0.010847802273929119
#    loaders:39回目    loss:0.005065624136477709
#    loaders:40回目    loss:0.0046017710119485855
#    loaders:41回目    loss:0.001468757400289178
#    loaders:42回目    loss:0.005335284862667322
#    loaders:43回目    loss:0.002703303936868906
#    loaders:44回目    loss:0.0034776106476783752
#    loaders:45回目    loss:0.014732420444488525
#    loaders:46回目    loss:0.0009463194292038679
#    loaders:47回目    loss:0.002978021977469325
#    loaders:48回目    loss:0.0012213134905323386
#    loaders:49回目    loss:0.00443195179104805
#    loaders:50回目    loss:0.006223175674676895
#    loaders:51回目    loss:0.01578257419168949
#    loaders:52回目    loss:0.014605075120925903
#    loaders:53回目    loss:0.0033904057927429676
#    loaders:54回目    loss:0.036888085305690765
#    loaders:55回目    loss:0.0037166140973567963
#    loaders:56回目    loss:0.0016969498246908188
#    loaders:57回目    loss:0.0009996654698625207
#    loaders:58回目    loss:0.001791677437722683
#    loaders:59回目    loss:0.01218088623136282
#    loaders:60回目    loss:0.0025006872601807117
#    loaders:61回目    loss:0.018165219575166702
#    loaders:62回目    loss:0.003195982426404953
# EPOCH12回目 train Loss: 0.0089 Acc: 0.9895
# val:フェイズ
#    loaders:1回目    loss:0.14291313290596008
#    loaders:2回目    loss:0.08634542673826218
#    loaders:3回目    loss:0.016693009063601494
#    loaders:4回目    loss:0.10802004486322403
#    loaders:5回目    loss:0.14261412620544434
#    loaders:6回目    loss:0.38162460923194885
#    loaders:7回目    loss:0.07903255522251129
#    loaders:8回目    loss:0.2761642634868622
#    loaders:9回目    loss:0.09030111879110336
#    loaders:10回目    loss:0.13776879012584686
#    loaders:11回目    loss:0.0702001303434372
#    loaders:12回目    loss:0.08204484730958939
#    loaders:13回目    loss:0.2226387858390808
#    loaders:14回目    loss:0.011370861902832985
#    loaders:15回目    loss:0.2589840292930603
# EPOCH12回目 val Loss: 0.1348 Acc: 0.9300
# Save File original_model_12.pth
# train:フェイズ
#    loaders:1回目    loss:0.02193545550107956
#    loaders:2回目    loss:0.004908776842057705
#    loaders:3回目    loss:0.0008825086406432092
#    loaders:4回目    loss:0.00697347754612565
#    loaders:5回目    loss:0.0018855443922802806
#    loaders:6回目    loss:0.009923706762492657
#    loaders:7回目    loss:0.010354381985962391
#    loaders:8回目    loss:0.0016867206431925297
#    loaders:9回目    loss:0.0029568278696388006
#    loaders:10回目    loss:0.01657690294086933
#    loaders:11回目    loss:0.003355263266712427
#    loaders:12回目    loss:0.0009188521653413773
#    loaders:13回目    loss:0.002658241894096136
#    loaders:14回目    loss:0.00533966114744544
#    loaders:15回目    loss:0.008379977196455002
#    loaders:16回目    loss:0.0025565167888998985
#    loaders:17回目    loss:0.0009317173971794546
#    loaders:18回目    loss:0.0033680193591862917
#    loaders:19回目    loss:0.04242328926920891
#    loaders:20回目    loss:0.0029926293063908815
#    loaders:21回目    loss:0.005873032379895449
#    loaders:22回目    loss:0.0027019805274903774
#    loaders:23回目    loss:0.01751042902469635
#    loaders:24回目    loss:0.05645507946610451
#    loaders:25回目    loss:0.0010166160063818097
#    loaders:26回目    loss:0.0025060486514121294
#    loaders:27回目    loss:0.014667551033198833
#    loaders:28回目    loss:0.007041011471301317
#    loaders:29回目    loss:0.0035301821772009134
#    loaders:30回目    loss:0.0037151058204472065
#    loaders:31回目    loss:0.011595023795962334
#    loaders:32回目    loss:0.003285336773842573
#    loaders:33回目    loss:0.002594585297629237
#    loaders:34回目    loss:0.0012454435927793384
#    loaders:35回目    loss:0.006348285358399153
#    loaders:36回目    loss:0.006829121150076389
#    loaders:37回目    loss:0.009782223030924797
#    loaders:38回目    loss:0.00492551876232028
#    loaders:39回目    loss:0.006845416035503149
#    loaders:40回目    loss:0.00495506264269352
#    loaders:41回目    loss:0.007842588238418102
#    loaders:42回目    loss:0.008623171597719193
#    loaders:43回目    loss:0.00583296874538064
# ...
#    loaders:52回目    loss:0.0024740295484662056
#    loaders:53回目    loss:0.0090580889955163
#    loaders:54回目    loss:0.0006907249917276204
#    loaders:55回目    loss:0.0010751060908660293
#    loaders:56回目    loss:0.0005325059755705297
#    loaders:57回目    loss:0.0017287704395130277
#    loaders:58回目    loss:0.0007309468928724527
#    loaders:59回目    loss:0.012609584257006645
#    loaders:60回目    loss:0.0015258521307259798
#    loaders:61回目    loss:0.0014410000294446945
#    loaders:62回目    loss:0.0059505789540708065
# EPOCH20回目 train Loss: 0.0022 Acc: 0.9915
# val:フェイズ
#    loaders:1回目    loss:0.1261100023984909
#    loaders:2回目    loss:0.09030458331108093
#    loaders:3回目    loss:0.004161296412348747
#    loaders:4回目    loss:0.1074749156832695
#    loaders:5回目    loss:0.15482646226882935
#    loaders:6回目    loss:0.20988939702510834
#    loaders:7回目    loss:0.048658955842256546
#    loaders:8回目    loss:0.20613759756088257
#    loaders:9回目    loss:0.05061277374625206
#    loaders:10回目    loss:0.15414729714393616
#    loaders:11回目    loss:0.13958576321601868
#    loaders:12回目    loss:0.12187586724758148
#    loaders:13回目    loss:0.2012900859117508
#    loaders:14回目    loss:0.002833984326571226
#    loaders:15回目    loss:0.21441824734210968
# EPOCH20回目 val Loss: 0.1173 Acc: 0.9330
# Save File original_model_20.pth
# train:フェイズ
#    loaders:1回目    loss:0.0010972714517265558
#    loaders:2回目    loss:0.00343983038328588
#    loaders:3回目    loss:0.0007699038251303136
#    loaders:4回目    loss:0.0004845397488679737
#    loaders:5回目    loss:0.0014111804775893688
#    loaders:6回目    loss:0.0004791138635482639
#    loaders:7回目    loss:0.0009143112692981958
#    loaders:8回目    loss:0.0006772025371901691
#    loaders:9回目    loss:0.001753751770593226
#    loaders:10回目    loss:0.0005947630852460861
#    loaders:11回目    loss:0.0018353568157181144
#    loaders:12回目    loss:0.001044105738401413
#    loaders:13回目    loss:0.0009732075850479305
#    loaders:14回目    loss:0.0005370804574340582
#    loaders:15回目    loss:0.0025815716944634914
#    loaders:16回目    loss:0.0012422800064086914
#    loaders:17回目    loss:0.0014607049524784088
#    loaders:18回目    loss:0.00037298878305591643
#    loaders:19回目    loss:0.0021783881820738316
#    loaders:20回目    loss:0.0011814996832981706
#    loaders:21回目    loss:0.0007810533279553056
#    loaders:22回目    loss:0.0006479661678895354
#    loaders:23回目    loss:0.001888565137051046
#    loaders:24回目    loss:0.0005690393154509366
#    loaders:25回目    loss:0.0012866210890933871
#    loaders:26回目    loss:0.0015482805902138352
#    loaders:27回目    loss:0.0010039019398391247
#    loaders:28回目    loss:0.0010713802184909582
#    loaders:29回目    loss:0.0020872533787041903
#    loaders:30回目    loss:0.01695002056658268
#    loaders:31回目    loss:0.00593554088845849
#    loaders:32回目    loss:0.0006917439168319106
#    loaders:33回目    loss:0.0017336721066385508
#    loaders:34回目    loss:0.0009166565723717213
#    loaders:35回目    loss:0.0007326444610953331
#    loaders:36回目    loss:0.0030267583206295967
#    loaders:37回目    loss:0.000908060756046325
#    loaders:38回目    loss:0.0005434293998405337
#    loaders:39回目    loss:0.007475292310118675
#    loaders:40回目    loss:0.0023924168199300766
#    loaders:41回目    loss:0.0014941963599994779
#    loaders:42回目    loss:0.000349808280589059
#    loaders:43回目    loss:0.0035460758954286575
#    loaders:44回目    loss:0.0008614067337475717
#    loaders:45回目    loss:0.00035906885750591755
#    loaders:46回目    loss:0.00022534970776177943
#    loaders:47回目    loss:0.0021264911629259586
#    loaders:48回目    loss:0.0032238822896033525
#    loaders:49回目    loss:0.0052390010096132755
#    loaders:50回目    loss:0.0005119400448165834
#    loaders:51回目    loss:0.0006836024112999439
#    loaders:52回目    loss:0.0038022079970687628
#    loaders:53回目    loss:0.0005789404967799783
#    loaders:54回目    loss:0.0006237970665097237
#    loaders:55回目    loss:0.0014146050671115518
#    loaders:56回目    loss:0.0007189501775428653
#    loaders:57回目    loss:0.0005995177780278027
#    loaders:58回目    loss:0.0010158997029066086
#    loaders:59回目    loss:0.002786249155178666
#    loaders:60回目    loss:0.0019614011980593204
#    loaders:61回目    loss:0.00031199236400425434
#    loaders:62回目    loss:0.0009871611837297678
# EPOCH21回目 train Loss: 0.0018 Acc: 0.9918
# val:フェイズ
#    loaders:1回目    loss:0.13952234387397766
#    loaders:2回目    loss:0.102238729596138
#    loaders:3回目    loss:0.001975185703486204
#    loaders:4回目    loss:0.11500316858291626
#    loaders:5回目    loss:0.14315466582775116
#    loaders:6回目    loss:0.2216520756483078
#    loaders:7回目    loss:0.040944408625364304
#    loaders:8回目    loss:0.23854857683181763
#    loaders:9回目    loss:0.04658607020974159
#    loaders:10回目    loss:0.15596286952495575
#    loaders:11回目    loss:0.10640978813171387
#    loaders:12回目    loss:0.09105625003576279
#    loaders:13回目    loss:0.1910325437784195
#    loaders:14回目    loss:0.0033483884762972593
#    loaders:15回目    loss:0.19680863618850708
# EPOCH21回目 val Loss: 0.1148 Acc: 0.9290
# train:フェイズ
#    loaders:1回目    loss:0.007953100837767124
#    loaders:2回目    loss:0.0010595718631520867
#    loaders:3回目    loss:0.0005781338550150394
#    loaders:4回目    loss:0.001400717068463564
#    loaders:5回目    loss:0.0009310501045547426
#    loaders:6回目    loss:0.0006917858845554292
#    loaders:7回目    loss:0.03206322714686394
#    loaders:8回目    loss:0.00160883623175323
#    loaders:9回目    loss:0.002310573821887374
#    loaders:10回目    loss:0.00048254604917019606
#    loaders:11回目    loss:0.0008212759857997298
#    loaders:12回目    loss:0.0008732951828278601
#    loaders:13回目    loss:0.0010668000904843211
#    loaders:14回目    loss:0.0013172222534194589
#    loaders:15回目    loss:0.000698912306688726
#    loaders:16回目    loss:0.0009048956562764943
#    loaders:17回目    loss:0.00034059377503581345
#    loaders:18回目    loss:0.0006400026613846421
#    loaders:19回目    loss:0.0003183280350640416
#    loaders:20回目    loss:0.0052229296416044235
#    loaders:21回目    loss:0.001285060541704297
#    loaders:22回目    loss:0.0021690845023840666
#    loaders:23回目    loss:0.00040007030474953353
#    loaders:24回目    loss:0.0007420034380629659
#    loaders:25回目    loss:0.0034630694426596165
#    loaders:26回目    loss:0.002697709947824478
#    loaders:27回目    loss:0.008021455258131027
#    loaders:28回目    loss:0.0007950611179694533
#    loaders:29回目    loss:0.0019075829768553376
#    loaders:30回目    loss:0.00039715031743980944
#    loaders:31回目    loss:0.0007243484142236412
#    loaders:32回目    loss:0.0005612564273178577
#    loaders:33回目    loss:0.005155310500413179
#    loaders:34回目    loss:0.0006874469108879566
#    loaders:35回目    loss:0.0008358385530300438
#    loaders:36回目    loss:0.0017883812543004751
#    loaders:37回目    loss:0.0007463149959221482
#    loaders:38回目    loss:0.0009282449609600008
#    loaders:39回目    loss:0.0008172725792974234
#    loaders:40回目    loss:0.00045197014696896076
#    loaders:41回目    loss:0.0017507203156128526
#    loaders:42回目    loss:0.000305086316075176
#    loaders:43回目    loss:0.001248143962584436
#    loaders:44回目    loss:0.005235788878053427
#    loaders:45回目    loss:0.0006451532826758921
#    loaders:46回目    loss:0.017104586586356163
#    loaders:47回目    loss:0.0007861513877287507
#    loaders:48回目    loss:0.0008716877782717347
#    loaders:49回目    loss:0.0018461609724909067
#    loaders:50回目    loss:0.0013484652154147625
#    loaders:51回目    loss:0.005174694117158651
#    loaders:52回目    loss:0.0006247447454370558
#    loaders:53回目    loss:0.008959155529737473
#    loaders:54回目    loss:0.0008112170617096126
#    loaders:55回目    loss:0.00014436898345593363
#    loaders:56回目    loss:0.002005184767767787
#    loaders:57回目    loss:0.0006576154264621437
#    loaders:58回目    loss:0.0006001756992191076
#    loaders:59回目    loss:0.005667542573064566
#    loaders:60回目    loss:0.0025897694285959005
#    loaders:61回目    loss:0.00022977193293627352
#    loaders:62回目    loss:0.014050567522644997
# EPOCH22回目 train Loss: 0.0027 Acc: 0.9913
# val:フェイズ
#    loaders:1回目    loss:0.1226741373538971
#    loaders:2回目    loss:0.11513017117977142
#    loaders:3回目    loss:0.0026615008246153593
#    loaders:4回目    loss:0.11897929757833481
#    loaders:5回目    loss:0.17568054795265198
#    loaders:6回目    loss:0.22128750383853912
#    loaders:7回目    loss:0.010923977941274643
#    loaders:8回目    loss:0.21261590719223022
#    loaders:9回目    loss:0.06256934255361557
#    loaders:10回目    loss:0.1882857382297516
#    loaders:11回目    loss:0.13673697412014008
#    loaders:12回目    loss:0.11361841857433319
#    loaders:13回目    loss:0.13069678843021393
#    loaders:14回目    loss:0.0024029300548136234
#    loaders:15回目    loss:0.21678906679153442
# EPOCH22回目 val Loss: 0.1172 Acc: 0.9290
# train:フェイズ
#    loaders:1回目    loss:0.0013047464890405536
#    loaders:2回目    loss:0.0008222325122915208
#    loaders:3回目    loss:0.0013619556557387114
#    loaders:4回目    loss:0.0008475573267787695
#    loaders:5回目    loss:0.0010552372550591826
#    loaders:6回目    loss:0.001617350266315043
#    loaders:7回目    loss:0.0003486719506327063
#    loaders:8回目    loss:0.0022596693597733974
#    loaders:9回目    loss:0.00047575170174241066
#    loaders:10回目    loss:0.0021331137977540493
#    loaders:11回目    loss:0.0021892643999308348
#    loaders:12回目    loss:0.002951116766780615
#    loaders:13回目    loss:0.0007013208814896643
#    loaders:14回目    loss:0.0005415869527496397
#    loaders:15回目    loss:0.0009424464078620076
#    loaders:16回目    loss:0.002376403659582138
#    loaders:17回目    loss:0.0029641776345670223
#    loaders:18回目    loss:0.0005590677028521895
#    loaders:19回目    loss:0.0013757869601249695
#    loaders:20回目    loss:0.0008725105435587466
#    loaders:21回目    loss:0.0006215812754817307
#    loaders:22回目    loss:0.0009886202169582248
#    loaders:23回目    loss:0.004790467210114002
#    loaders:24回目    loss:0.022688843309879303
#    loaders:25回目    loss:0.0019737081602215767
#    loaders:26回目    loss:0.0010172307956963778
#    loaders:27回目    loss:0.00051922193961218
#    loaders:28回目    loss:0.00037203976535238326
#    loaders:29回目    loss:0.0011160420253872871
#    loaders:30回目    loss:0.0006232043961063027
#    loaders:31回目    loss:0.0005836610216647387
#    loaders:32回目    loss:0.0008223247714340687
#    loaders:33回目    loss:0.006014659535139799
#    loaders:34回目    loss:0.003001815639436245
#    loaders:35回目    loss:0.0008140647551044822
#    loaders:36回目    loss:0.00800577737390995
#    loaders:37回目    loss:0.0004246274766046554
#    loaders:38回目    loss:0.0005151134100742638
#    loaders:39回目    loss:0.005087523255497217
#    loaders:40回目    loss:0.0007170430617406964
#    loaders:41回目    loss:0.0038876566104590893
#    loaders:42回目    loss:0.0012824113946408033
#    loaders:43回目    loss:0.0038646392058581114
#    loaders:44回目    loss:0.0009488915675319731
#    loaders:45回目    loss:0.01650204323232174
#    loaders:46回目    loss:0.0029149458277970552
#    loaders:47回目    loss:0.008600541390478611
#    loaders:48回目    loss:0.0022368086501955986
#    loaders:49回目    loss:0.00069037004141137
#    loaders:50回目    loss:0.001997103216126561
#    loaders:51回目    loss:0.0020301423501223326
#    loaders:52回目    loss:0.006277719046920538
#    loaders:53回目    loss:0.0014631899539381266
#    loaders:54回目    loss:0.00042378369835205376
#    loaders:55回目    loss:0.006081815343350172
#    loaders:56回目    loss:0.008049439638853073
#    loaders:57回目    loss:0.0019799722358584404
#    loaders:58回目    loss:0.002411901019513607
#    loaders:59回目    loss:0.0006534772692248225
#    loaders:60回目    loss:0.0011719833128154278
#    loaders:61回目    loss:0.0009553755517117679
#    loaders:62回目    loss:0.0006609659176319838
# EPOCH23回目 train Loss: 0.0026 Acc: 0.9918
# val:フェイズ
#    loaders:1回目    loss:0.1535162776708603
#    loaders:2回目    loss:0.07874001562595367
#    loaders:3回目    loss:0.005941088777035475
#    loaders:4回目    loss:0.11710795015096664
#    loaders:5回目    loss:0.2594938576221466
#    loaders:6回目    loss:0.2720789909362793
#    loaders:7回目    loss:0.05043609440326691
#    loaders:8回目    loss:0.24496597051620483
#    loaders:9回目    loss:0.010187703184783459
#    loaders:10回目    loss:0.20286181569099426
#    loaders:11回目    loss:0.21892839670181274
#    loaders:12回目    loss:0.20323702692985535
#    loaders:13回目    loss:0.13522301614284515
#    loaders:14回目    loss:0.0017559609841555357
#    loaders:15回目    loss:0.3275846242904663
# EPOCH23回目 val Loss: 0.1461 Acc: 0.9260
# train:フェイズ
#    loaders:1回目    loss:0.0007866091327741742
#    loaders:2回目    loss:0.020085103809833527
#    loaders:3回目    loss:0.0003427276969887316
#    loaders:4回目    loss:0.02306261658668518
#    loaders:5回目    loss:0.0015098819276317954
#    loaders:6回目    loss:0.007268471643328667
#    loaders:7回目    loss:0.004308740142732859
#    loaders:8回目    loss:0.003074557986110449
#    loaders:9回目    loss:0.0010383639018982649
#    loaders:10回目    loss:0.002631485927850008
#    loaders:11回目    loss:0.0012167948298156261
#    loaders:12回目    loss:0.0017272725235670805
#    loaders:13回目    loss:0.0009285648120567203
#    loaders:14回目    loss:0.0012941526947543025
#    loaders:15回目    loss:0.0005189438816159964
#    loaders:16回目    loss:0.020581431686878204
#    loaders:17回目    loss:0.034270063042640686
#    loaders:18回目    loss:0.0024676185566931963
#    loaders:19回目    loss:0.0020175965037196875
#    loaders:20回目    loss:0.002348282840102911
#    loaders:21回目    loss:0.0003849893109872937
#    loaders:22回目    loss:0.0038654268719255924
#    loaders:23回目    loss:0.0005613334942609072
#    loaders:24回目    loss:0.001355802291072905
#    loaders:25回目    loss:0.004040077794343233
#    loaders:26回目    loss:0.0004131791938561946
#    loaders:27回目    loss:0.0007509160786867142
#    loaders:28回目    loss:0.0005189202493056655
#    loaders:29回目    loss:0.0005255821160972118
#    loaders:30回目    loss:0.00038597092498093843
#    loaders:31回目    loss:0.0038994839414954185
#    loaders:32回目    loss:0.0017000864027068019
#    loaders:33回目    loss:0.0020155743695795536
#    loaders:34回目    loss:0.0006605704547837377
#    loaders:35回目    loss:0.0010709756752476096
#    loaders:36回目    loss:0.00031512422719970345
#    loaders:37回目    loss:0.001395104918628931
#    loaders:38回目    loss:0.001613615546375513
#    loaders:39回目    loss:0.002503246534615755
#    loaders:40回目    loss:0.00368276028893888
#    loaders:41回目    loss:0.0013999065849930048
#    loaders:42回目    loss:0.0007958199712447822
#    loaders:43回目    loss:0.007675603032112122
#    loaders:44回目    loss:0.0005108306650072336
#    loaders:45回目    loss:0.004710407927632332
#    loaders:46回目    loss:0.0014373717131093144
#    loaders:47回目    loss:0.0005705927032977343
#    loaders:48回目    loss:0.00044652275391854346
#    loaders:49回目    loss:0.0007530819275416434
#    loaders:50回目    loss:0.0005213841795921326
#    loaders:51回目    loss:0.003214373253285885
#    loaders:52回目    loss:0.003287896979600191
#    loaders:53回目    loss:0.0008267536759376526
#    loaders:54回目    loss:0.001409277319908142
#    loaders:55回目    loss:0.0010927075054496527
#    loaders:56回目    loss:0.0012151339324191213
#    loaders:57回目    loss:0.000559711130335927
#    loaders:58回目    loss:0.0021984109189361334
#    loaders:59回目    loss:0.00030740289366804063
#    loaders:60回目    loss:0.00025378618738614023
#    loaders:61回目    loss:0.00021328439470380545
#    loaders:62回目    loss:0.000249080709181726
# EPOCH24回目 train Loss: 0.0031 Acc: 0.9910
# val:フェイズ
#    loaders:1回目    loss:0.22303101420402527
#    loaders:2回目    loss:0.12874078750610352
#    loaders:3回目    loss:0.016343792900443077
#    loaders:4回目    loss:0.13712178170681
#    loaders:5回目    loss:0.28298816084861755
#    loaders:6回目    loss:0.23689912259578705
#    loaders:7回目    loss:0.022927409037947655
#    loaders:8回目    loss:0.23315340280532837
#    loaders:9回目    loss:0.02383504807949066
#    loaders:10回目    loss:0.19747355580329895
#    loaders:11回目    loss:0.14760981500148773
#    loaders:12回目    loss:0.0908757895231247
#    loaders:13回目    loss:0.16238439083099365
#    loaders:14回目    loss:0.0012703490210697055
#    loaders:15回目    loss:0.3323161005973816
# EPOCH24回目 val Loss: 0.1432 Acc: 0.9310
# Best val Acc: 0.933000
# [0.7515  0.932   0.95175 0.9755  0.978   0.984   0.986   0.98475 0.98375
#  0.985   0.98775 0.98775 0.9895  0.99075 0.99125 0.9915  0.99075 0.9915
#  0.992   0.992   0.9915  0.99175 0.99125 0.99175 0.991  ]
# [0.899 0.889 0.918 0.903 0.928 0.915 0.913 0.918 0.911 0.923 0.922 0.924
#  0.93  0.926 0.927 0.925 0.922 0.926 0.928 0.926 0.933 0.929 0.929 0.926
#  0.931]

# %%
#
# pth配下の不要なファイルを削除し、Bestモデルのみリネーム行うコード
# by 大木さん

import os
import re
from datetime import datetime

# 対象のディレクトリパス
directory_path = 'drive/MyDrive/2024_AIContest2/Thema1/pth'

# ファイル名のパターン
file_pattern = r"original_model_(\d+)\.pth"

# 現在の日付と時間を取得 (yyyymmdd_hhmm)
current_time = datetime.now().strftime("%Y%m%d_%H%M")

# 最大のXXを持つファイルを特定
max_number = -1
file_to_keep = None

# ディレクトリ内のファイルを走査
for file_name in os.listdir(directory_path):
    file_path = os.path.join(directory_path, file_name)

    # 正規表現でファイル名が "original_model_XX.pth" 形式かチェック
    match = re.match(file_pattern, file_name)
    if match:
        number = int(match.group(1))  # XX部分を取得
        if number > max_number:
            max_number = number
            file_to_keep = file_name

# 最も大きい数字を持つファイルに接頭辞を付けてリネーム
if file_to_keep:
    new_file_name = f"{current_time}_{file_to_keep}"
    new_file_path = os.path.join(directory_path, new_file_name)
    os.rename(os.path.join(directory_path, file_to_keep), new_file_path)
    print(f"{file_to_keep} は {new_file_name} にリネームされました。")

# ディレクトリ内のファイルを再度走査して、不要なファイルを削除
for file_name in os.listdir(directory_path):
    file_path = os.path.join(directory_path, file_name)

    # "original_model_XX.pth" 形式のファイルを削除
    match = re.match(file_pattern, file_name)
    if match and file_name != new_file_name:
        try:
            os.remove(file_path)
            print(f"{file_path} は削除されました。")
        except FileNotFoundError:
            print(f"{file_path} は見つかりませんでした。")
        except PermissionError:
            print(f"{file_path} の削除に必要な権限がありません。")
        except Exception as e:
            print(f"{file_path} の削除中にエラーが発生しました: {e}")
# Out:
# original_model_20.pth は 20250407_1435_original_model_20.pth にリネームされました。
# drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_0.pth は削除されました。
# drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_2.pth は削除されました。
# drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_4.pth は削除されました。
# drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_12.pth は削除されました。

# %%
#学習したモデルを使ってtestデータの推論を実施
import pandas as pd
import os
import zipfile
import torch
import torch.nn as nn
import torch.optim as optim
import albumentations
from torch.utils.data import Dataset
from torchvision import datasets, models, transforms
from PIL import Image, ImageFilter

work_dir           = '/content/sample_data'
save_dir           = '/content/drive/MyDrive/2024_AIContest2/Thema1/'
test_zip_file_path = '/content/sample_data/test_images.zip'
test_file_dir      = os.path.join(work_dir, 'test_images')
report_format_tsv  = os.path.join(work_dir, 'sample_submit.tsv')
best_model_path    = os.path.join(save_dir, 'pth/20250407_1435_original_model_20.pth')
output_file        = os.path.join(save_dir, 'output/20250407_out_submit_4.tsv')

TARGET_NUM = 10

# ZIPファイルを解凍する
def extract_zip(zip_file_path, extract_to):

    if not os.path.exists(test_file_dir):
        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            zip_ref.extractall(extract_to)

extract_zip(test_zip_file_path, work_dir)

#dataサイズ定義
dataset_sizes= {
    'train':len(image_datasets['train']),
    'val':len(image_datasets['val'])
}

#submit用dataset定義
class For_Submission_Datasets(Dataset):

    def __init__(self, data_transform):
        self.df = pd.read_csv(report_format_tsv ,sep='\t',names=['filename','target'])
        self.data_transform = data_transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):
        file = self.df['filename'][index]
        image = Image.open(test_file_dir +'/'+ file)
        image = self.data_transform(image)

        return image,file

#submit用dataset作成
subdataset = For_Submission_Datasets(data_transform=data_transforms['val'])

#submit用dataloaders作成
subdataloader = torch.utils.data.DataLoader(subdataset, batch_size=1, shuffle=False, num_workers=0, drop_last=True)

#精度の最も高いモデルをロード
#モデルの名前を適宜変更して、最も精度の高いモデルをロードしましょう
best_model = get_model(target_num = TARGET_NUM)
best_model.load_state_dict(torch.load(best_model_path, map_location=lambda storage, loc: storage), strict=True)

submit = pd.read_csv(report_format_tsv,sep='\t', header=None)
#print(submit)
#テストデータに対しての推論
pred = []
for i,(inputs, labels) in enumerate(subdataloader):
    inputs = inputs.to(DEVICE)
    best_model.eval()
    outputs = best_model(inputs)
    _, preds = torch.max(outputs, 1)
    pred.append(preds.item())

df_test = pd.read_csv(report_format_tsv ,sep='\t',names=['filename','target'])

df_test['pred'] = pred
#print(df_test)
submit[1] = pred

submit.to_csv(output_file ,sep='\t', index=False, header=False)
print(submit)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#                   0  1
# 0        test_0.jpg  6
# 1        test_1.jpg  7
# 2        test_2.jpg  5
# 3        test_3.jpg  0
# 4        test_4.jpg  3
# ...             ... ..
# 7995  test_7995.jpg  9
# 7996  test_7996.jpg  6
# 7997  test_7997.jpg  8
# 7998  test_7998.jpg  8
# 7999  test_7999.jpg  8
#
# [8000 rows x 2 columns]

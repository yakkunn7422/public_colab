# %% [markdown]
# <a href="https://colab.research.google.com/github/yakkunn7422/public_colab/blob/main/2024_AIC2_thema1_main7_resnet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Googleドライブのマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -fr /content/sample_data/new_train_images
# !rm -fr /content/sample_data/test_images.zip
# !rm -fr /content/sample_data/train_images.zip
# !rm -fr /content/sample_data/train_master.tsv
# !rm -fr /content/sample_data/sample_submit.tsv
# !rm -fr /content/sample_data/resnet18-5c106cde.pth
# !rm -fr /content/sample_data/resnet50-19c8e357.pth
# !rm -fr /content/sample_data/label_master.tsv

# %%
#
# pth配下の不要なファイルを削除し、Bestモデルのみリネーム行うコード
# by 大木さん

import os
import re
from datetime import datetime

# 対象のディレクトリパス
directory_path = 'drive/MyDrive/2024_AIContest2/Thema1/pth'

# ファイル名のパターン
file_pattern = r"original_model_(\d+)\.pth"

# 現在の日付と時間を取得 (yyyymmdd_hhmm)
current_time = datetime.now().strftime("%Y%m%d_%H%M")

# 最大のXXを持つファイルを特定
max_number = -1
file_to_keep = None

# ディレクトリ内のファイルを走査
for file_name in os.listdir(directory_path):
    file_path = os.path.join(directory_path, file_name)

    # 正規表現でファイル名が "original_model_XX.pth" 形式かチェック
    match = re.match(file_pattern, file_name)
    if match:
        number = int(match.group(1))  # XX部分を取得
        if number > max_number:
            max_number = number
            file_to_keep = file_name

# 最も大きい数字を持つファイルに接頭辞を付けてリネーム
if file_to_keep:
    new_file_name = f"{current_time}_{file_to_keep}"
    new_file_path = os.path.join(directory_path, new_file_name)
    os.rename(os.path.join(directory_path, file_to_keep), new_file_path)
    print(f"{file_to_keep} は {new_file_name} にリネームされました。")

# ディレクトリ内のファイルを再度走査して、不要なファイルを削除
for file_name in os.listdir(directory_path):
    file_path = os.path.join(directory_path, file_name)

    # "original_model_XX.pth" 形式のファイルを削除
    match = re.match(file_pattern, file_name)
    if match and file_name != new_file_name:
        try:
            os.remove(file_path)
            print(f"{file_path} は削除されました。")
        except FileNotFoundError:
            print(f"{file_path} は見つかりませんでした。")
        except PermissionError:
            print(f"{file_path} の削除に必要な権限がありません。")
        except Exception as e:
            print(f"{file_path} の削除中にエラーが発生しました: {e}")
# Out:
# original_model_14.pth は 20250404_0005_original_model_14.pth にリネームされました。
# drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_0.pth は削除されました。
# drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_1.pth は削除されました。
# drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_2.pth は削除されました。
# drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_3.pth は削除されました。
# drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_6.pth は削除されました。
# drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_7.pth は削除されました。
# drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_10.pth は削除されました。
# drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_12.pth は削除されました。

# %%
import os
print("カレントワーキングディレクトリは[" + os.getcwd() + "]です")
# Out:
# カレントワーキングディレクトリは[/content]です

# %%
pip install albumentations
# Out:
# Collecting albumentations
#   Downloading albumentations-2.0.5-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.11/dist-packages (from albumentations) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from albumentations) (1.14.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from albumentations) (2.11.1)
# Collecting albucore==0.0.23 (from albumentations)
#   Downloading albucore-0.0.23-py3-none-any.whl.metadata (5.3 kB)
# Collecting opencv-python-headless>=4.9.0.80 (from albumentations)
#   Downloading opencv_python_headless-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting stringzilla>=3.10.4 (from albucore==0.0.23->albumentations)
#   Downloading stringzilla-3.12.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl.metadata (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 3.2 MB/s eta 0:00:00
# Collecting simsimd>=5.9.2 (from albucore==0.0.23->albumentations)
#   Downloading simsimd-6.2.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (2.33.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (4.13.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (0.4.0)
# Downloading albumentations-2.0.5-py3-none-any.whl (290 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.6/290.6 kB 10.2 MB/s eta 0:00:00
# Downloading albucore-0.0.23-py3-none-any.whl (14 kB)
# Downloading opencv_python_headless-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (50.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 MB 24.0 MB/s eta 0:00:00
# Downloading simsimd-6.2.1-cp311-cp311-manylinux_2_28_x86_64.whl (632 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 632.7/632.7 kB 22.9 MB/s eta 0:00:00
# Downloading stringzilla-3.12.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.6/307.6 kB 22.1 MB/s eta 0:00:00
# Installing collected packages: stringzilla, simsimd, opencv-python-headless, albucore, albumentations
# Successfully installed albucore-0.0.23 albumentations-2.0.5 opencv-python-headless-4.11.0.86 simsimd-6.2.1 stringzilla-3.12.3

# %%
# sample_data 配下にResnet18使う際のデータ一式を持ってくるコード

import os
import pandas as pd
import zipfile
import shutil
import numpy as np

#パラメータ
TRAIN_RATIO = 0.8



#trainイメージファイル、testイメージファイル等のファイル格納先
input_dir = '/content/drive/MyDrive/2024_AIContest2/Thema1'
work_dir =  '/content/sample_data'

#trainデータの解凍・成形先のディレクトリ
output_dir = os.path.join(work_dir, 'new_train_images')

#trainデータファイル名
zip_file_path = os.path.join(work_dir, 'train_images.zip')
#trainデータのラベルまとめファイル名
tsv_file_path = os.path.join(work_dir, 'train_master.tsv')

# ファイルをCOPYする
def simple_copy_files(src_dir, dst_dir):
    os.makedirs(dst_dir, exist_ok=True)  # コピー先ディレクトリを作成（既に存在する場合は何もしない）

    for file_name in os.listdir(src_dir):
        full_file_name = os.path.join(src_dir, file_name)
        if os.path.isfile(full_file_name):
            shutil.copy2(full_file_name, dst_dir)  # ファイルのコピー

# トレインとバリデーション用のディレクトリおよびその中のラベルごとのサブディレクトリを作成する
def create_directories(base_dir, labels):

    train_dir = os.path.join(base_dir, 'train')
    val_dir = os.path.join(base_dir, 'val')

    for dir_path in [train_dir, val_dir]:
        if not os.path.exists(dir_path):
            os.makedirs(dir_path)

    for label in labels:
        os.makedirs(os.path.join(train_dir, str(label)), exist_ok=True)
        os.makedirs(os.path.join(val_dir, str(label)), exist_ok=True)

    return train_dir, val_dir

# ZIPファイルを解凍する
def extract_zip(zip_file_path, extract_to):

    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)

# TSVファイルを読み込み、1行目を削除してデータフレームを準備する
def load_and_prepare_data(tsv_file_path):

    df = pd.read_csv(tsv_file_path, sep='\t', names=['filename', 'label_id'])
    df = df.iloc[1:].reset_index(drop=True)

    return df

# 画像ファイルをディレクトリに分配する
def distribute_images(df, image_dir, train_dir, val_dir, train_ratio=0.8):

    for label in df['label_id'].unique():
        label_images = df[df['label_id'] == label]['filename'].tolist()
        # シャッフルして分割

        np.random.shuffle(label_images)
        train_size = int(len(label_images) * train_ratio)
        train_images = label_images[:train_size]
        val_images = label_images[train_size:]

        for image_name in train_images:
            src_path = os.path.join(image_dir, image_name)
            dst_path = os.path.join(train_dir, str(label), image_name)
            shutil.copy(src_path, dst_path)

        for image_name in val_images:
            src_path = os.path.join(image_dir, image_name)
            dst_path = os.path.join(val_dir, str(label), image_name)
            shutil.copy(src_path, dst_path)

# ディレクトリ内のアイテムを探索し数を表示する
def count_files_recursive(directory):
    total_files = 0

    for root, dirs, files in os.walk(directory):
        files_count = len(files)
        subdir_relative = os.path.relpath(root, directory)
        print(f"Directory '{subdir_relative}' contains {files_count} files.")

        total_files += files_count

    print(f"Total files in '{directory}': {total_files}")

# メイン処理を実行する関数
def main(zip_file_path, tsv_file_path, output_dir, train_ratio=0.8):

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    df = load_and_prepare_data(tsv_file_path)

    extract_zip(zip_file_path, output_dir)

    labels = df['label_id'].unique()

    train_dir, val_dir = create_directories(output_dir, labels)
    image_dir = os.path.join(output_dir, 'train_images')

    distribute_images(df, image_dir, train_dir, val_dir, train_ratio)

    # 解凍後のディレクトリを削除
    if os.path.exists(image_dir):
        shutil.rmtree(image_dir)
        print(f"Deleted temporary directory: {image_dir}")

# 実行
# INPUTディレクトリのファイルをOUTPUTディレクトリにすべてCOPY
simple_copy_files(input_dir,work_dir)
# Train.zipファイル内の画像をtrain、val毎(割合い0.8)かつラベル毎のディレクトリに配置
main(zip_file_path, tsv_file_path, output_dir, train_ratio = TRAIN_RATIO)

count_files_recursive(output_dir)
# Out:
# Deleted temporary directory: /content/sample_data/new_train_images/train_images
# Directory '.' contains 0 files.
# Directory 'val' contains 0 files.
# Directory 'val/7' contains 100 files.
# Directory 'val/9' contains 100 files.
# Directory 'val/4' contains 100 files.
# Directory 'val/1' contains 100 files.
# Directory 'val/0' contains 100 files.
# Directory 'val/3' contains 100 files.
# Directory 'val/8' contains 100 files.
# Directory 'val/6' contains 100 files.
# Directory 'val/5' contains 100 files.
# Directory 'val/2' contains 100 files.
# Directory 'train' contains 0 files.
# Directory 'train/7' contains 400 files.
# Directory 'train/9' contains 400 files.
# Directory 'train/4' contains 400 files.
# Directory 'train/1' contains 400 files.
# Directory 'train/0' contains 400 files.
# Directory 'train/3' contains 400 files.
# Directory 'train/8' contains 400 files.
# Directory 'train/6' contains 400 files.
# Directory 'train/5' contains 400 files.
# Directory 'train/2' contains 400 files.
# Total files in '/content/sample_data/new_train_images': 5000

# %%
# Resnet50で学習
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import zipfile
import torch
import torch.nn as nn
import torch.optim as optim
import albumentations
from torch.utils.data import Dataset, ConcatDataset
from torchvision import datasets, models, transforms
from PIL import Image, ImageFilter

input_dir = '/content/drive/MyDrive/2024_AIContest2/Thema1'
work_dir =  '/content/sample_data'


#定数設定
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
TARGET_NUM = 10
BATCH_SIZE = 64
LEARNING_RATE = 0.01
EPOCH = 15
TRANSFER_LEARNING = True
MODEL_LEARNING = True

#transforms定義
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(256),
        transforms.RandomHorizontalFlip(p=0.5),
#        transforms.GaussianBlur(kernel_size=5, sigma=(0.1, 2.0)),
#        transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
}

#dataset作成(旧)
image_datasets = {
    'train': datasets.ImageFolder('/content/sample_data/new_train_images/train',data_transforms['train']),
    'val': datasets.ImageFolder('/content/sample_data/new_train_images/val',data_transforms['val'])
}

#dataloaders作成
image_dataloaders = {
    'train': torch.utils.data.DataLoader(image_datasets['train'], batch_size=BATCH_SIZE, shuffle=True, num_workers=0, drop_last=True),
    'val': torch.utils.data.DataLoader(image_datasets['val'], batch_size=BATCH_SIZE, shuffle=False, num_workers=0, drop_last=True),
}

#dataサイズ定義
dataset_sizes= {
    'train':len(image_datasets['train']),
    'val':len(image_datasets['val'])
}

#ResNet50モデル定義
def get_model(target_num,isPretrained=False):

    if(isPretrained):
        model_ft = models.resnet50(pretrained=False)
        model_ft.load_state_dict(torch.load(os.path.join(work_dir, '/content/sample_data/resnet50-19c8e357.pth'), map_location=lambda storage, loc: storage,weights_only=False), strict=True)
    else:
        model_ft = models.resnet50(pretrained=False)

    model_ft.fc = nn.Linear(2048, target_num)
    model_ft = model_ft.to(DEVICE)
    return model_ft

if not MODEL_LEARNING:
    print("処理を停止します。")
    sys.exit()  # プログラムを終了

#モデルのインスタンス作成 転移学習なし（FALSE）
model_ft = get_model(target_num=TARGET_NUM,isPretrained=TRANSFER_LEARNING)

#最適化関数定義
optimizer = optim.SGD(model_ft.parameters(),lr=LEARNING_RATE, momentum=0.9)

#loss関数定義
criterion = nn.CrossEntropyLoss()

#モデル訓練用関数
def train_model(model, criterion, optimizer, num_epochs=5,is_saved = False):
    best_acc = 0.0


    train_arr1 = np.zeros(EPOCH)
    val_arr1   = np.zeros(EPOCH)

    # エポック数だけ下記工程の繰り返し
    for epoch in range(num_epochs):

        for phase in ['train', 'val']:
            print('{}:フェイズ'.format(phase))

            # 訓練フェイズと検証フェイズの切り替え
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            # dataloadersからバッチサイズだけデータ取り出し、下記工程（1−5）の繰り返し
            for i,(inputs, labels) in enumerate(image_dataloaders[phase]):
                inputs = inputs.to(DEVICE)
                labels = labels.to(DEVICE)

                # 1. optimizerの勾配初期化
                optimizer.zero_grad()

                # 2.モデルに入力データをinputし、outputを取り出す
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)

                # 3. outputと正解ラベルから、lossを算出
                loss = criterion(outputs, labels)
                print('   loaders:{}回目'.format(i+1)  ,'   loss:{}'.format(loss))

                if phase == 'train':
                    # 4. 誤差逆伝播法により勾配の算出
                    loss.backward()
                    # 5. optimizerのパラメータ更新
                    optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            print('EPOCH{}回目 {} Loss: {:.4f} Acc: {:.4f}'.format(epoch, phase, epoch_loss, epoch_acc))

            if phase == 'train':
                train_arr1[epoch]=epoch_acc
            else:
                val_arr1[epoch]=epoch_acc

            # C. 今までのエポックでの精度よりも高い場合はモデルの保存
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                if(is_saved):
                    print('Save File original_model_{}.pth'.format(epoch))
                    torch.save(model.state_dict(), '/content/drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_{}.pth'.format(epoch))


    print('Best val Acc: {:4f}'.format(best_acc))
    print(train_arr1)
    print(val_arr1)
    train_ser1 = pd.Series(train_arr1,name='train_acc')
    result_data = pd.DataFrame(train_ser1)
    result_data['val_acc']=val_arr1
    result_data.plot()
    plt.show()

train_model(model = model_ft,criterion = criterion,optimizer = optimizer,num_epochs=EPOCH,is_saved = True)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# train:フェイズ
#    loaders:1回目    loss:2.3794820308685303
#    loaders:2回目    loss:2.3757243156433105
#    loaders:3回目    loss:2.224797010421753
#    loaders:4回目    loss:2.0741405487060547
#    loaders:5回目    loss:1.834177851676941
#    loaders:6回目    loss:1.7362728118896484
#    loaders:7回目    loss:1.60733962059021
#    loaders:8回目    loss:1.3553738594055176
#    loaders:9回目    loss:1.268157958984375
#    loaders:10回目    loss:1.0612401962280273
#    loaders:11回目    loss:0.9151715040206909
#    loaders:12回目    loss:0.6847032308578491
#    loaders:13回目    loss:0.5777654051780701
#    loaders:14回目    loss:0.49081867933273315
#    loaders:15回目    loss:0.5332233309745789
#    loaders:16回目    loss:0.4105243980884552
#    loaders:17回目    loss:0.36054718494415283
#    loaders:18回目    loss:0.21010780334472656
#    loaders:19回目    loss:0.38204142451286316
#    loaders:20回目    loss:0.3385932743549347
#    loaders:21回目    loss:0.2916167676448822
#    loaders:22回目    loss:0.27480435371398926
#    loaders:23回目    loss:0.2511424720287323
#    loaders:24回目    loss:0.2053067833185196
#    loaders:25回目    loss:0.1919678896665573
#    loaders:26回目    loss:0.22593268752098083
#    loaders:27回目    loss:0.3357992172241211
#    loaders:28回目    loss:0.30397531390190125
#    loaders:29回目    loss:0.2290363758802414
#    loaders:30回目    loss:0.27205368876457214
#    loaders:31回目    loss:0.29324421286582947
#    loaders:32回目    loss:0.24989266693592072
#    loaders:33回目    loss:0.251954585313797
#    loaders:34回目    loss:0.42841336131095886
#    loaders:35回目    loss:0.28018292784690857
#    loaders:36回目    loss:0.3152022361755371
#    loaders:37回目    loss:0.2565915584564209
#    loaders:38回目    loss:0.4147624373435974
#    loaders:39回目    loss:0.38354334235191345
#    loaders:40回目    loss:0.19179391860961914
#    loaders:41回目    loss:0.28574326634407043
#    loaders:42回目    loss:0.368912935256958
#    loaders:43回目    loss:0.3914114832878113
#    loaders:44回目    loss:0.3809773921966553
#    loaders:45回目    loss:0.32569220662117004
#    loaders:46回目    loss:0.27472206950187683
#    loaders:47回目    loss:0.4583847224712372
#    loaders:48回目    loss:0.2297707200050354
#    loaders:49回目    loss:0.17898115515708923
#    loaders:50回目    loss:0.6062510013580322
#    loaders:51回目    loss:0.33455151319503784
#    loaders:52回目    loss:0.23250073194503784
#    loaders:53回目    loss:0.18749022483825684
#    loaders:54回目    loss:0.16928188502788544
#    loaders:55回目    loss:0.3309975266456604
#    loaders:56回目    loss:0.21782921254634857
#    loaders:57回目    loss:0.25357550382614136
#    loaders:58回目    loss:0.3396790325641632
#    loaders:59回目    loss:0.2621572017669678
#    loaders:60回目    loss:0.432978093624115
#    loaders:61回目    loss:0.35818010568618774
#    loaders:62回目    loss:0.3821035623550415
# EPOCH0回目 train Loss: 0.5675 Acc: 0.8043
# val:フェイズ
#    loaders:1回目    loss:0.5808380842208862
#    loaders:2回目    loss:0.5828161835670471
#    loaders:3回目    loss:0.20986545085906982
#    loaders:4回目    loss:0.14888998866081238
#    loaders:5回目    loss:0.15916235744953156
#    loaders:6回目    loss:0.43903976678848267
#    loaders:7回目    loss:0.42692819237709045
#    loaders:8回目    loss:0.5593096613883972
#    loaders:9回目    loss:0.5644672513008118
#    loaders:10回目    loss:0.3868737518787384
#    loaders:11回目    loss:0.24528957903385162
#    loaders:12回目    loss:1.3512458801269531
#    loaders:13回目    loss:0.5528262257575989
#    loaders:14回目    loss:0.03655589371919632
#    loaders:15回目    loss:0.38618484139442444
# EPOCH0回目 val Loss: 0.4243 Acc: 0.8230
# Save File original_model_0.pth
# train:フェイズ
#    loaders:1回目    loss:0.07441341876983643
#    loaders:2回目    loss:0.16218093037605286
#    loaders:3回目    loss:0.17965063452720642
#    loaders:4回目    loss:0.23201490938663483
#    loaders:5回目    loss:0.44836121797561646
#    loaders:6回目    loss:0.2666446268558502
#    loaders:7回目    loss:0.20440708100795746
#    loaders:8回目    loss:0.24809867143630981
#    loaders:9回目    loss:0.31790536642074585
#    loaders:10回目    loss:0.28869134187698364
#    loaders:11回目    loss:0.21700313687324524
#    loaders:12回目    loss:0.16271348297595978
#    loaders:13回目    loss:0.1566147655248642
#    loaders:14回目    loss:0.2589796483516693
#    loaders:15回目    loss:0.18558262288570404
#    loaders:16回目    loss:0.19729705154895782
#    loaders:17回目    loss:0.2358919233083725
#    loaders:18回目    loss:0.1400917023420334
#    loaders:19回目    loss:0.21923686563968658
#    loaders:20回目    loss:0.18141286075115204
#    loaders:21回目    loss:0.14522278308868408
#    loaders:22回目    loss:0.19736182689666748
#    loaders:23回目    loss:0.2329476922750473
#    loaders:24回目    loss:0.18358834087848663
#    loaders:25回目    loss:0.2863643169403076
#    loaders:26回目    loss:0.27909424901008606
#    loaders:27回目    loss:0.08741442859172821
#    loaders:28回目    loss:0.3138819932937622
#    loaders:29回目    loss:0.21550658345222473
#    loaders:30回目    loss:0.1890023946762085
#    loaders:31回目    loss:0.1301901787519455
#    loaders:32回目    loss:0.395399808883667
#    loaders:33回目    loss:0.17059655487537384
#    loaders:34回目    loss:0.30248960852622986
#    loaders:35回目    loss:0.1480000764131546
#    loaders:36回目    loss:0.38189229369163513
#    loaders:37回目    loss:0.2050349861383438
#    loaders:38回目    loss:0.1388639658689499
#    loaders:39回目    loss:0.11926566809415817
#    loaders:40回目    loss:0.1984986662864685
#    loaders:41回目    loss:0.08099745213985443
#    loaders:42回目    loss:0.16864456236362457
#    loaders:43回目    loss:0.1286107897758484
#    loaders:44回目    loss:0.33571892976760864
#    loaders:45回目    loss:0.3471984565258026
#    loaders:46回目    loss:0.11122272163629532
#    loaders:47回目    loss:0.046061139553785324
#    loaders:48回目    loss:0.3022153973579407
#    loaders:49回目    loss:0.10209138691425323
#    loaders:50回目    loss:0.3602209985256195
#    loaders:51回目    loss:0.08239885419607162
#    loaders:52回目    loss:0.2844093441963196
#    loaders:53回目    loss:0.2589060664176941
#    loaders:54回目    loss:0.2338981032371521
#    loaders:55回目    loss:0.1914479285478592
#    loaders:56回目    loss:0.1788995862007141
#    loaders:57回目    loss:0.21066731214523315
#    loaders:58回目    loss:0.23881372809410095
#    loaders:59回目    loss:0.20088110864162445
#    loaders:60回目    loss:0.14919216930866241
#    loaders:61回目    loss:0.16971570253372192
#    loaders:62回目    loss:0.4272881746292114
# EPOCH1回目 train Loss: 0.2129 Acc: 0.9205
# val:フェイズ
#    loaders:1回目    loss:0.04698390141129494
#    loaders:2回目    loss:0.3718998432159424
#    loaders:3回目    loss:0.12243589013814926
#    loaders:4回目    loss:0.28076037764549255
#    loaders:5回目    loss:0.12518936395645142
#    loaders:6回目    loss:0.15655866265296936
#    loaders:7回目    loss:0.1525096595287323
#    loaders:8回目    loss:0.15556012094020844
#    loaders:9回目    loss:0.7151555418968201
#    loaders:10回目    loss:1.06240975856781
#    loaders:11回目    loss:1.2190136909484863
#    loaders:12回目    loss:0.31771668791770935
#    loaders:13回目    loss:0.2947837710380554
#    loaders:14回目    loss:0.2198314070701599
#    loaders:15回目    loss:0.2514992952346802
# EPOCH1回目 val Loss: 0.3515 Acc: 0.8560
# Save File original_model_1.pth
# train:フェイズ
#    loaders:1回目    loss:0.12077276408672333
#    loaders:2回目    loss:0.06987713277339935
#    loaders:3回目    loss:0.11674442887306213
#    loaders:4回目    loss:0.07770663499832153
#    loaders:5回目    loss:0.06503386050462723
#    loaders:6回目    loss:0.06788881868124008
#    loaders:7回目    loss:0.11879189312458038
#    loaders:8回目    loss:0.020231399685144424
#    loaders:9回目    loss:0.10331417620182037
#    loaders:10回目    loss:0.09967968612909317
#    loaders:11回目    loss:0.11363675445318222
#    loaders:12回目    loss:0.11897425353527069
#    loaders:13回目    loss:0.03658842295408249
#    loaders:14回目    loss:0.15826044976711273
#    loaders:15回目    loss:0.0414947047829628
#    loaders:16回目    loss:0.09945546835660934
#    loaders:17回目    loss:0.10727681964635849
#    loaders:18回目    loss:0.08322349935770035
#    loaders:19回目    loss:0.07703950256109238
#    loaders:20回目    loss:0.05133784934878349
#    loaders:21回目    loss:0.09644017368555069
#    loaders:22回目    loss:0.1117146834731102
#    loaders:23回目    loss:0.04187426343560219
#    loaders:24回目    loss:0.07297823578119278
#    loaders:25回目    loss:0.06177736818790436
#    loaders:26回目    loss:0.0660443976521492
#    loaders:27回目    loss:0.0751301720738411
#    loaders:28回目    loss:0.122928187251091
#    loaders:29回目    loss:0.02870338037610054
#    loaders:30回目    loss:0.04600627347826958
#    loaders:31回目    loss:0.1138254851102829
#    loaders:32回目    loss:0.03671316057443619
#    loaders:33回目    loss:0.0474838986992836
#    loaders:34回目    loss:0.07810705155134201
#    loaders:35回目    loss:0.09938336908817291
#    loaders:36回目    loss:0.1477309912443161
#    loaders:37回目    loss:0.09765710681676865
#    loaders:38回目    loss:0.048578761518001556
#    loaders:39回目    loss:0.10478043556213379
#    loaders:40回目    loss:0.09483552724123001
#    loaders:41回目    loss:0.04757273569703102
#    loaders:42回目    loss:0.06674366444349289
#    loaders:43回目    loss:0.07883267849683762
#    loaders:44回目    loss:0.0791817307472229
#    loaders:45回目    loss:0.09346476197242737
#    loaders:46回目    loss:0.20280885696411133
#    loaders:47回目    loss:0.1593760997056961
#    loaders:48回目    loss:0.08156809210777283
#    loaders:49回目    loss:0.049753811210393906
#    loaders:50回目    loss:0.038843460381031036
#    loaders:51回目    loss:0.1469915509223938
#    loaders:52回目    loss:0.08645625412464142
#    loaders:53回目    loss:0.12357421964406967
#    loaders:54回目    loss:0.08374061435461044
#    loaders:55回目    loss:0.07756712287664413
#    loaders:56回目    loss:0.024169301614165306
#    loaders:57回目    loss:0.04418881982564926
#    loaders:58回目    loss:0.12426050752401352
#    loaders:59回目    loss:0.0872778445482254
#    loaders:60回目    loss:0.07078386843204498
#    loaders:61回目    loss:0.1544366329908371
#    loaders:62回目    loss:0.10148883610963821
# EPOCH2回目 train Loss: 0.0858 Acc: 0.9610
# val:フェイズ
#    loaders:1回目    loss:0.07876727730035782
#    loaders:2回目    loss:0.2875741124153137
#    loaders:3回目    loss:0.27754369378089905
#    loaders:4回目    loss:0.16343693435192108
#    loaders:5回目    loss:0.11353648453950882
#    loaders:6回目    loss:0.3293743133544922
#    loaders:7回目    loss:0.17043255269527435
#    loaders:8回目    loss:0.1254219114780426
#    loaders:9回目    loss:0.1534876525402069
#    loaders:10回目    loss:0.8746696710586548
#    loaders:11回目    loss:0.7337573766708374
#    loaders:12回目    loss:0.3857842981815338
#    loaders:13回目    loss:0.18972402811050415
#    loaders:14回目    loss:0.1275748759508133
#    loaders:15回目    loss:0.4889201521873474
# EPOCH2回目 val Loss: 0.2880 Acc: 0.8670
# Save File original_model_2.pth
# train:フェイズ
#    loaders:1回目    loss:0.054519154131412506
#    loaders:2回目    loss:0.04492399841547012
#    loaders:3回目    loss:0.015140959993004799
#    loaders:4回目    loss:0.00994458980858326
#    loaders:5回目    loss:0.10074862837791443
#    loaders:6回目    loss:0.01824020780622959
#    loaders:7回目    loss:0.08196687698364258
#    loaders:8回目    loss:0.022643784061074257
#    loaders:9回目    loss:0.05302387848496437
#    loaders:10回目    loss:0.04202903434634209
#    loaders:11回目    loss:0.01731252111494541
#    loaders:12回目    loss:0.0422448106110096
#    loaders:13回目    loss:0.049557387828826904
#    loaders:14回目    loss:0.017255635932087898
#    loaders:15回目    loss:0.0419514924287796
#    loaders:16回目    loss:0.023981638252735138
#    loaders:17回目    loss:0.07708735018968582
#    loaders:18回目    loss:0.02129429206252098
#    loaders:19回目    loss:0.0996091440320015
#    loaders:20回目    loss:0.02030128426849842
#    loaders:21回目    loss:0.05213037133216858
#    loaders:22回目    loss:0.05055208504199982
#    loaders:23回目    loss:0.024899465963244438
#    loaders:24回目    loss:0.10787495970726013
#    loaders:25回目    loss:0.03153592348098755
#    loaders:26回目    loss:0.12936435639858246
#    loaders:27回目    loss:0.10235538333654404
#    loaders:28回目    loss:0.06689310818910599
#    loaders:29回目    loss:0.011539464816451073
#    loaders:30回目    loss:0.01956944540143013
#    loaders:31回目    loss:0.06541552394628525
#    loaders:32回目    loss:0.028620239347219467
#    loaders:33回目    loss:0.0324707068502903
#    loaders:34回目    loss:0.026655230671167374
#    loaders:35回目    loss:0.10197121649980545
#    loaders:36回目    loss:0.038771070539951324
#    loaders:37回目    loss:0.17171183228492737
#    loaders:38回目    loss:0.024605631828308105
#    loaders:39回目    loss:0.06770119071006775
#    loaders:40回目    loss:0.03742271661758423
#    loaders:41回目    loss:0.027928264811635017
#    loaders:42回目    loss:0.02708386816084385
#    loaders:43回目    loss:0.007030251901596785
#    loaders:44回目    loss:0.08647461980581284
#    loaders:45回目    loss:0.009247583337128162
#    loaders:46回目    loss:0.041726600378751755
#    loaders:47回目    loss:0.026996083557605743
#    loaders:48回目    loss:0.07346457242965698
#    loaders:49回目    loss:0.10120896995067596
#    loaders:50回目    loss:0.052501827478408813
#    loaders:51回目    loss:0.030456138774752617
#    loaders:52回目    loss:0.030811933800578117
#    loaders:53回目    loss:0.10995211452245712
#    loaders:54回目    loss:0.05428915470838547
#    loaders:55回目    loss:0.009535398334264755
#    loaders:56回目    loss:0.04263733699917793
#    loaders:57回目    loss:0.12901586294174194
#    loaders:58回目    loss:0.03480026498436928
#    loaders:59回目    loss:0.029258765280246735
#    loaders:60回目    loss:0.03282943367958069
#    loaders:61回目    loss:0.07663966715335846
#    loaders:62回目    loss:0.09052079916000366
# EPOCH3回目 train Loss: 0.0507 Acc: 0.9758
# val:フェイズ
#    loaders:1回目    loss:0.017192518338561058
#    loaders:2回目    loss:0.05601663887500763
#    loaders:3回目    loss:0.14162485301494598
#    loaders:4回目    loss:0.4315586984157562
#    loaders:5回目    loss:0.13683654367923737
#    loaders:6回目    loss:0.3017609715461731
#    loaders:7回目    loss:0.5011215209960938
#    loaders:8回目    loss:0.7326127886772156
#    loaders:9回目    loss:0.4801922142505646
#    loaders:10回目    loss:0.09492550790309906
#    loaders:11回目    loss:0.08956499397754669
#    loaders:12回目    loss:0.46852582693099976
#    loaders:13回目    loss:0.260275274515152
#    loaders:14回目    loss:0.11518409103155136
#    loaders:15回目    loss:0.07703263312578201
# EPOCH3回目 val Loss: 0.2499 Acc: 0.8940
# Save File original_model_3.pth
# train:フェイズ
#    loaders:1回目    loss:0.03159179538488388
#    loaders:2回目    loss:0.014743645675480366
#    loaders:3回目    loss:0.01360967569053173
#    loaders:4回目    loss:0.029461057856678963
#    loaders:5回目    loss:0.02142164669930935
#    loaders:6回目    loss:0.0241100937128067
#    loaders:7回目    loss:0.014106585644185543
#    loaders:8回目    loss:0.0723787173628807
#    loaders:9回目    loss:0.037302177399396896
#    loaders:10回目    loss:0.048167262226343155
#    loaders:11回目    loss:0.09768401086330414
#    loaders:12回目    loss:0.04728376492857933
#    loaders:13回目    loss:0.038950320333242416
#    loaders:14回目    loss:0.011844467371702194
#    loaders:15回目    loss:0.04405315965414047
#    loaders:16回目    loss:0.0207991823554039
#    loaders:17回目    loss:0.010601007379591465
#    loaders:18回目    loss:0.045111242681741714
#    loaders:19回目    loss:0.09084556251764297
#    loaders:20回目    loss:0.019648408517241478
#    loaders:21回目    loss:0.055632900446653366
#    loaders:22回目    loss:0.02860838733613491
#    loaders:23回目    loss:0.09188752621412277
#    loaders:24回目    loss:0.07505292445421219
#    loaders:25回目    loss:0.06791131943464279
#    loaders:26回目    loss:0.050625041127204895
#    loaders:27回目    loss:0.035078417509794235
#    loaders:28回目    loss:0.023771213367581367
#    loaders:29回目    loss:0.05161558464169502
#    loaders:30回目    loss:0.0049668168649077415
#    loaders:31回目    loss:0.03060748241841793
#    loaders:32回目    loss:0.023470481857657433
#    loaders:33回目    loss:0.11333895474672318
#    loaders:34回目    loss:0.04551137611269951
#    loaders:35回目    loss:0.05424952507019043
#    loaders:36回目    loss:0.04803907871246338
#    loaders:37回目    loss:0.12621356546878815
#    loaders:38回目    loss:0.13686750829219818
#    loaders:39回目    loss:0.05329098552465439
#    loaders:40回目    loss:0.005124916788190603
#    loaders:41回目    loss:0.0034835785627365112
#    loaders:42回目    loss:0.02033011056482792
#    loaders:43回目    loss:0.012992532923817635
#    loaders:44回目    loss:0.06276994198560715
#    loaders:45回目    loss:0.05571538954973221
#    loaders:46回目    loss:0.1715422123670578
#    loaders:47回目    loss:0.014309171587228775
#    loaders:48回目    loss:0.023461749777197838
#    loaders:49回目    loss:0.03379771113395691
#    loaders:50回目    loss:0.07894708216190338
#    loaders:51回目    loss:0.07502320408821106
#    loaders:52回目    loss:0.011584203690290451
#    loaders:53回目    loss:0.01797838881611824
#    loaders:54回目    loss:0.05784595012664795
#    loaders:55回目    loss:0.006670694332569838
#    loaders:56回目    loss:0.12852270901203156
#    loaders:57回目    loss:0.16643814742565155
#    loaders:58回目    loss:0.032078299671411514
#    loaders:59回目    loss:0.033107563853263855
#    loaders:60回目    loss:0.05068621784448624
#    loaders:61回目    loss:0.07743190973997116
#    loaders:62回目    loss:0.04254846274852753
# EPOCH4回目 train Loss: 0.0485 Acc: 0.9763
# val:フェイズ
#    loaders:1回目    loss:0.12508165836334229
#    loaders:2回目    loss:0.36855462193489075
#    loaders:3回目    loss:0.3369302749633789
#    loaders:4回目    loss:0.2506532073020935
#    loaders:5回目    loss:0.2952900528907776
#    loaders:6回目    loss:0.582881510257721
#    loaders:7回目    loss:0.41033709049224854
#    loaders:8回目    loss:0.6477392911911011
#    loaders:9回目    loss:1.0287535190582275
#    loaders:10回目    loss:0.6156637072563171
#    loaders:11回目    loss:0.11171422898769379
#    loaders:12回目    loss:0.23493757843971252
#    loaders:13回目    loss:0.2598373591899872
#    loaders:14回目    loss:0.12846118211746216
#    loaders:15回目    loss:0.04695688188076019
# EPOCH4回目 val Loss: 0.3484 Acc: 0.8750
# train:フェイズ
#    loaders:1回目    loss:0.10709112882614136
#    loaders:2回目    loss:0.02218884415924549
#    loaders:3回目    loss:0.054124124348163605
#    loaders:4回目    loss:0.017424326390028
#    loaders:5回目    loss:0.0404636412858963
#    loaders:6回目    loss:0.029010718688368797
#    loaders:7回目    loss:0.07574934512376785
#    loaders:8回目    loss:0.007380186580121517
#    loaders:9回目    loss:0.00388011010363698
#    loaders:10回目    loss:0.019662847742438316
#    loaders:11回目    loss:0.05480223521590233
#    loaders:12回目    loss:0.008121252059936523
#    loaders:13回目    loss:0.026047321036458015
#    loaders:14回目    loss:0.06469818949699402
#    loaders:15回目    loss:0.12470094859600067
#    loaders:16回目    loss:0.03443146497011185
#    loaders:17回目    loss:0.0433877557516098
#    loaders:18回目    loss:0.04532434418797493
#    loaders:19回目    loss:0.025220712646842003
#    loaders:20回目    loss:0.024148881435394287
#    loaders:21回目    loss:0.022499144077301025
#    loaders:22回目    loss:0.058827582746744156
#    loaders:23回目    loss:0.03542351722717285
#    loaders:24回目    loss:0.046832989901304245
#    loaders:25回目    loss:0.06563355028629303
#    loaders:26回目    loss:0.013387532904744148
#    loaders:27回目    loss:0.006733693182468414
#    loaders:28回目    loss:0.008128483779728413
#    loaders:29回目    loss:0.017447538673877716
#    loaders:30回目    loss:0.02084195800125599
#    loaders:31回目    loss:0.04930984601378441
#    loaders:32回目    loss:0.020538337528705597
#    loaders:33回目    loss:0.13599570095539093
#    loaders:34回目    loss:0.00265007303096354
#    loaders:35回目    loss:0.02720947004854679
#    loaders:36回目    loss:0.028103314340114594
#    loaders:37回目    loss:0.045158546417951584
#    loaders:38回目    loss:0.016758855432271957
#    loaders:39回目    loss:0.03523307666182518
#    loaders:40回目    loss:0.004577970132231712
#    loaders:41回目    loss:0.03094279207289219
#    loaders:42回目    loss:0.0244513601064682
#    loaders:43回目    loss:0.03454480692744255
#    loaders:44回目    loss:0.009457364678382874
#    loaders:45回目    loss:0.08416924625635147
#    loaders:46回目    loss:0.08302512019872665
#    loaders:47回目    loss:0.015797920525074005
#    loaders:48回目    loss:0.01211878564208746
#    loaders:49回目    loss:0.018890058621764183
#    loaders:50回目    loss:0.02224385365843773
#    loaders:51回目    loss:0.03161071240901947
#    loaders:52回目    loss:0.10853884369134903
#    loaders:53回目    loss:0.15067104995250702
#    loaders:54回目    loss:0.04877127334475517
#    loaders:55回目    loss:0.05061094090342522
#    loaders:56回目    loss:0.0049157170578837395
#    loaders:57回目    loss:0.01910790428519249
#    loaders:58回目    loss:0.003429584437981248
#    loaders:59回目    loss:0.016945380717515945
#    loaders:60回目    loss:0.04226717725396156
#    loaders:61回目    loss:0.016021572053432465
#    loaders:62回目    loss:0.049574676901102066
# EPOCH5回目 train Loss: 0.0379 Acc: 0.9793
# val:フェイズ
#    loaders:1回目    loss:0.05602206662297249
#    loaders:2回目    loss:0.13436201214790344
#    loaders:3回目    loss:0.062086548656225204
#    loaders:4回目    loss:0.07328324764966965
#    loaders:5回目    loss:0.13799139857292175
#    loaders:6回目    loss:0.47771599888801575
#    loaders:7回目    loss:0.3430635631084442
#    loaders:8回目    loss:0.3155810534954071
#    loaders:9回目    loss:0.4821956753730774
#    loaders:10回目    loss:0.28787586092948914
#    loaders:11回目    loss:0.13037973642349243
#    loaders:12回目    loss:0.41655033826828003
#    loaders:13回目    loss:0.3643224835395813
#    loaders:14回目    loss:0.023977484554052353
#    loaders:15回目    loss:0.34262093901634216
# EPOCH5回目 val Loss: 0.2335 Acc: 0.8890
# train:フェイズ
#    loaders:1回目    loss:0.01817735843360424
#    loaders:2回目    loss:0.008343306370079517
#    loaders:3回目    loss:0.0027274377644062042
#    loaders:4回目    loss:0.0312594436109066
#    loaders:5回目    loss:0.0038281010929495096
#    loaders:6回目    loss:0.013293993659317493
#    loaders:7回目    loss:0.044149138033390045
#    loaders:8回目    loss:0.005750471260398626
#    loaders:9回目    loss:0.006934948731213808
#    loaders:10回目    loss:0.07533480226993561
#    loaders:11回目    loss:0.021030737087130547
#    loaders:12回目    loss:0.054590314626693726
#    loaders:13回目    loss:0.06682862341403961
#    loaders:14回目    loss:0.008826309815049171
#    loaders:15回目    loss:0.005046638194471598
#    loaders:16回目    loss:0.0033289887942373753
#    loaders:17回目    loss:0.041900113224983215
#    loaders:18回目    loss:0.009998944588005543
#    loaders:19回目    loss:0.013244153000414371
#    loaders:20回目    loss:0.010287007316946983
#    loaders:21回目    loss:0.006463381461799145
#    loaders:22回目    loss:0.005287181120365858
#    loaders:23回目    loss:0.002150381449609995
#    loaders:24回目    loss:0.023226583376526833
#    loaders:25回目    loss:0.0058127399533987045
#    loaders:26回目    loss:0.00422965083271265
#    loaders:27回目    loss:0.02453739568591118
#    loaders:28回目    loss:0.008892142213881016
#    loaders:29回目    loss:0.08089839667081833
#    loaders:30回目    loss:0.010115879587829113
#    loaders:31回目    loss:0.014336536638438702
#    loaders:32回目    loss:0.009638254530727863
#    loaders:33回目    loss:0.10267781466245651
#    loaders:34回目    loss:0.002559518674388528
#    loaders:35回目    loss:0.05457262322306633
#    loaders:36回目    loss:0.02918415144085884
#    loaders:37回目    loss:0.009022247046232224
#    loaders:38回目    loss:0.0014362335205078125
#    loaders:39回目    loss:0.005548060405999422
#    loaders:40回目    loss:0.015965718775987625
#    loaders:41回目    loss:0.0464346818625927
#    loaders:42回目    loss:0.0048043434508144855
#    loaders:43回目    loss:0.04997948929667473
#    loaders:44回目    loss:0.011690497398376465
#    loaders:45回目    loss:0.04213125631213188
#    loaders:46回目    loss:0.029517268761992455
#    loaders:47回目    loss:0.005030268337577581
#    loaders:48回目    loss:0.15647965669631958
#    loaders:49回目    loss:0.031168265268206596
#    loaders:50回目    loss:0.15850667655467987
#    loaders:51回目    loss:0.009191436693072319
#    loaders:52回目    loss:0.049295518547296524
#    loaders:53回目    loss:0.006719799246639013
#    loaders:54回目    loss:0.009058390744030476
#    loaders:55回目    loss:0.012007752433419228
#    loaders:56回目    loss:0.12920579314231873
#    loaders:57回目    loss:0.12897442281246185
#    loaders:58回目    loss:0.058860938996076584
#    loaders:59回目    loss:0.06464285403490067
#    loaders:60回目    loss:0.03495658189058304
#    loaders:61回目    loss:0.017197376117110252
#    loaders:62回目    loss:0.0875835046172142
# EPOCH6回目 train Loss: 0.0321 Acc: 0.9820
# val:フェイズ
#    loaders:1回目    loss:0.18246817588806152
#    loaders:2回目    loss:0.30574437975883484
#    loaders:3回目    loss:0.20502488315105438
#    loaders:4回目    loss:0.28782790899276733
#    loaders:5回目    loss:0.24241061508655548
#    loaders:6回目    loss:0.6147223114967346
#    loaders:7回目    loss:0.16901594400405884
#    loaders:8回目    loss:0.1597193479537964
#    loaders:9回目    loss:0.18208754062652588
#    loaders:10回目    loss:0.16845110058784485
#    loaders:11回目    loss:0.3769107460975647
#    loaders:12回目    loss:0.3381013870239258
#    loaders:13回目    loss:0.12983614206314087
#    loaders:14回目    loss:0.06302051246166229
#    loaders:15回目    loss:0.023161327466368675
# EPOCH6回目 val Loss: 0.2207 Acc: 0.9020
# Save File original_model_6.pth
# train:フェイズ
#    loaders:1回目    loss:0.031832966953516006
#    loaders:2回目    loss:0.0052499109879136086
#    loaders:3回目    loss:0.040973398834466934
#    loaders:4回目    loss:0.021178193390369415
#    loaders:5回目    loss:0.03189739212393761
#    loaders:6回目    loss:0.014969246461987495
#    loaders:7回目    loss:0.062136515974998474
#    loaders:8回目    loss:0.009412712417542934
#    loaders:9回目    loss:0.0036745809484273195
#    loaders:10回目    loss:0.04300754889845848
#    loaders:11回目    loss:0.03898070752620697
#    loaders:12回目    loss:0.017128806561231613
#    loaders:13回目    loss:0.055475957691669464
#    loaders:14回目    loss:0.031054746359586716
#    loaders:15回目    loss:0.06793055683374405
#    loaders:16回目    loss:0.009630031883716583
#    loaders:17回目    loss:0.006529809441417456
#    loaders:18回目    loss:0.015401673503220081
#    loaders:19回目    loss:0.05231821537017822
#    loaders:20回目    loss:0.013594196178019047
#    loaders:21回目    loss:0.031549736857414246
#    loaders:22回目    loss:0.012547080405056477
#    loaders:23回目    loss:0.09383339434862137
#    loaders:24回目    loss:0.047978103160858154
#    loaders:25回目    loss:0.018654871731996536
#    loaders:26回目    loss:0.04532793164253235
#    loaders:27回目    loss:0.015541501343250275
#    loaders:28回目    loss:0.005626659840345383
#    loaders:29回目    loss:0.002549255732446909
#    loaders:30回目    loss:0.015243707224726677
#    loaders:31回目    loss:0.04898107424378395
#    loaders:32回目    loss:0.010996591299772263
#    loaders:33回目    loss:0.008344687521457672
#    loaders:34回目    loss:0.023896442726254463
#    loaders:35回目    loss:0.01159893162548542
#    loaders:36回目    loss:0.004143598955124617
#    loaders:37回目    loss:0.004809664562344551
#    loaders:38回目    loss:0.017041202634572983
#    loaders:39回目    loss:0.005926672834903002
#    loaders:40回目    loss:0.032212670892477036
#    loaders:41回目    loss:0.03566021844744682
#    loaders:42回目    loss:0.06643494963645935
#    loaders:43回目    loss:0.01652280054986477
#    loaders:44回目    loss:0.021394390612840652
#    loaders:45回目    loss:0.006316319108009338
#    loaders:46回目    loss:0.033658016473054886
#    loaders:47回目    loss:0.002727907383814454
#    loaders:48回目    loss:0.004844309762120247
#    loaders:49回目    loss:0.017407944425940514
#    loaders:50回目    loss:0.03325672447681427
#    loaders:51回目    loss:0.02136167138814926
#    loaders:52回目    loss:0.005465826019644737
#    loaders:53回目    loss:0.018292609602212906
#    loaders:54回目    loss:0.004834738094359636
#    loaders:55回目    loss:0.01895032450556755
#    loaders:56回目    loss:0.10095309466123581
#    loaders:57回目    loss:0.0010603585978969932
#    loaders:58回目    loss:0.01760779693722725
#    loaders:59回目    loss:0.002011330099776387
#    loaders:60回目    loss:0.0021546774078160524
#    loaders:61回目    loss:0.012597151100635529
#    loaders:62回目    loss:0.014325522817671299
# EPOCH7回目 train Loss: 0.0238 Acc: 0.9850
# val:フェイズ
#    loaders:1回目    loss:0.05225689336657524
#    loaders:2回目    loss:0.12516938149929047
#    loaders:3回目    loss:0.16264961659908295
#    loaders:4回目    loss:0.13435453176498413
#    loaders:5回目    loss:0.1274051070213318
#    loaders:6回目    loss:0.3042125701904297
#    loaders:7回目    loss:0.16442908346652985
#    loaders:8回目    loss:0.25344476103782654
#    loaders:9回目    loss:0.4304053783416748
#    loaders:10回目    loss:0.17574575543403625
#    loaders:11回目    loss:0.10541679710149765
#    loaders:12回目    loss:0.29133981466293335
#    loaders:13回目    loss:0.11487936228513718
#    loaders:14回目    loss:0.15505728125572205
#    loaders:15回目    loss:0.11438529193401337
# EPOCH7回目 val Loss: 0.1735 Acc: 0.9090
# Save File original_model_7.pth
# train:フェイズ
#    loaders:1回目    loss:0.004248793702572584
#    loaders:2回目    loss:0.036258697509765625
#    loaders:3回目    loss:0.035928357392549515
#    loaders:4回目    loss:0.0017425320111215115
#    loaders:5回目    loss:0.0022410289384424686
#    loaders:6回目    loss:0.0018344679847359657
#    loaders:7回目    loss:0.003962340764701366
#    loaders:8回目    loss:0.0033161682076752186
#    loaders:9回目    loss:0.0020464768167585135
#    loaders:10回目    loss:0.040801793336868286
#    loaders:11回目    loss:0.0024033738300204277
#    loaders:12回目    loss:0.0060554202646017075
#    loaders:13回目    loss:0.015535371378064156
#    loaders:14回目    loss:0.007629937492311001
#    loaders:15回目    loss:0.026911264285445213
#    loaders:16回目    loss:0.011706817895174026
#    loaders:17回目    loss:0.020122140645980835
#    loaders:18回目    loss:0.04221450909972191
#    loaders:19回目    loss:0.07434898614883423
#    loaders:20回目    loss:0.0044786762446165085
#    loaders:21回目    loss:0.04109613224864006
#    loaders:22回目    loss:0.001908936072140932
#    loaders:23回目    loss:0.0008336500031873584
#    loaders:24回目    loss:0.07373140752315521
#    loaders:25回目    loss:0.004074099939316511
#    loaders:26回目    loss:0.003972488921135664
#    loaders:27回目    loss:0.009516069665551186
#    loaders:28回目    loss:0.08904897421598434
#    loaders:29回目    loss:0.006160070188343525
#    loaders:30回目    loss:0.0027746648993343115
#    loaders:31回目    loss:0.02242308296263218
#    loaders:32回目    loss:0.014551173895597458
#    loaders:33回目    loss:0.029721347615122795
#    loaders:34回目    loss:0.004024480003863573
#    loaders:35回目    loss:0.03912712633609772
#    loaders:36回目    loss:0.0027881707064807415
#    loaders:37回目    loss:0.11720763891935349
#    loaders:38回目    loss:0.043218061327934265
#    loaders:39回目    loss:0.009252753108739853
#    loaders:40回目    loss:0.031375136226415634
#    loaders:41回目    loss:0.001155316480435431
#    loaders:42回目    loss:0.0032745262142270803
#    loaders:43回目    loss:0.0021613265853375196
#    loaders:44回目    loss:0.06966064125299454
#    loaders:45回目    loss:0.06191891059279442
#    loaders:46回目    loss:0.013207457028329372
#    loaders:47回目    loss:0.009572261944413185
#    loaders:48回目    loss:0.014695825055241585
#    loaders:49回目    loss:0.04371929168701172
#    loaders:50回目    loss:0.0550144761800766
#    loaders:51回目    loss:0.047211091965436935
#    loaders:52回目    loss:0.007497274316847324
#    loaders:53回目    loss:0.01491690892726183
#    loaders:54回目    loss:0.01594686508178711
#    loaders:55回目    loss:0.002381972037255764
#    loaders:56回目    loss:0.008830288425087929
#    loaders:57回目    loss:0.0439942330121994
#    loaders:58回目    loss:0.023749923333525658
#    loaders:59回目    loss:0.007947340607643127
#    loaders:60回目    loss:0.002628192538395524
#    loaders:61回目    loss:0.046103816479444504
#    loaders:62回目    loss:0.0070268455892801285
# EPOCH8回目 train Loss: 0.0223 Acc: 0.9848
# val:フェイズ
#    loaders:1回目    loss:0.13353464007377625
#    loaders:2回目    loss:0.43946781754493713
#    loaders:3回目    loss:0.40100711584091187
#    loaders:4回目    loss:0.19825910031795502
#    loaders:5回目    loss:0.10942001640796661
#    loaders:6回目    loss:0.24732714891433716
#    loaders:7回目    loss:0.15958735346794128
#    loaders:8回目    loss:0.16810034215450287
#    loaders:9回目    loss:0.44922131299972534
#    loaders:10回目    loss:0.2845434546470642
#    loaders:11回目    loss:0.4327443540096283
#    loaders:12回目    loss:0.035029344260692596
#    loaders:13回目    loss:0.06737858057022095
#    loaders:14回目    loss:0.014713062904775143
#    loaders:15回目    loss:0.2640721797943115
# EPOCH8回目 val Loss: 0.2179 Acc: 0.9040
# train:フェイズ
#    loaders:1回目    loss:0.009028708562254906
#    loaders:2回目    loss:0.0067302267998456955
#    loaders:3回目    loss:0.013813270255923271
#    loaders:4回目    loss:0.02012365497648716
#    loaders:5回目    loss:0.005073558539152145
#    loaders:6回目    loss:0.003522263141348958
#    loaders:7回目    loss:0.0008680401952005923
#    loaders:8回目    loss:0.0033083322923630476
#    loaders:9回目    loss:0.018414784222841263
#    loaders:10回目    loss:0.01019921712577343
#    loaders:11回目    loss:0.003339627757668495
#    loaders:12回目    loss:0.001343500567600131
#    loaders:13回目    loss:0.008778547868132591
#    loaders:14回目    loss:0.009620142169296741
#    loaders:15回目    loss:0.003006687853485346
#    loaders:16回目    loss:0.012218708172440529
#    loaders:17回目    loss:0.007821760140359402
#    loaders:18回目    loss:0.01281894650310278
#    loaders:19回目    loss:0.0009624150698073208
#    loaders:20回目    loss:0.0004728863132186234
#    loaders:21回目    loss:0.013851113617420197
#    loaders:22回目    loss:0.013175374828279018
#    loaders:23回目    loss:0.017575711011886597
#    loaders:24回目    loss:0.008678976446390152
#    loaders:25回目    loss:0.0007968039717525244
#    loaders:26回目    loss:0.006577962543815374
#    loaders:27回目    loss:0.0035209201741963625
#    loaders:28回目    loss:0.004495745059102774
#    loaders:29回目    loss:0.007630106061697006
#    loaders:30回目    loss:0.006060756742954254
#    loaders:31回目    loss:0.001188087509945035
#    loaders:32回目    loss:0.0014615844702348113
#    loaders:33回目    loss:0.005093263927847147
#    loaders:34回目    loss:0.0012267635902389884
#    loaders:35回目    loss:0.002431566594168544
#    loaders:36回目    loss:0.002087731845676899
#    loaders:37回目    loss:0.007555704098194838
#    loaders:38回目    loss:0.0013565344270318747
#    loaders:39回目    loss:0.009164716117084026
#    loaders:40回目    loss:0.001302796765230596
#    loaders:41回目    loss:0.003100654808804393
#    loaders:42回目    loss:0.006458032410591841
#    loaders:43回目    loss:0.0003553043061401695
#    loaders:44回目    loss:0.0008363857632502913
#    loaders:45回目    loss:0.008580479770898819
#    loaders:46回目    loss:0.0038198838010430336
#    loaders:47回目    loss:0.0038250626530498266
#    loaders:48回目    loss:0.0078070880845189095
#    loaders:49回目    loss:0.04993785172700882
#    loaders:50回目    loss:0.0034350783098489046
#    loaders:51回目    loss:0.000841926725115627
#    loaders:52回目    loss:0.0010042650392279029
#    loaders:53回目    loss:0.009023109450936317
#    loaders:54回目    loss:0.009143334813416004
#    loaders:55回目    loss:0.001308980630710721
#    loaders:56回目    loss:0.0005590725922957063
#    loaders:57回目    loss:0.0021523803006857634
#    loaders:58回目    loss:0.0024509700015187263
#    loaders:59回目    loss:0.007036680821329355
#    loaders:60回目    loss:0.0012828237377107143
#    loaders:61回目    loss:0.05385958030819893
#    loaders:62回目    loss:0.0013854503631591797
# EPOCH9回目 train Loss: 0.0071 Acc: 0.9910
# val:フェイズ
#    loaders:1回目    loss:0.08719661086797714
#    loaders:2回目    loss:0.20390447974205017
#    loaders:3回目    loss:0.13544775545597076
#    loaders:4回目    loss:0.15077565610408783
#    loaders:5回目    loss:0.10396190732717514
#    loaders:6回目    loss:0.3599018156528473
#    loaders:7回目    loss:0.26327741146087646
#    loaders:8回目    loss:0.21265721321105957
#    loaders:9回目    loss:0.3515778183937073
#    loaders:10回目    loss:0.17035719752311707
#    loaders:11回目    loss:0.20964974164962769
#    loaders:12回目    loss:0.4985256791114807
#    loaders:13回目    loss:0.1839875727891922
#    loaders:14回目    loss:0.00464833015576005
#    loaders:15回目    loss:0.11874948441982269
# EPOCH9回目 val Loss: 0.1955 Acc: 0.9000
# train:フェイズ
#    loaders:1回目    loss:0.0014740816550329328
#    loaders:2回目    loss:0.001586402184329927
#    loaders:3回目    loss:0.0005901181721128523
#    loaders:4回目    loss:0.000989156193099916
#    loaders:5回目    loss:0.0029300919268280268
#    loaders:6回目    loss:0.0053151738829910755
#    loaders:7回目    loss:0.0013462505303323269
#    loaders:8回目    loss:0.0008261644979938865
#    loaders:9回目    loss:0.0017152020009234548
#    loaders:10回目    loss:0.002926821354776621
#    loaders:11回目    loss:0.0027812314219772816
#    loaders:12回目    loss:0.011572067625820637
#    loaders:13回目    loss:0.0013279172126203775
#    loaders:14回目    loss:0.003973104991018772
#    loaders:15回目    loss:0.0013625405263155699
#    loaders:16回目    loss:0.002976550254970789
#    loaders:17回目    loss:0.003903690492734313
#    loaders:18回目    loss:0.008255038410425186
#    loaders:19回目    loss:0.0032257428392767906
#    loaders:20回目    loss:0.00097567995544523
#    loaders:21回目    loss:0.001213827170431614
#    loaders:22回目    loss:0.008921884931623936
#    loaders:23回目    loss:0.020168010145425797
#    loaders:24回目    loss:0.003917142283171415
#    loaders:25回目    loss:0.0030893029179424047
#    loaders:26回目    loss:0.0015240800566971302
#    loaders:27回目    loss:0.0012107430957257748
#    loaders:28回目    loss:0.0081649674102664
#    loaders:29回目    loss:0.026504170149564743
#    loaders:30回目    loss:0.0026658170390874147
#    loaders:31回目    loss:0.0008008814766071737
#    loaders:32回目    loss:0.003016182454302907
#    loaders:33回目    loss:0.0025664696004241705
#    loaders:34回目    loss:0.002748740604147315
#    loaders:35回目    loss:0.007086497265845537
#    loaders:36回目    loss:0.006193010602146387
#    loaders:37回目    loss:0.0008219823357649148
#    loaders:38回目    loss:0.008828094229102135
#    loaders:39回目    loss:0.0007977351197041571
#    loaders:40回目    loss:0.0022517407778650522
#    loaders:41回目    loss:0.000943620631005615
#    loaders:42回目    loss:0.0023223613388836384
#    loaders:43回目    loss:0.0007873351569287479
#    loaders:44回目    loss:0.0017417889321222901
#    loaders:45回目    loss:0.00028534361626952887
#    loaders:46回目    loss:0.0016335060354322195
#    loaders:47回目    loss:0.003709452925249934
#    loaders:48回目    loss:0.0024598969612270594
#    loaders:49回目    loss:0.00024353009939659387
#    loaders:50回目    loss:0.0025799120776355267
#    loaders:51回目    loss:0.010841513983905315
#    loaders:52回目    loss:0.017734386026859283
#    loaders:53回目    loss:0.0007508804555982351
#    loaders:54回目    loss:0.0005703649949282408
#    loaders:55回目    loss:0.0020094290375709534
#    loaders:56回目    loss:0.0028169844299554825
#    loaders:57回目    loss:0.0012171966955065727
#    loaders:58回目    loss:0.001348105724900961
#    loaders:59回目    loss:0.00044331280514597893
#    loaders:60回目    loss:0.0007718857377767563
#    loaders:61回目    loss:0.005943106021732092
#    loaders:62回目    loss:0.001521986210718751
# EPOCH10回目 train Loss: 0.0038 Acc: 0.9910
# val:フェイズ
#    loaders:1回目    loss:0.08255874365568161
#    loaders:2回目    loss:0.26782235503196716
#    loaders:3回目    loss:0.21193718910217285
#    loaders:4回目    loss:0.1678687483072281
#    loaders:5回目    loss:0.13367874920368195
#    loaders:6回目    loss:0.23071712255477905
#    loaders:7回目    loss:0.11083139479160309
#    loaders:8回目    loss:0.2010149508714676
#    loaders:9回目    loss:0.43681153655052185
#    loaders:10回目    loss:0.18107876181602478
#    loaders:11回目    loss:0.0805821642279625
#    loaders:12回目    loss:0.12591983377933502
#    loaders:13回目    loss:0.06688900291919708
#    loaders:14回目    loss:0.01677074283361435
#    loaders:15回目    loss:0.0382215678691864
# EPOCH10回目 val Loss: 0.1506 Acc: 0.9160
# Save File original_model_10.pth
# train:フェイズ
#    loaders:1回目    loss:0.004718621727079153
#    loaders:2回目    loss:0.002014515455812216
#    loaders:3回目    loss:0.001407075673341751
#    loaders:4回目    loss:0.0005608965875580907
#    loaders:5回目    loss:0.004879591055214405
#    loaders:6回目    loss:0.000808588694781065
#    loaders:7回目    loss:0.0007320078439079225
#    loaders:8回目    loss:0.05345293506979942
#    loaders:9回目    loss:0.0011767084943130612
#    loaders:10回目    loss:0.0002679023891687393
#    loaders:11回目    loss:0.0005015877541154623
#    loaders:12回目    loss:0.0060973637737333775
#    loaders:13回目    loss:0.016363009810447693
#    loaders:14回目    loss:0.001125722541473806
#    loaders:15回目    loss:0.00016010290710255504
#    loaders:16回目    loss:0.0003234957985114306
#    loaders:17回目    loss:0.002907785354182124
#    loaders:18回目    loss:0.003808288834989071
#    loaders:19回目    loss:0.00026603825972415507
#    loaders:20回目    loss:0.002868850249797106
#    loaders:21回目    loss:0.00038443083758465946
#    loaders:22回目    loss:0.005425433628261089
#    loaders:23回目    loss:0.0038791752886027098
#    loaders:24回目    loss:0.0005466761067509651
#    loaders:25回目    loss:0.0005940280971117318
#    loaders:26回目    loss:0.0004040979838464409
#    loaders:27回目    loss:0.005101481918245554
#    loaders:28回目    loss:0.0005129359196871519
#    loaders:29回目    loss:0.004677890334278345
#    loaders:30回目    loss:0.0008034503553062677
#    loaders:31回目    loss:0.005761641077697277
#    loaders:32回目    loss:0.0004598463710863143
#    loaders:33回目    loss:0.0025545742828398943
#    loaders:34回目    loss:0.0020446833223104477
#    loaders:35回目    loss:0.000411530549172312
#    loaders:36回目    loss:0.0007906187092885375
#    loaders:37回目    loss:0.00103960616979748
#    loaders:38回目    loss:0.014463527128100395
#    loaders:39回目    loss:0.0013756779953837395
#    loaders:40回目    loss:0.002313720528036356
#    loaders:41回目    loss:0.0050491709262132645
#    loaders:42回目    loss:0.005404320079833269
#    loaders:43回目    loss:0.000642183527816087
#    loaders:44回目    loss:0.0010672250064089894
#    loaders:45回目    loss:0.0008289804682135582
#    loaders:46回目    loss:0.00024564351770095527
#    loaders:47回目    loss:0.07310470193624496
#    loaders:48回目    loss:0.0005230696406215429
#    loaders:49回目    loss:0.0008215443231165409
#    loaders:50回目    loss:0.0009057932184077799
#    loaders:51回目    loss:0.0007604632992297411
#    loaders:52回目    loss:0.005320011172443628
#    loaders:53回目    loss:0.0038998008240014315
#    loaders:54回目    loss:0.0022675497457385063
#    loaders:55回目    loss:0.0005591016379185021
#    loaders:56回目    loss:0.002422614488750696
#    loaders:57回目    loss:0.0020917218644171953
#    loaders:58回目    loss:0.005430357065051794
#    loaders:59回目    loss:0.007788582239300013
#    loaders:60回目    loss:0.0013199466047808528
#    loaders:61回目    loss:0.007921071723103523
#    loaders:62回目    loss:0.0008010435849428177
# EPOCH11回目 train Loss: 0.0046 Acc: 0.9915
# val:フェイズ
#    loaders:1回目    loss:0.21051044762134552
#    loaders:2回目    loss:0.4258333146572113
#    loaders:3回目    loss:0.2622954845428467
#    loaders:4回目    loss:0.1631086766719818
#    loaders:5回目    loss:0.15773728489875793
#    loaders:6回目    loss:0.2312479317188263
#    loaders:7回目    loss:0.21552564203739166
#    loaders:8回目    loss:0.17167092859745026
#    loaders:9回目    loss:0.2553894817829132
#    loaders:10回目    loss:0.12068673223257065
#    loaders:11回目    loss:0.12863092124462128
#    loaders:12回目    loss:0.4075755476951599
#    loaders:13回目    loss:0.20011672377586365
#    loaders:14回目    loss:0.019653532654047012
#    loaders:15回目    loss:0.045441459864377975
# EPOCH11回目 val Loss: 0.1930 Acc: 0.9080
# train:フェイズ
#    loaders:1回目    loss:0.0005379559006541967
#    loaders:2回目    loss:0.0003090804966632277
#    loaders:3回目    loss:0.003868635045364499
#    loaders:4回目    loss:0.01109616830945015
#    loaders:5回目    loss:0.0004934590542688966
#    loaders:6回目    loss:0.0010454986477270722
#    loaders:7回目    loss:0.0018151175463572145
#    loaders:8回目    loss:0.0003573356370907277
#    loaders:9回目    loss:0.0006182070355862379
#    loaders:10回目    loss:0.001127696828916669
#    loaders:11回目    loss:0.0012717285426333547
#    loaders:12回目    loss:0.0008972926298156381
#    loaders:13回目    loss:0.001026937272399664
#    loaders:14回目    loss:0.0007002133061178029
#    loaders:15回目    loss:0.00034360605059191585
#    loaders:16回目    loss:0.00030387562583200634
#    loaders:17回目    loss:0.005992860533297062
#    loaders:18回目    loss:0.0013127160491421819
#    loaders:19回目    loss:0.0015769462333992124
#    loaders:20回目    loss:0.007661477662622929
#    loaders:21回目    loss:0.004218122456222773
#    loaders:22回目    loss:0.0008902549743652344
#    loaders:23回目    loss:0.005627980921417475
#    loaders:24回目    loss:0.0008230197709053755
#    loaders:25回目    loss:0.0018673191079869866
#    loaders:26回目    loss:0.0015022370498627424
#    loaders:27回目    loss:0.0015856035752221942
#    loaders:28回目    loss:0.003791855415329337
#    loaders:29回目    loss:0.0002948978799395263
#    loaders:30回目    loss:0.0009907694766297936
#    loaders:31回目    loss:0.0022001650650054216
#    loaders:32回目    loss:0.005016971845179796
#    loaders:33回目    loss:0.0012313786428421736
#    loaders:34回目    loss:0.0002995814720634371
#    loaders:35回目    loss:0.00045377726200968027
#    loaders:36回目    loss:0.0004452887806110084
#    loaders:37回目    loss:0.00322283199056983
#    loaders:38回目    loss:0.002523234812542796
#    loaders:39回目    loss:0.0018315891502425075
#    loaders:40回目    loss:0.0004261141875758767
#    loaders:41回目    loss:0.0005573448725044727
#    loaders:42回目    loss:0.0011426983401179314
#    loaders:43回目    loss:0.00034759577829390764
#    loaders:44回目    loss:0.007409209385514259
#    loaders:45回目    loss:0.000724785088095814
#    loaders:46回目    loss:0.009089402854442596
#    loaders:47回目    loss:0.0008652157848700881
#    loaders:48回目    loss:0.0005994371022097766
#    loaders:49回目    loss:0.0018028415506705642
#    loaders:50回目    loss:0.0010493355803191662
#    loaders:51回目    loss:0.0003615564783103764
#    loaders:52回目    loss:0.00046857111738063395
#    loaders:53回目    loss:0.00042013844358734787
#    loaders:54回目    loss:0.0023288375232368708
#    loaders:55回目    loss:0.0011658658040687442
#    loaders:56回目    loss:0.013384564779698849
#    loaders:57回目    loss:0.000888058275450021
#    loaders:58回目    loss:0.003796989331021905
#    loaders:59回目    loss:0.008865502662956715
#    loaders:60回目    loss:0.0007831897237338126
#    loaders:61回目    loss:0.0008414507610723376
#    loaders:62回目    loss:0.00039189006201922894
# EPOCH12回目 train Loss: 0.0022 Acc: 0.9918
# val:フェイズ
#    loaders:1回目    loss:0.16891412436962128
#    loaders:2回目    loss:0.3630668818950653
#    loaders:3回目    loss:0.23376286029815674
#    loaders:4回目    loss:0.16950279474258423
#    loaders:5回目    loss:0.1755037158727646
#    loaders:6回目    loss:0.404979407787323
#    loaders:7回目    loss:0.24531160295009613
#    loaders:8回目    loss:0.16156871616840363
#    loaders:9回目    loss:0.21604762971401215
#    loaders:10回目    loss:0.13117718696594238
#    loaders:11回目    loss:0.10024292021989822
#    loaders:12回目    loss:0.2028753161430359
#    loaders:13回目    loss:0.07698918133974075
#    loaders:14回目    loss:0.012687427923083305
#    loaders:15回目    loss:0.06311631947755814
# EPOCH12回目 val Loss: 0.1744 Acc: 0.9180
# Save File original_model_12.pth
# train:フェイズ
#    loaders:1回目    loss:0.0038236158434301615
#    loaders:2回目    loss:0.0011080997064709663
#    loaders:3回目    loss:0.006237830501049757
#    loaders:4回目    loss:0.0004977989592589438
#    loaders:5回目    loss:0.0008604705799371004
#    loaders:6回目    loss:0.0008721482008695602
#    loaders:7回目    loss:0.0007955332985147834
#    loaders:8回目    loss:0.00042986677726730704
#    loaders:9回目    loss:0.00078036286868155
#    loaders:10回目    loss:0.0001679653360042721
#    loaders:11回目    loss:0.0003930609382223338
#    loaders:12回目    loss:0.0030354259070008993
#    loaders:13回目    loss:0.0005753287696279585
#    loaders:14回目    loss:0.0021081366576254368
#    loaders:15回目    loss:0.0009627197287045419
#    loaders:16回目    loss:0.01993330754339695
#    loaders:17回目    loss:0.002486272482201457
#    loaders:18回目    loss:0.002252788282930851
#    loaders:19回目    loss:0.0018521194579079747
#    loaders:20回目    loss:0.0013353102840483189
#    loaders:21回目    loss:0.0003856568073388189
#    loaders:22回目    loss:0.0017064583953469992
#    loaders:23回目    loss:0.00045201758621260524
#    loaders:24回目    loss:0.0007216562516987324
#    loaders:25回目    loss:0.0001458332408219576
#    loaders:26回目    loss:0.0005036689108237624
#    loaders:27回目    loss:0.0006501289899460971
#    loaders:28回目    loss:0.0006143843638710678
#    loaders:29回目    loss:0.0002659833407960832
#    loaders:30回目    loss:0.0005803951644338667
#    loaders:31回目    loss:0.0005041692638769746
#    loaders:32回目    loss:0.00029311300022527575
#    loaders:33回目    loss:0.0004004372749477625
#    loaders:34回目    loss:0.00467295665293932
#    loaders:35回目    loss:0.003873418550938368
#    loaders:36回目    loss:0.008632553741335869
#    loaders:37回目    loss:0.008370981551706791
#    loaders:38回目    loss:0.0012516694841906428
#    loaders:39回目    loss:0.0011558420956134796
#    loaders:40回目    loss:0.0041544074192643166
#    loaders:41回目    loss:0.005180748645216227
#    loaders:42回目    loss:0.0011440871749073267
#    loaders:43回目    loss:0.00041887833504006267
#    loaders:44回目    loss:0.001762515981681645
#    loaders:45回目    loss:0.001669843913987279
#    loaders:46回目    loss:0.0004488868871703744
#    loaders:47回目    loss:0.0007684268639422953
#    loaders:48回目    loss:0.0002704011567402631
#    loaders:49回目    loss:0.0001488528068875894
#    loaders:50回目    loss:0.0003531461115926504
#    loaders:51回目    loss:0.00059939653147012
#    loaders:52回目    loss:0.0008324781083501875
#    loaders:53回目    loss:0.0004288683121558279
#    loaders:54回目    loss:0.00017925669089891016
#    loaders:55回目    loss:0.00010593701153993607
#    loaders:56回目    loss:0.0024004336446523666
#    loaders:57回目    loss:0.00010927580296993256
#    loaders:58回目    loss:0.0008910138276405632
#    loaders:59回目    loss:0.002436679322272539
#    loaders:60回目    loss:0.00021299804211594164
#    loaders:61回目    loss:0.005172327160835266
#    loaders:62回目    loss:0.00030747195705771446
# EPOCH13回目 train Loss: 0.0019 Acc: 0.9918
# val:フェイズ
#    loaders:1回目    loss:0.14171931147575378
#    loaders:2回目    loss:0.37892869114875793
#    loaders:3回目    loss:0.23366722464561462
#    loaders:4回目    loss:0.17422959208488464
#    loaders:5回目    loss:0.13331793248653412
#    loaders:6回目    loss:0.2403120994567871
#    loaders:7回目    loss:0.18673944473266602
#    loaders:8回目    loss:0.19480933248996735
#    loaders:9回目    loss:0.31844398379325867
#    loaders:10回目    loss:0.15721441805362701
#    loaders:11回目    loss:0.027995772659778595
#    loaders:12回目    loss:0.13770431280136108
#    loaders:13回目    loss:0.07172108441591263
#    loaders:14回目    loss:0.013016746379435062
#    loaders:15回目    loss:0.04163724184036255
# EPOCH13回目 val Loss: 0.1569 Acc: 0.9180
# train:フェイズ
#    loaders:1回目    loss:0.0009340660180896521
#    loaders:2回目    loss:0.00014471556642092764
#    loaders:3回目    loss:0.0005280861514620483
#    loaders:4回目    loss:0.0006378171965479851
#    loaders:5回目    loss:0.0001679072593105957
#    loaders:6回目    loss:0.0009539322927594185
#    loaders:7回目    loss:0.0006729597225785255
#    loaders:8回目    loss:0.000858760962728411
#    loaders:9回目    loss:0.0006570197292603552
#    loaders:10回目    loss:0.0006348036113195121
#    loaders:11回目    loss:0.0005389124853536487
#    loaders:12回目    loss:0.00010634095087880269
#    loaders:13回目    loss:0.0003680093795992434
#    loaders:14回目    loss:0.0006594242295250297
#    loaders:15回目    loss:0.0006472733803093433
#    loaders:16回目    loss:0.003798768622800708
#    loaders:17回目    loss:0.0008815938490442932
#    loaders:18回目    loss:0.00011011642345692962
#    loaders:19回目    loss:0.00022566827828995883
#    loaders:20回目    loss:0.001506377593614161
#    loaders:21回目    loss:0.00488873990252614
#    loaders:22回目    loss:0.001323589705862105
#    loaders:23回目    loss:0.0002680281759239733
#    loaders:24回目    loss:0.00027117985882796347
#    loaders:25回目    loss:0.0006262268871068954
#    loaders:26回目    loss:0.00034489354584366083
#    loaders:27回目    loss:0.00023941621475387365
#    loaders:28回目    loss:0.0006286815623752773
#    loaders:29回目    loss:0.0006459582946263254
#    loaders:30回目    loss:0.0006411868962459266
#    loaders:31回目    loss:0.0002756523317657411
#    loaders:32回目    loss:0.001115119899623096
#    loaders:33回目    loss:0.0017099216347560287
#    loaders:34回目    loss:0.0006395571981556714
#    loaders:35回目    loss:0.0011896028881892562
#    loaders:36回目    loss:0.004067789297550917
#    loaders:37回目    loss:0.0012848996557295322
#    loaders:38回目    loss:0.0054209050722420216
#    loaders:39回目    loss:0.00021070969523862004
#    loaders:40回目    loss:0.000578278093598783
#    loaders:41回目    loss:0.00045515241799876094
#    loaders:42回目    loss:0.0002170701918657869
#    loaders:43回目    loss:0.0002529688645154238
#    loaders:44回目    loss:0.0003604184603318572
#    loaders:45回目    loss:0.006482189055532217
#    loaders:46回目    loss:0.00026500297826714814
#    loaders:47回目    loss:0.0005040167015977204
#    loaders:48回目    loss:0.004860909655690193
#    loaders:49回目    loss:0.000428812054451555
#    loaders:50回目    loss:0.00025033007841557264
#    loaders:51回目    loss:0.0002866248833015561
#    loaders:52回目    loss:0.0005966249736957252
#    loaders:53回目    loss:0.00281551037915051
#    loaders:54回目    loss:0.0003239632351323962
#    loaders:55回目    loss:0.0002328450937056914
#    loaders:56回目    loss:0.0010699932463467121
#    loaders:57回目    loss:0.004892305471003056
#    loaders:58回目    loss:0.00407451530918479
#    loaders:59回目    loss:0.0011788841802626848
#    loaders:60回目    loss:0.0004921684158034623
#    loaders:61回目    loss:0.00019984347454737872
#    loaders:62回目    loss:0.002055408200249076
# EPOCH14回目 train Loss: 0.0012 Acc: 0.9920
# val:フェイズ
#    loaders:1回目    loss:0.12245657294988632
#    loaders:2回目    loss:0.32334980368614197
#    loaders:3回目    loss:0.18545430898666382
#    loaders:4回目    loss:0.14412780106067657
#    loaders:5回目    loss:0.11502179503440857
#    loaders:6回目    loss:0.2128375619649887
#    loaders:7回目    loss:0.17284032702445984
#    loaders:8回目    loss:0.18331830203533173
#    loaders:9回目    loss:0.3644179105758667
#    loaders:10回目    loss:0.18353497982025146
#    loaders:11回目    loss:0.04061737284064293
#    loaders:12回目    loss:0.18229420483112335
#    loaders:13回目    loss:0.08599025756120682
#    loaders:14回目    loss:0.013160817325115204
#    loaders:15回目    loss:0.054667502641677856
# EPOCH14回目 val Loss: 0.1526 Acc: 0.9220
# Save File original_model_14.pth
# Best val Acc: 0.922000
# [0.80425 0.9205  0.961   0.97575 0.97625 0.97925 0.982   0.985   0.98475
#  0.991   0.991   0.9915  0.99175 0.99175 0.992  ]
# [0.823 0.856 0.867 0.894 0.875 0.889 0.902 0.909 0.904 0.9   0.916 0.908
#  0.918 0.918 0.922]

# %%
#学習したモデルを使ってtestデータの推論を実施
import pandas as pd
import os
import zipfile
import torch
import torch.nn as nn
import torch.optim as optim
import albumentations
from torch.utils.data import Dataset
from torchvision import datasets, models, transforms
from PIL import Image, ImageFilter

work_dir           = '/content/sample_data'
save_dir           = '/content/drive/MyDrive/2024_AIContest2/Thema1/'
test_zip_file_path = '/content/sample_data/test_images.zip'
test_file_dir      = os.path.join(work_dir, 'test_images')
report_format_tsv  = os.path.join(work_dir, 'sample_submit.tsv')
best_model_path    = os.path.join(save_dir, 'pth/20250403_1137_original_model_5.pth')
output_file        = os.path.join(save_dir, 'output/20250402_out_submit_4.tsv')

TARGET_NUM = 10

# ZIPファイルを解凍する
def extract_zip(zip_file_path, extract_to):

    if not os.path.exists(test_file_dir):
        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            zip_ref.extractall(extract_to)

extract_zip(test_zip_file_path, work_dir)

#dataサイズ定義
dataset_sizes= {
    'train':len(image_datasets['train']),
    'val':len(image_datasets['val'])
}

#submit用dataset定義
class For_Submission_Datasets(Dataset):

    def __init__(self, data_transform):
        self.df = pd.read_csv(report_format_tsv ,sep='\t',names=['filename','target'])
        self.data_transform = data_transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):
        file = self.df['filename'][index]
        image = Image.open(test_file_dir +'/'+ file)
        image = self.data_transform(image)

        return image,file

#submit用dataset作成
subdataset = For_Submission_Datasets(data_transform=data_transforms['val'])

#submit用dataloaders作成
subdataloader = torch.utils.data.DataLoader(subdataset, batch_size=1, shuffle=False, num_workers=0, drop_last=True)

#精度の最も高いモデルをロード
#モデルの名前を適宜変更して、最も精度の高いモデルをロードしましょう
best_model = get_model(target_num = TARGET_NUM)
best_model.load_state_dict(torch.load(best_model_path, map_location=lambda storage, loc: storage), strict=True)

submit = pd.read_csv(report_format_tsv,sep='\t', header=None)
#print(submit)
#テストデータに対しての推論
pred = []
for i,(inputs, labels) in enumerate(subdataloader):
    inputs = inputs.to(DEVICE)
    best_model.eval()
    outputs = best_model(inputs)
    _, preds = torch.max(outputs, 1)
    pred.append(preds.item())

df_test = pd.read_csv(report_format_tsv ,sep='\t',names=['filename','target'])

df_test['pred'] = pred
#print(df_test)
submit[1] = pred

submit.to_csv(output_file ,sep='\t', index=False, header=False)
print(submit)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#                   0  1
# 0        test_0.jpg  6
# 1        test_1.jpg  7
# 2        test_2.jpg  5
# 3        test_3.jpg  0
# 4        test_4.jpg  3
# ...             ... ..
# 7995  test_7995.jpg  9
# 7996  test_7996.jpg  6
# 7997  test_7997.jpg  8
# 7998  test_7998.jpg  8
# 7999  test_7999.jpg  8
#
# [8000 rows x 2 columns]

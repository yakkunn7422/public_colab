# %% [markdown]
# <a href="https://colab.research.google.com/github/yakkunn7422/public_colab/blob/main/2024_AIC2_thema1_main6_resnet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Googleドライブのマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -fr /content/sample_data/new_train_images
# !rm -fr /content/sample_data/test_images.zip
# !rm -fr /content/sample_data/train_images.zip
# !rm -fr /content/sample_data/train_master.tsv
# !rm -fr /content/sample_data/sample_submit.tsv
# !rm -fr /content/sample_data/resnet18-5c106cde.pth
# !rm -fr /content/sample_data/label_master.tsv

# %%
import os
import re
from datetime import datetime

# 対象のディレクトリパス
directory_path = 'drive/MyDrive/2024_AIContest2/Thema1/pth'

# ファイル名のパターン
file_pattern = r"original_model_(\d+)\.pth"

# 現在の日付と時間を取得 (yyyymmdd_hhmm)
current_time = datetime.now().strftime("%Y%m%d_%H%M")

# 最大のXXを持つファイルを特定
max_number = -1
file_to_keep = None

# ディレクトリ内のファイルを走査
for file_name in os.listdir(directory_path):
    file_path = os.path.join(directory_path, file_name)

    # 正規表現でファイル名が "original_model_XX.pth" 形式かチェック
    match = re.match(file_pattern, file_name)
    if match:
        number = int(match.group(1))  # XX部分を取得
        if number > max_number:
            max_number = number
            file_to_keep = file_name

# 最も大きい数字を持つファイルに接頭辞を付けてリネーム
if file_to_keep:
    new_file_name = f"{current_time}_{file_to_keep}"
    new_file_path = os.path.join(directory_path, new_file_name)
    os.rename(os.path.join(directory_path, file_to_keep), new_file_path)
    print(f"{file_to_keep} は {new_file_name} にリネームされました。")

# ディレクトリ内のファイルを再度走査して、不要なファイルを削除
for file_name in os.listdir(directory_path):
    file_path = os.path.join(directory_path, file_name)

    # "original_model_XX.pth" 形式のファイルを削除
    match = re.match(file_pattern, file_name)
    if match and file_name != new_file_name:
        try:
            os.remove(file_path)
            print(f"{file_path} は削除されました。")
        except FileNotFoundError:
            print(f"{file_path} は見つかりませんでした。")
        except PermissionError:
            print(f"{file_path} の削除に必要な権限がありません。")
        except Exception as e:
            print(f"{file_path} の削除中にエラーが発生しました: {e}")
# Out:
# original_model_5.pth は 20250403_1137_original_model_5.pth にリネームされました。
# drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_0.pth は削除されました。
# drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_1.pth は削除されました。
# drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_2.pth は削除されました。
# drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_3.pth は削除されました。
# drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_4.pth は削除されました。

# %%
import os
print("カレントワーキングディレクトリは[" + os.getcwd() + "]です")
# Out:
# カレントワーキングディレクトリは[/content]です

# %%
# sample_data 配下にResnet18使う際のデータ一式を持ってくるコード

import os
import pandas as pd
import zipfile
import shutil
import numpy as np

#パラメータ
TRAIN_RATIO = 0.8



#trainイメージファイル、testイメージファイル等のファイル格納先
input_dir = '/content/drive/MyDrive/2024_AIContest2/Thema1'
work_dir =  '/content/sample_data'

#trainデータの解凍・成形先のディレクトリ
output_dir = os.path.join(work_dir, 'new_train_images')

#trainデータファイル名
zip_file_path = os.path.join(work_dir, 'train_images.zip')
#trainデータのラベルまとめファイル名
tsv_file_path = os.path.join(work_dir, 'train_master.tsv')

# ファイルをCOPYする
def simple_copy_files(src_dir, dst_dir):
    os.makedirs(dst_dir, exist_ok=True)  # コピー先ディレクトリを作成（既に存在する場合は何もしない）

    for file_name in os.listdir(src_dir):
        full_file_name = os.path.join(src_dir, file_name)
        if os.path.isfile(full_file_name):
            shutil.copy2(full_file_name, dst_dir)  # ファイルのコピー

# トレインとバリデーション用のディレクトリおよびその中のラベルごとのサブディレクトリを作成する
def create_directories(base_dir, labels):

    train_dir = os.path.join(base_dir, 'train')
    val_dir = os.path.join(base_dir, 'val')

    for dir_path in [train_dir, val_dir]:
        if not os.path.exists(dir_path):
            os.makedirs(dir_path)

    for label in labels:
        os.makedirs(os.path.join(train_dir, str(label)), exist_ok=True)
        os.makedirs(os.path.join(val_dir, str(label)), exist_ok=True)

    return train_dir, val_dir

# ZIPファイルを解凍する
def extract_zip(zip_file_path, extract_to):

    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)

# TSVファイルを読み込み、1行目を削除してデータフレームを準備する
def load_and_prepare_data(tsv_file_path):

    df = pd.read_csv(tsv_file_path, sep='\t', names=['filename', 'label_id'])
    df = df.iloc[1:].reset_index(drop=True)

    return df

# 画像ファイルをディレクトリに分配する
def distribute_images(df, image_dir, train_dir, val_dir, train_ratio=0.8):

    for label in df['label_id'].unique():
        label_images = df[df['label_id'] == label]['filename'].tolist()
        # シャッフルして分割

        np.random.shuffle(label_images)
        train_size = int(len(label_images) * train_ratio)
        train_images = label_images[:train_size]
        val_images = label_images[train_size:]

        for image_name in train_images:
            src_path = os.path.join(image_dir, image_name)
            dst_path = os.path.join(train_dir, str(label), image_name)
            shutil.copy(src_path, dst_path)

        for image_name in val_images:
            src_path = os.path.join(image_dir, image_name)
            dst_path = os.path.join(val_dir, str(label), image_name)
            shutil.copy(src_path, dst_path)

# ディレクトリ内のアイテムを探索し数を表示する
def count_files_recursive(directory):
    total_files = 0

    for root, dirs, files in os.walk(directory):
        files_count = len(files)
        subdir_relative = os.path.relpath(root, directory)
        print(f"Directory '{subdir_relative}' contains {files_count} files.")

        total_files += files_count

    print(f"Total files in '{directory}': {total_files}")

# メイン処理を実行する関数
def main(zip_file_path, tsv_file_path, output_dir, train_ratio=0.8):

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    df = load_and_prepare_data(tsv_file_path)

    extract_zip(zip_file_path, output_dir)

    labels = df['label_id'].unique()

    train_dir, val_dir = create_directories(output_dir, labels)
    image_dir = os.path.join(output_dir, 'train_images')

    distribute_images(df, image_dir, train_dir, val_dir, train_ratio)

    # 解凍後のディレクトリを削除
    if os.path.exists(image_dir):
        shutil.rmtree(image_dir)
        print(f"Deleted temporary directory: {image_dir}")

# 実行
# INPUTディレクトリのファイルをOUTPUTディレクトリにすべてCOPY
simple_copy_files(input_dir,work_dir)
# Train.zipファイル内の画像をtrain、val毎(割合い0.8)かつラベル毎のディレクトリに配置
main(zip_file_path, tsv_file_path, output_dir, train_ratio = TRAIN_RATIO)

count_files_recursive(output_dir)
# Out:
# Deleted temporary directory: /content/sample_data/new_train_images/train_images
# Directory '.' contains 0 files.
# Directory 'train' contains 0 files.
# Directory 'train/6' contains 400 files.
# Directory 'train/7' contains 400 files.
# Directory 'train/2' contains 400 files.
# Directory 'train/3' contains 400 files.
# Directory 'train/9' contains 400 files.
# Directory 'train/0' contains 400 files.
# Directory 'train/5' contains 400 files.
# Directory 'train/8' contains 400 files.
# Directory 'train/4' contains 400 files.
# Directory 'train/1' contains 400 files.
# Directory 'val' contains 0 files.
# Directory 'val/6' contains 100 files.
# Directory 'val/7' contains 100 files.
# Directory 'val/2' contains 100 files.
# Directory 'val/3' contains 100 files.
# Directory 'val/9' contains 100 files.
# Directory 'val/0' contains 100 files.
# Directory 'val/5' contains 100 files.
# Directory 'val/8' contains 100 files.
# Directory 'val/4' contains 100 files.
# Directory 'val/1' contains 100 files.
# Total files in '/content/sample_data/new_train_images': 5000

# %%
# Resnet50で学習
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import zipfile
import torch
import torch.nn as nn
import torch.optim as optim
import albumentations
from torch.utils.data import Dataset, ConcatDataset
from torchvision import datasets, models, transforms
from PIL import Image, ImageFilter

input_dir = '/content/drive/MyDrive/2024_AIContest2/Thema1'
work_dir =  '/content/sample_data'


#定数設定
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
TARGET_NUM = 10
BATCH_SIZE = 64
LEARNING_RATE = 0.005
EPOCH = 25
TRANSFER_LEARNING = True
MODEL_LEARNING = True

#transforms定義
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(256),
        transforms.GaussianBlur(kernel_size=5, sigma=(0.1, 2.0)),
        transforms.RandomRotation(degrees=(-45, 45)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
    'train_flipped': transforms.Compose([
        transforms.Resize(256),
        transforms.RandomHorizontalFlip(p=1.0),  # 常に反転
        transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
}

# dataset追加対応
# --- ここから
train_dataset = datasets.ImageFolder('/content/sample_data/new_train_images/train', data_transforms['train'])
train_dataset_flipped = datasets.ImageFolder('/content/sample_data/new_train_images/train', data_transforms['train_flipped'])

# 元のデータセットと反転データセットを結合
combined_train_dataset = ConcatDataset([train_dataset, train_dataset_flipped])

image_datasets = {
    'train': combined_train_dataset,  # 結合されたデータセットを使用
    'val': datasets.ImageFolder('/content/sample_data/new_train_images/val', data_transforms['val']),
}
# --- ここまで
#dataset作成(旧)
#image_datasets = {
#    'train': datasets.ImageFolder('/content/sample_data/new_train_images/train',data_transforms['train']),
#    'val': datasets.ImageFolder('/content/sample_data/new_train_images/val',data_transforms['val'])
#}

#dataloaders作成
image_dataloaders = {
    'train': torch.utils.data.DataLoader(image_datasets['train'], batch_size=BATCH_SIZE, shuffle=True, num_workers=0, drop_last=True),
    'val': torch.utils.data.DataLoader(image_datasets['val'], batch_size=BATCH_SIZE, shuffle=False, num_workers=0, drop_last=True),
}

#dataサイズ定義
dataset_sizes= {
    'train':len(image_datasets['train']),
    'val':len(image_datasets['val'])
}

#ResNet50モデル定義
def get_model(target_num,isPretrained=False):

    if(isPretrained):
        model_ft = models.resnet50(pretrained=False)
        model_ft.load_state_dict(torch.load(os.path.join(work_dir, '/content/sample_data/resnet50-19c8e357.pth'), map_location=lambda storage, loc: storage,weights_only=False), strict=True)
    else:
        model_ft = models.resnet50(pretrained=False)

    model_ft.fc = nn.Linear(2048, target_num)
    model_ft = model_ft.to(DEVICE)
    return model_ft

if not MODEL_LEARNING:
    print("処理を停止します。")
    sys.exit()  # プログラムを終了

#モデルのインスタンス作成 転移学習なし（FALSE）
model_ft = get_model(target_num=TARGET_NUM,isPretrained=TRANSFER_LEARNING)

#最適化関数定義
optimizer = optim.SGD(model_ft.parameters(),lr=LEARNING_RATE, momentum=0.9)

#loss関数定義
criterion = nn.CrossEntropyLoss()

#モデル訓練用関数
def train_model(model, criterion, optimizer, num_epochs=5,is_saved = False):
    best_acc = 0.0


    train_arr1 = np.zeros(EPOCH)
    val_arr1   = np.zeros(EPOCH)

    # エポック数だけ下記工程の繰り返し
    for epoch in range(num_epochs):

        for phase in ['train', 'val']:
            print('{}:フェイズ'.format(phase))

            # 訓練フェイズと検証フェイズの切り替え
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            # dataloadersからバッチサイズだけデータ取り出し、下記工程（1−5）の繰り返し
            for i,(inputs, labels) in enumerate(image_dataloaders[phase]):
                inputs = inputs.to(DEVICE)
                labels = labels.to(DEVICE)

                # 1. optimizerの勾配初期化
                optimizer.zero_grad()

                # 2.モデルに入力データをinputし、outputを取り出す
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)

                # 3. outputと正解ラベルから、lossを算出
                loss = criterion(outputs, labels)
                print('   loaders:{}回目'.format(i+1)  ,'   loss:{}'.format(loss))

                if phase == 'train':
                    # 4. 誤差逆伝播法により勾配の算出
                    loss.backward()
                    # 5. optimizerのパラメータ更新
                    optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            print('EPOCH{}回目 {} Loss: {:.4f} Acc: {:.4f}'.format(epoch, phase, epoch_loss, epoch_acc))

            if phase == 'train':
                train_arr1[epoch]=epoch_acc
            else:
                val_arr1[epoch]=epoch_acc

            # C. 今までのエポックでの精度よりも高い場合はモデルの保存
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                if(is_saved):
                    print('Save File original_model_{}.pth'.format(epoch))
                    torch.save(model.state_dict(), '/content/drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_{}.pth'.format(epoch))


    print('Best val Acc: {:4f}'.format(best_acc))
    print(train_arr1)
    print(val_arr1)
    train_ser1 = pd.Series(train_arr1,name='train_acc')
    result_data = pd.DataFrame(train_ser1)
    result_data['val_acc']=val_arr1
    result_data.plot()
    plt.show()

train_model(model = model_ft,criterion = criterion,optimizer = optimizer,num_epochs=EPOCH,is_saved = True)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# train:フェイズ
#    loaders:1回目    loss:2.405517339706421
#    loaders:2回目    loss:2.3796496391296387
#    loaders:3回目    loss:2.23239803314209
#    loaders:4回目    loss:2.221088409423828
#    loaders:5回目    loss:2.2020814418792725
#    loaders:6回目    loss:2.257639169692993
#    loaders:7回目    loss:2.1317331790924072
#    loaders:8回目    loss:2.103829860687256
#    loaders:9回目    loss:1.9822025299072266
#    loaders:10回目    loss:1.947999358177185
#    loaders:11回目    loss:1.8665670156478882
#    loaders:12回目    loss:1.901815414428711
#    loaders:13回目    loss:1.6363177299499512
#    loaders:14回目    loss:1.5737794637680054
#    loaders:15回目    loss:1.508798360824585
#    loaders:16回目    loss:1.3088319301605225
#    loaders:17回目    loss:1.225370168685913
#    loaders:18回目    loss:1.2607849836349487
#    loaders:19回目    loss:1.118344783782959
#    loaders:20回目    loss:0.953860878944397
#    loaders:21回目    loss:0.8995571732521057
#    loaders:22回目    loss:0.8479165434837341
#    loaders:23回目    loss:0.7612488865852356
#    loaders:24回目    loss:0.6661155819892883
#    loaders:25回目    loss:0.6718220114707947
#    loaders:26回目    loss:0.6903448700904846
#    loaders:27回目    loss:0.553779125213623
#    loaders:28回目    loss:0.5710547566413879
#    loaders:29回目    loss:0.49726250767707825
#    loaders:30回目    loss:0.518589198589325
#    loaders:31回目    loss:0.46836918592453003
#    loaders:32回目    loss:0.5518800616264343
#    loaders:33回目    loss:0.5105459094047546
#    loaders:34回目    loss:0.3160434663295746
#    loaders:35回目    loss:0.5314147472381592
#    loaders:36回目    loss:0.322064608335495
#    loaders:37回目    loss:0.4765959084033966
#    loaders:38回目    loss:0.4386313855648041
#    loaders:39回目    loss:0.46518003940582275
#    loaders:40回目    loss:0.49868857860565186
#    loaders:41回目    loss:0.5135268568992615
#    loaders:42回目    loss:0.35673126578330994
#    loaders:43回目    loss:0.5748785734176636
#    loaders:44回目    loss:0.326551616191864
#    loaders:45回目    loss:0.44812992215156555
#    loaders:46回目    loss:0.42547672986984253
#    loaders:47回目    loss:0.2593671679496765
#    loaders:48回目    loss:0.3944409191608429
#    loaders:49回目    loss:0.23359562456607819
#    loaders:50回目    loss:0.2281176596879959
#    loaders:51回目    loss:0.4247281551361084
#    loaders:52回目    loss:0.32002338767051697
#    loaders:53回目    loss:0.225058451294899
#    loaders:54回目    loss:0.2994442582130432
#    loaders:55回目    loss:0.3031872808933258
#    loaders:56回目    loss:0.5634132027626038
#    loaders:57回目    loss:0.29543545842170715
#    loaders:58回目    loss:0.26982924342155457
#    loaders:59回目    loss:0.29637840390205383
#    loaders:60回目    loss:0.32535606622695923
#    loaders:61回目    loss:0.3012261986732483
#    loaders:62回目    loss:0.2441413551568985
#    loaders:63回目    loss:0.5020033121109009
#    loaders:64回目    loss:0.345230370759964
#    loaders:65回目    loss:0.38973093032836914
#    loaders:66回目    loss:0.27845409512519836
#    loaders:67回目    loss:0.45442596077919006
#    loaders:68回目    loss:0.3834334909915924
#    loaders:69回目    loss:0.24820174276828766
#    loaders:70回目    loss:0.33908382058143616
#    loaders:71回目    loss:0.4382222890853882
#    loaders:72回目    loss:0.26489731669425964
#    loaders:73回目    loss:0.32593220472335815
#    loaders:74回目    loss:0.36717894673347473
#    loaders:75回目    loss:0.23666301369667053
#    loaders:76回目    loss:0.33181795477867126
#    loaders:77回目    loss:0.324779748916626
#    loaders:78回目    loss:0.30271250009536743
#    loaders:79回目    loss:0.32147032022476196
#    loaders:80回目    loss:0.2756757140159607
#    loaders:81回目    loss:0.36296913027763367
#    loaders:82回目    loss:0.41930103302001953
#    loaders:83回目    loss:0.20060355961322784
#    loaders:84回目    loss:0.2859657108783722
#    loaders:85回目    loss:0.32583826780319214
#    loaders:86回目    loss:0.33264854550361633
#    loaders:87回目    loss:0.29169702529907227
#    loaders:88回目    loss:0.4327445328235626
#    loaders:89回目    loss:0.4016994833946228
#    loaders:90回目    loss:0.3288942277431488
#    loaders:91回目    loss:0.3688090145587921
#    loaders:92回目    loss:0.4915854036808014
#    loaders:93回目    loss:0.244557186961174
#    loaders:94回目    loss:0.29165422916412354
#    loaders:95回目    loss:0.1942201852798462
#    loaders:96回目    loss:0.19206269085407257
#    loaders:97回目    loss:0.3830808699131012
#    loaders:98回目    loss:0.4046795964241028
#    loaders:99回目    loss:0.30290961265563965
#    loaders:100回目    loss:0.1710508167743683
#    loaders:101回目    loss:0.2877407371997833
#    loaders:102回目    loss:0.15950129926204681
#    loaders:103回目    loss:0.3658481240272522
#    loaders:104回目    loss:0.3251194357872009
#    loaders:105回目    loss:0.19618043303489685
#    loaders:106回目    loss:0.3022826313972473
#    loaders:107回目    loss:0.2788497507572174
#    loaders:108回目    loss:0.28257033228874207
#    loaders:109回目    loss:0.2718736231327057
#    loaders:110回目    loss:0.44424566626548767
#    loaders:111回目    loss:0.16316567361354828
#    loaders:112回目    loss:0.3420799672603607
#    loaders:113回目    loss:0.2295803427696228
#    loaders:114回目    loss:0.28534483909606934
#    loaders:115回目    loss:0.27092695236206055
#    loaders:116回目    loss:0.19535839557647705
#    loaders:117回目    loss:0.3802107274532318
#    loaders:118回目    loss:0.19060026109218597
#    loaders:119回目    loss:0.4504506587982178
#    loaders:120回目    loss:0.6509634256362915
#    loaders:121回目    loss:0.30442342162132263
#    loaders:122回目    loss:0.22329509258270264
#    loaders:123回目    loss:0.20759163796901703
#    loaders:124回目    loss:0.34098929166793823
#    loaders:125回目    loss:0.2573094964027405
# EPOCH0回目 train Loss: 0.6005 Acc: 0.7970
# val:フェイズ
#    loaders:1回目    loss:0.16922223567962646
#    loaders:2回目    loss:0.21263888478279114
#    loaders:3回目    loss:0.3230796754360199
#    loaders:4回目    loss:0.1423528641462326
#    loaders:5回目    loss:0.03580746427178383
#    loaders:6回目    loss:0.29386472702026367
#    loaders:7回目    loss:0.2409331202507019
#    loaders:8回目    loss:0.46546968817710876
#    loaders:9回目    loss:0.26569095253944397
#    loaders:10回目    loss:0.17542357742786407
#    loaders:11回目    loss:0.09663081169128418
#    loaders:12回目    loss:0.3659086227416992
#    loaders:13回目    loss:0.22667577862739563
#    loaders:14回目    loss:0.05643957853317261
#    loaders:15回目    loss:0.1531532257795334
# EPOCH0回目 val Loss: 0.2063 Acc: 0.8880
# Save File original_model_0.pth
# train:フェイズ
#    loaders:1回目    loss:0.32053062319755554
#    loaders:2回目    loss:0.20611855387687683
#    loaders:3回目    loss:0.15762802958488464
#    loaders:4回目    loss:0.2605930268764496
#    loaders:5回目    loss:0.22067172825336456
#    loaders:6回目    loss:0.23637834191322327
#    loaders:7回目    loss:0.15179958939552307
#    loaders:8回目    loss:0.18012529611587524
#    loaders:9回目    loss:0.09174986183643341
#    loaders:10回目    loss:0.15937896072864532
#    loaders:11回目    loss:0.06212366744875908
#    loaders:12回目    loss:0.26315465569496155
#    loaders:13回目    loss:0.1561594009399414
#    loaders:14回目    loss:0.16771894693374634
#    loaders:15回目    loss:0.23731453716754913
#    loaders:16回目    loss:0.2424788475036621
#    loaders:17回目    loss:0.14255502820014954
#    loaders:18回目    loss:0.15170137584209442
#    loaders:19回目    loss:0.13584761321544647
#    loaders:20回目    loss:0.2501000165939331
#    loaders:21回目    loss:0.21506159007549286
#    loaders:22回目    loss:0.3215186297893524
#    loaders:23回目    loss:0.1704765111207962
#    loaders:24回目    loss:0.16186176240444183
#    loaders:25回目    loss:0.2825149893760681
#    loaders:26回目    loss:0.16692273318767548
#    loaders:27回目    loss:0.20460361242294312
#    loaders:28回目    loss:0.09809215366840363
#    loaders:29回目    loss:0.11706029623746872
#    loaders:30回目    loss:0.22993908822536469
#    loaders:31回目    loss:0.17037610709667206
#    loaders:32回目    loss:0.10080555081367493
#    loaders:33回目    loss:0.21676039695739746
#    loaders:34回目    loss:0.23739376664161682
#    loaders:35回目    loss:0.16251103579998016
#    loaders:36回目    loss:0.08440200239419937
#    loaders:37回目    loss:0.14055845141410828
#    loaders:38回目    loss:0.25822752714157104
#    loaders:39回目    loss:0.1833980530500412
#    loaders:40回目    loss:0.19704751670360565
#    loaders:41回目    loss:0.28858482837677
#    loaders:42回目    loss:0.09360470622777939
#    loaders:43回目    loss:0.09831122308969498
#    loaders:44回目    loss:0.08358430117368698
#    loaders:45回目    loss:0.07314502447843552
#    loaders:46回目    loss:0.19863620400428772
#    loaders:47回目    loss:0.12926897406578064
#    loaders:48回目    loss:0.17131873965263367
#    loaders:49回目    loss:0.05248018354177475
#    loaders:50回目    loss:0.16940569877624512
#    loaders:51回目    loss:0.14076343178749084
#    loaders:52回目    loss:0.19772975146770477
#    loaders:53回目    loss:0.100196473300457
#    loaders:54回目    loss:0.14369939267635345
#    loaders:55回目    loss:0.04162200912833214
#    loaders:56回目    loss:0.19715337455272675
#    loaders:57回目    loss:0.10719384998083115
#    loaders:58回目    loss:0.11503760516643524
#    loaders:59回目    loss:0.1993517428636551
#    loaders:60回目    loss:0.12407948076725006
#    loaders:61回目    loss:0.0945187583565712
#    loaders:62回目    loss:0.16642072796821594
#    loaders:63回目    loss:0.16487672924995422
#    loaders:64回目    loss:0.1495339274406433
#    loaders:65回目    loss:0.12542769312858582
#    loaders:66回目    loss:0.06729718297719955
#    loaders:67回目    loss:0.15960758924484253
#    loaders:68回目    loss:0.17448726296424866
#    loaders:69回目    loss:0.1758025735616684
#    loaders:70回目    loss:0.08041384816169739
#    loaders:71回目    loss:0.0805647149682045
#    loaders:72回目    loss:0.07373983412981033
#    loaders:73回目    loss:0.17055651545524597
#    loaders:74回目    loss:0.10308416932821274
#    loaders:75回目    loss:0.05732782930135727
#    loaders:76回目    loss:0.17288215458393097
#    loaders:77回目    loss:0.19288820028305054
#    loaders:78回目    loss:0.11185049265623093
#    loaders:79回目    loss:0.1626509577035904
#    loaders:80回目    loss:0.19645816087722778
#    loaders:81回目    loss:0.08972591161727905
#    loaders:82回目    loss:0.18951033055782318
#    loaders:83回目    loss:0.07629547268152237
#    loaders:84回目    loss:0.20765797793865204
#    loaders:85回目    loss:0.1957622617483139
#    loaders:86回目    loss:0.16829374432563782
#    loaders:87回目    loss:0.10747738182544708
#    loaders:88回目    loss:0.03775697946548462
#    loaders:89回目    loss:0.12789802253246307
#    loaders:90回目    loss:0.18024225533008575
#    loaders:91回目    loss:0.08214583247900009
#    loaders:92回目    loss:0.10469206422567368
#    loaders:93回目    loss:0.2035655528306961
#    loaders:94回目    loss:0.13020294904708862
#    loaders:95回目    loss:0.19030191004276276
#    loaders:96回目    loss:0.05569673329591751
#    loaders:97回目    loss:0.2798621356487274
#    loaders:98回目    loss:0.14802992343902588
#    loaders:99回目    loss:0.13609819114208221
#    loaders:100回目    loss:0.09389539808034897
#    loaders:101回目    loss:0.16247496008872986
#    loaders:102回目    loss:0.08875218033790588
#    loaders:103回目    loss:0.09746673703193665
#    loaders:104回目    loss:0.062220994383096695
#    loaders:105回目    loss:0.07548905909061432
#    loaders:106回目    loss:0.1653011590242386
#    loaders:107回目    loss:0.16228178143501282
#    loaders:108回目    loss:0.07782585173845291
#    loaders:109回目    loss:0.20167334377765656
#    loaders:110回目    loss:0.13779225945472717
#    loaders:111回目    loss:0.14806154370307922
#    loaders:112回目    loss:0.05648207291960716
#    loaders:113回目    loss:0.12051718682050705
#    loaders:114回目    loss:0.1534743309020996
#    loaders:115回目    loss:0.08858812600374222
#    loaders:116回目    loss:0.13193780183792114
#    loaders:117回目    loss:0.11955717206001282
#    loaders:118回目    loss:0.07487984746694565
#    loaders:119回目    loss:0.10403986275196075
#    loaders:120回目    loss:0.1862844079732895
#    loaders:121回目    loss:0.12715978920459747
#    loaders:122回目    loss:0.22924403846263885
#    loaders:123回目    loss:0.07650695741176605
#    loaders:124回目    loss:0.15175370872020721
#    loaders:125回目    loss:0.15611159801483154
# EPOCH1回目 train Loss: 0.1510 Acc: 0.9511
# val:フェイズ
#    loaders:1回目    loss:0.09237372875213623
#    loaders:2回目    loss:0.08989309519529343
#    loaders:3回目    loss:0.14295412600040436
#    loaders:4回目    loss:0.048018984496593475
#    loaders:5回目    loss:0.042921945452690125
#    loaders:6回目    loss:0.5811974406242371
#    loaders:7回目    loss:0.3366166651248932
#    loaders:8回目    loss:0.22959914803504944
#    loaders:9回目    loss:0.19217506051063538
#    loaders:10回目    loss:0.2032126486301422
#    loaders:11回目    loss:0.1615789830684662
#    loaders:12回目    loss:0.13369041681289673
#    loaders:13回目    loss:0.11333400756120682
#    loaders:14回目    loss:0.030516766011714935
#    loaders:15回目    loss:0.30451107025146484
# EPOCH1回目 val Loss: 0.1730 Acc: 0.9040
# Save File original_model_1.pth
# train:フェイズ
#    loaders:1回目    loss:0.13645020127296448
#    loaders:2回目    loss:0.11990934610366821
#    loaders:3回目    loss:0.15055815875530243
#    loaders:4回目    loss:0.167829692363739
#    loaders:5回目    loss:0.24819308519363403
#    loaders:6回目    loss:0.08405215293169022
#    loaders:7回目    loss:0.09219890087842941
#    loaders:8回目    loss:0.059732116758823395
#    loaders:9回目    loss:0.010741029866039753
#    loaders:10回目    loss:0.1268835961818695
#    loaders:11回目    loss:0.07841141521930695
#    loaders:12回目    loss:0.14026713371276855
#    loaders:13回目    loss:0.15783394873142242
#    loaders:14回目    loss:0.1056288480758667
#    loaders:15回目    loss:0.05014239624142647
#    loaders:16回目    loss:0.05886410176753998
#    loaders:17回目    loss:0.047901783138513565
#    loaders:18回目    loss:0.2998158633708954
#    loaders:19回目    loss:0.170491024851799
#    loaders:20回目    loss:0.04060880467295647
#    loaders:21回目    loss:0.17719586193561554
#    loaders:22回目    loss:0.0414237454533577
#    loaders:23回目    loss:0.08873620629310608
#    loaders:24回目    loss:0.10445135086774826
#    loaders:25回目    loss:0.0865364745259285
#    loaders:26回目    loss:0.17412306368350983
#    loaders:27回目    loss:0.1283106952905655
#    loaders:28回目    loss:0.11531937122344971
#    loaders:29回目    loss:0.0709931030869484
#    loaders:30回目    loss:0.08326581865549088
#    loaders:31回目    loss:0.06249140948057175
#    loaders:32回目    loss:0.02222621999680996
#    loaders:33回目    loss:0.10833269357681274
#    loaders:34回目    loss:0.05777360498905182
#    loaders:35回目    loss:0.1930750012397766
#    loaders:36回目    loss:0.14525079727172852
#    loaders:37回目    loss:0.14916518330574036
#    loaders:38回目    loss:0.09863495826721191
#    loaders:39回目    loss:0.10495167970657349
#    loaders:40回目    loss:0.02502608299255371
#    loaders:41回目    loss:0.1652751863002777
#    loaders:42回目    loss:0.15552692115306854
#    loaders:43回目    loss:0.04769790917634964
#    loaders:44回目    loss:0.04972916096448898
#    loaders:45回目    loss:0.13387420773506165
#    loaders:46回目    loss:0.16857492923736572
#    loaders:47回目    loss:0.1582278162240982
#    loaders:48回目    loss:0.0706210657954216
#    loaders:49回目    loss:0.05438964068889618
#    loaders:50回目    loss:0.08233208954334259
#    loaders:51回目    loss:0.3052358627319336
#    loaders:52回目    loss:0.06215335428714752
#    loaders:53回目    loss:0.06919914484024048
#    loaders:54回目    loss:0.09744774550199509
#    loaders:55回目    loss:0.045604072511196136
#    loaders:56回目    loss:0.06057491898536682
#    loaders:57回目    loss:0.10175177454948425
#    loaders:58回目    loss:0.1415097713470459
#    loaders:59回目    loss:0.2813822031021118
#    loaders:60回目    loss:0.08586666733026505
#    loaders:61回目    loss:0.15036806464195251
#    loaders:62回目    loss:0.2156323939561844
#    loaders:63回目    loss:0.1170104518532753
#    loaders:64回目    loss:0.0973912924528122
#    loaders:65回目    loss:0.0556262731552124
#    loaders:66回目    loss:0.14420005679130554
#    loaders:67回目    loss:0.08595257252454758
#    loaders:68回目    loss:0.21176545321941376
#    loaders:69回目    loss:0.18949761986732483
#    loaders:70回目    loss:0.09900078922510147
#    loaders:71回目    loss:0.039762917906045914
#    loaders:72回目    loss:0.13406595587730408
#    loaders:73回目    loss:0.033734407275915146
#    loaders:74回目    loss:0.06806065887212753
#    loaders:75回目    loss:0.14180217683315277
#    loaders:76回目    loss:0.040104255080223083
#    loaders:77回目    loss:0.1301349699497223
#    loaders:78回目    loss:0.14345349371433258
#    loaders:79回目    loss:0.18780255317687988
#    loaders:80回目    loss:0.22053882479667664
#    loaders:81回目    loss:0.11282961815595627
#    loaders:82回目    loss:0.17259325087070465
#    loaders:83回目    loss:0.10536088794469833
#    loaders:84回目    loss:0.13184505701065063
#    loaders:85回目    loss:0.0824594795703888
#    loaders:86回目    loss:0.09666916728019714
#    loaders:87回目    loss:0.13330432772636414
#    loaders:88回目    loss:0.052352603524923325
#    loaders:89回目    loss:0.17686456441879272
#    loaders:90回目    loss:0.06498636305332184
#    loaders:91回目    loss:0.11741723865270615
#    loaders:92回目    loss:0.11954546719789505
#    loaders:93回目    loss:0.24825161695480347
#    loaders:94回目    loss:0.06737394630908966
#    loaders:95回目    loss:0.18317335844039917
#    loaders:96回目    loss:0.029126515612006187
#    loaders:97回目    loss:0.10474754124879837
#    loaders:98回目    loss:0.05276305973529816
#    loaders:99回目    loss:0.1071949228644371
#    loaders:100回目    loss:0.18113037943840027
#    loaders:101回目    loss:0.1807907670736313
#    loaders:102回目    loss:0.16405035555362701
#    loaders:103回目    loss:0.08686476200819016
#    loaders:104回目    loss:0.09159289300441742
#    loaders:105回目    loss:0.02022772841155529
#    loaders:106回目    loss:0.12299684435129166
#    loaders:107回目    loss:0.12804357707500458
#    loaders:108回目    loss:0.14490605890750885
#    loaders:109回目    loss:0.08691630512475967
#    loaders:110回目    loss:0.09245748072862625
#    loaders:111回目    loss:0.14953118562698364
#    loaders:112回目    loss:0.16271476447582245
#    loaders:113回目    loss:0.07496149092912674
#    loaders:114回目    loss:0.14148855209350586
#    loaders:115回目    loss:0.0805148258805275
#    loaders:116回目    loss:0.08909786492586136
#    loaders:117回目    loss:0.0405057892203331
#    loaders:118回目    loss:0.1637541800737381
#    loaders:119回目    loss:0.11017581075429916
#    loaders:120回目    loss:0.06491868197917938
#    loaders:121回目    loss:0.047191206365823746
#    loaders:122回目    loss:0.06687428057193756
#    loaders:123回目    loss:0.11153475940227509
#    loaders:124回目    loss:0.13200831413269043
#    loaders:125回目    loss:0.11575707048177719
# EPOCH2回目 train Loss: 0.1139 Acc: 0.9625
# val:フェイズ
#    loaders:1回目    loss:0.16743142902851105
#    loaders:2回目    loss:0.21167248487472534
#    loaders:3回目    loss:0.15701580047607422
#    loaders:4回目    loss:0.0414859838783741
#    loaders:5回目    loss:0.059451524168252945
#    loaders:6回目    loss:0.3910427689552307
#    loaders:7回目    loss:0.3365168869495392
#    loaders:8回目    loss:0.27108147740364075
#    loaders:9回目    loss:0.24232174456119537
#    loaders:10回目    loss:0.37489089369773865
#    loaders:11回目    loss:0.4174065887928009
#    loaders:12回目    loss:0.32570746541023254
#    loaders:13回目    loss:0.215505450963974
#    loaders:14回目    loss:0.03603794425725937
#    loaders:15回目    loss:0.16574816405773163
# EPOCH2回目 val Loss: 0.2185 Acc: 0.8910
# train:フェイズ
#    loaders:1回目    loss:0.10873012989759445
#    loaders:2回目    loss:0.07798371464014053
#    loaders:3回目    loss:0.05620691180229187
#    loaders:4回目    loss:0.16103890538215637
#    loaders:5回目    loss:0.07043416798114777
#    loaders:6回目    loss:0.09892097115516663
#    loaders:7回目    loss:0.060600172728300095
#    loaders:8回目    loss:0.10084393620491028
#    loaders:9回目    loss:0.014316962100565434
#    loaders:10回目    loss:0.17900659143924713
#    loaders:11回目    loss:0.06827455013990402
#    loaders:12回目    loss:0.15157590806484222
#    loaders:13回目    loss:0.22269795835018158
#    loaders:14回目    loss:0.15360692143440247
#    loaders:15回目    loss:0.07552655786275864
#    loaders:16回目    loss:0.0122800562530756
#    loaders:17回目    loss:0.03934697434306145
#    loaders:18回目    loss:0.035718441009521484
#    loaders:19回目    loss:0.05052639916539192
#    loaders:20回目    loss:0.0666184276342392
#    loaders:21回目    loss:0.05599542334675789
#    loaders:22回目    loss:0.03556915000081062
#    loaders:23回目    loss:0.016096003353595734
#    loaders:24回目    loss:0.15827131271362305
#    loaders:25回目    loss:0.14960360527038574
#    loaders:26回目    loss:0.1031629666686058
#    loaders:27回目    loss:0.1381458342075348
#    loaders:28回目    loss:0.02649332396686077
#    loaders:29回目    loss:0.15713174641132355
#    loaders:30回目    loss:0.12586237490177155
#    loaders:31回目    loss:0.07519877701997757
#    loaders:32回目    loss:0.07156237214803696
#    loaders:33回目    loss:0.05277160555124283
#    loaders:34回目    loss:0.05438978970050812
#    loaders:35回目    loss:0.047915518283843994
#    loaders:36回目    loss:0.025893812999129295
#    loaders:37回目    loss:0.08921138197183609
#    loaders:38回目    loss:0.21892693638801575
#    loaders:39回目    loss:0.06774850934743881
#    loaders:40回目    loss:0.27558454871177673
#    loaders:41回目    loss:0.05649576708674431
#    loaders:42回目    loss:0.06537912040948868
#    loaders:43回目    loss:0.04172471538186073
#    loaders:44回目    loss:0.030502768233418465
#    loaders:45回目    loss:0.019441040232777596
#    loaders:46回目    loss:0.10156261175870895
#    loaders:47回目    loss:0.063832588493824
#    loaders:48回目    loss:0.11006064713001251
#    loaders:49回目    loss:0.1263609379529953
#    loaders:50回目    loss:0.07433878630399704
#    loaders:51回目    loss:0.02268824353814125
#    loaders:52回目    loss:0.045839857310056686
#    loaders:53回目    loss:0.16687650978565216
#    loaders:54回目    loss:0.0791555792093277
#    loaders:55回目    loss:0.1937752515077591
#    loaders:56回目    loss:0.0639258399605751
#    loaders:57回目    loss:0.04671572893857956
#    loaders:58回目    loss:0.06473205983638763
#    loaders:59回目    loss:0.03713805601000786
#    loaders:60回目    loss:0.02927752397954464
#    loaders:61回目    loss:0.12633289396762848
#    loaders:62回目    loss:0.12424255907535553
#    loaders:63回目    loss:0.02849731408059597
#    loaders:64回目    loss:0.06289587914943695
#    loaders:65回目    loss:0.044495590031147
#    loaders:66回目    loss:0.06315667927265167
#    loaders:67回目    loss:0.18434451520442963
#    loaders:68回目    loss:0.04664439335465431
#    loaders:69回目    loss:0.1287040263414383
#    loaders:70回目    loss:0.20899641513824463
#    loaders:71回目    loss:0.1289033740758896
#    loaders:72回目    loss:0.016872890293598175
#    loaders:73回目    loss:0.029077798128128052
#    loaders:74回目    loss:0.13100028038024902
#    loaders:75回目    loss:0.1273672729730606
#    loaders:76回目    loss:0.08991021662950516
#    loaders:77回目    loss:0.12844230234622955
#    loaders:78回目    loss:0.10155567526817322
#    loaders:79回目    loss:0.031949881464242935
#    loaders:80回目    loss:0.040125660598278046
#    loaders:81回目    loss:0.030681753531098366
#    loaders:82回目    loss:0.04866049066185951
#    loaders:83回目    loss:0.036242593079805374
#    loaders:84回目    loss:0.07967817783355713
#    loaders:85回目    loss:0.05541900545358658
#    loaders:86回目    loss:0.039879344403743744
#    loaders:87回目    loss:0.04770437628030777
#    loaders:88回目    loss:0.12336347252130508
#    loaders:89回目    loss:0.1293923407793045
#    loaders:90回目    loss:0.0603247806429863
#    loaders:91回目    loss:0.06701698154211044
#    loaders:92回目    loss:0.034558311104774475
#    loaders:93回目    loss:0.06963152438402176
#    loaders:94回目    loss:0.1353093683719635
#    loaders:95回目    loss:0.029365774244070053
#    loaders:96回目    loss:0.02674015611410141
#    loaders:97回目    loss:0.058523017913103104
#    loaders:98回目    loss:0.06750737875699997
#    loaders:99回目    loss:0.0295267291367054
#    loaders:100回目    loss:0.1550465077161789
#    loaders:101回目    loss:0.06355210393667221
#    loaders:102回目    loss:0.008144124411046505
#    loaders:103回目    loss:0.08447927236557007
#    loaders:104回目    loss:0.1147431805729866
#    loaders:105回目    loss:0.04122401773929596
#    loaders:106回目    loss:0.04729926958680153
#    loaders:107回目    loss:0.04205245152115822
#    loaders:108回目    loss:0.08851711452007294
#    loaders:109回目    loss:0.05313067510724068
#    loaders:110回目    loss:0.06724536418914795
#    loaders:111回目    loss:0.03715857118368149
#    loaders:112回目    loss:0.015658630058169365
#    loaders:113回目    loss:0.009992207400500774
#    loaders:114回目    loss:0.028600797057151794
#    loaders:115回目    loss:0.08169679343700409
#    loaders:116回目    loss:0.15497581660747528
#    loaders:117回目    loss:0.1382916420698166
#    loaders:118回目    loss:0.039785124361515045
#    loaders:119回目    loss:0.008068641647696495
#    loaders:120回目    loss:0.08986768871545792
#    loaders:121回目    loss:0.0668502226471901
#    loaders:122回目    loss:0.23251667618751526
#    loaders:123回目    loss:0.04528177157044411
#    loaders:124回目    loss:0.010881757363677025
#    loaders:125回目    loss:0.03729898855090141
# EPOCH3回目 train Loss: 0.0797 Acc: 0.9745
# val:フェイズ
#    loaders:1回目    loss:0.13341563940048218
#    loaders:2回目    loss:0.15387651324272156
#    loaders:3回目    loss:0.18585409224033356
#    loaders:4回目    loss:0.05667644739151001
#    loaders:5回目    loss:0.0601716972887516
#    loaders:6回目    loss:0.5953521728515625
#    loaders:7回目    loss:0.2547512352466583
#    loaders:8回目    loss:0.20200765132904053
#    loaders:9回目    loss:0.23949697613716125
#    loaders:10回目    loss:0.2451368272304535
#    loaders:11回目    loss:0.13188956677913666
#    loaders:12回目    loss:0.12115844339132309
#    loaders:13回目    loss:0.22360765933990479
#    loaders:14回目    loss:0.03541458770632744
#    loaders:15回目    loss:0.11127718538045883
# EPOCH3回目 val Loss: 0.1760 Acc: 0.9080
# Save File original_model_3.pth
# train:フェイズ
#    loaders:1回目    loss:0.1282954216003418
#    loaders:2回目    loss:0.026832111179828644
#    loaders:3回目    loss:0.06938988715410233
#    loaders:4回目    loss:0.08702106773853302
#    loaders:5回目    loss:0.050570011138916016
#    loaders:6回目    loss:0.022075295448303223
#    loaders:7回目    loss:0.03676331415772438
#    loaders:8回目    loss:0.020268410444259644
#    loaders:9回目    loss:0.04292989894747734
#    loaders:10回目    loss:0.0663401186466217
#    loaders:11回目    loss:0.06387022882699966
#    loaders:12回目    loss:0.04202788323163986
#    loaders:13回目    loss:0.010846833698451519
#    loaders:14回目    loss:0.03596797585487366
#    loaders:15回目    loss:0.07131793349981308
#    loaders:16回目    loss:0.06339812278747559
#    loaders:17回目    loss:0.05824902653694153
#    loaders:18回目    loss:0.07078741490840912
#    loaders:19回目    loss:0.010343348607420921
#    loaders:20回目    loss:0.11764723062515259
#    loaders:21回目    loss:0.09609399735927582
#    loaders:22回目    loss:0.014056081883609295
#    loaders:23回目    loss:0.10715030878782272
#    loaders:24回目    loss:0.059494499117136
#    loaders:25回目    loss:0.02733166329562664
#    loaders:26回目    loss:0.06649254262447357
#    loaders:27回目    loss:0.033806804567575455
#    loaders:28回目    loss:0.08147827535867691
#    loaders:29回目    loss:0.010765979066491127
#    loaders:30回目    loss:0.01036166027188301
#    loaders:31回目    loss:0.02912227436900139
#    loaders:32回目    loss:0.05298759043216705
#    loaders:33回目    loss:0.028875067830085754
#    loaders:34回目    loss:0.045906659215688705
#    loaders:35回目    loss:0.08899340033531189
#    loaders:36回目    loss:0.015524879097938538
#    loaders:37回目    loss:0.09319066256284714
#    loaders:38回目    loss:0.04718504846096039
#    loaders:39回目    loss:0.024409707635641098
#    loaders:40回目    loss:0.05104066804051399
#    loaders:41回目    loss:0.014415811747312546
#    loaders:42回目    loss:0.027051245793700218
#    loaders:43回目    loss:0.011088259518146515
#    loaders:44回目    loss:0.05044914409518242
#    loaders:45回目    loss:0.06565310806035995
#    loaders:46回目    loss:0.026674622669816017
#    loaders:47回目    loss:0.02310703508555889
#    loaders:48回目    loss:0.07853982597589493
#    loaders:49回目    loss:0.014448256231844425
#    loaders:50回目    loss:0.04680773615837097
#    loaders:51回目    loss:0.09294334799051285
#    loaders:52回目    loss:0.02555067464709282
#    loaders:53回目    loss:0.03182812035083771
#    loaders:54回目    loss:0.0842241570353508
#    loaders:55回目    loss:0.07394389063119888
#    loaders:56回目    loss:0.04763360321521759
#    loaders:57回目    loss:0.032567381858825684
#    loaders:58回目    loss:0.05571644753217697
#    loaders:59回目    loss:0.0053972662426531315
#    loaders:60回目    loss:0.009491986595094204
#    loaders:61回目    loss:0.10433093458414078
#    loaders:62回目    loss:0.007641843520104885
#    loaders:63回目    loss:0.08186603337526321
#    loaders:64回目    loss:0.023081742227077484
#    loaders:65回目    loss:0.034185316413640976
#    loaders:66回目    loss:0.11985059827566147
#    loaders:67回目    loss:0.13303324580192566
#    loaders:68回目    loss:0.02447807975113392
#    loaders:69回目    loss:0.02853921242058277
#    loaders:70回目    loss:0.028508557006716728
#    loaders:71回目    loss:0.007434247527271509
#    loaders:72回目    loss:0.009764051996171474
#    loaders:73回目    loss:0.06197632476687431
#    loaders:74回目    loss:0.09931715577840805
#    loaders:75回目    loss:0.04896964132785797
#    loaders:76回目    loss:0.10137003660202026
#    loaders:77回目    loss:0.04928363114595413
#    loaders:78回目    loss:0.010640429332852364
#    loaders:79回目    loss:0.06849286705255508
#    loaders:80回目    loss:0.024387015029788017
#    loaders:81回目    loss:0.011586826294660568
#    loaders:82回目    loss:0.010912713594734669
#    loaders:83回目    loss:0.031442418694496155
#    loaders:84回目    loss:0.03188687562942505
#    loaders:85回目    loss:0.0986652746796608
#    loaders:86回目    loss:0.02204209566116333
#    loaders:87回目    loss:0.035135164856910706
#    loaders:88回目    loss:0.053497377783060074
#    loaders:89回目    loss:0.08152366429567337
#    loaders:90回目    loss:0.0318133570253849
#    loaders:91回目    loss:0.033496879041194916
#    loaders:92回目    loss:0.0514783039689064
#    loaders:93回目    loss:0.021987194195389748
#    loaders:94回目    loss:0.022246066480875015
#    loaders:95回目    loss:0.016454046592116356
#    loaders:96回目    loss:0.008245011791586876
#    loaders:97回目    loss:0.03951623663306236
#    loaders:98回目    loss:0.009548211470246315
#    loaders:99回目    loss:0.018728969618678093
#    loaders:100回目    loss:0.05075440928339958
#    loaders:101回目    loss:0.07300437241792679
#    loaders:102回目    loss:0.07187376171350479
#    loaders:103回目    loss:0.03394351899623871
#    loaders:104回目    loss:0.012736724689602852
#    loaders:105回目    loss:0.024886056780815125
#    loaders:106回目    loss:0.07731619477272034
#    loaders:107回目    loss:0.04717792943120003
#    loaders:108回目    loss:0.01939675211906433
#    loaders:109回目    loss:0.018902871757745743
#    loaders:110回目    loss:0.06767086684703827
#    loaders:111回目    loss:0.03092493861913681
#    loaders:112回目    loss:0.01719898171722889
#    loaders:113回目    loss:0.013688609004020691
#    loaders:114回目    loss:0.07511300593614578
#    loaders:115回目    loss:0.041457679122686386
#    loaders:116回目    loss:0.006114511750638485
#    loaders:117回目    loss:0.031359948217868805
#    loaders:118回目    loss:0.024240905418992043
#    loaders:119回目    loss:0.13960561156272888
#    loaders:120回目    loss:0.009865290485322475
#    loaders:121回目    loss:0.1586613655090332
#    loaders:122回目    loss:0.041878342628479004
#    loaders:123回目    loss:0.05519958212971687
#    loaders:124回目    loss:0.05324261263012886
#    loaders:125回目    loss:0.02900579199194908
# EPOCH4回目 train Loss: 0.0466 Acc: 0.9861
# val:フェイズ
#    loaders:1回目    loss:0.12258826196193695
#    loaders:2回目    loss:0.12433912605047226
#    loaders:3回目    loss:0.2764483392238617
#    loaders:4回目    loss:0.1169603243470192
#    loaders:5回目    loss:0.006021049804985523
#    loaders:6回目    loss:0.38321995735168457
#    loaders:7回目    loss:0.1435210257768631
#    loaders:8回目    loss:0.17306765913963318
#    loaders:9回目    loss:0.28028157353401184
#    loaders:10回目    loss:0.2865268588066101
#    loaders:11回目    loss:0.13898637890815735
#    loaders:12回目    loss:0.22698773443698883
#    loaders:13回目    loss:0.21963033080101013
#    loaders:14回目    loss:0.02867412194609642
#    loaders:15回目    loss:0.06706643849611282
# EPOCH4回目 val Loss: 0.1660 Acc: 0.9010
# train:フェイズ
#    loaders:1回目    loss:0.010530435480177402
#    loaders:2回目    loss:0.008852949365973473
#    loaders:3回目    loss:0.04312092810869217
#    loaders:4回目    loss:0.016531456261873245
#    loaders:5回目    loss:0.05197079852223396
#    loaders:6回目    loss:0.020973917096853256
#    loaders:7回目    loss:0.08330335468053818
#    loaders:8回目    loss:0.0361882746219635
#    loaders:9回目    loss:0.03727836161851883
#    loaders:10回目    loss:0.007378232199698687
#    loaders:11回目    loss:0.03888619318604469
#    loaders:12回目    loss:0.012226954102516174
#    loaders:13回目    loss:0.007519647479057312
#    loaders:14回目    loss:0.010685781016945839
#    loaders:15回目    loss:0.13367770612239838
#    loaders:16回目    loss:0.20264387130737305
#    loaders:17回目    loss:0.027768366038799286
#    loaders:18回目    loss:0.0030361597891896963
#    loaders:19回目    loss:0.022562449797987938
#    loaders:20回目    loss:0.035537298768758774
#    loaders:21回目    loss:0.010769679211080074
#    loaders:22回目    loss:0.06986577063798904
#    loaders:23回目    loss:0.04144033417105675
#    loaders:24回目    loss:0.013039554469287395
#    loaders:25回目    loss:0.02459522895514965
#    loaders:26回目    loss:0.011978927068412304
#    loaders:27回目    loss:0.0296685341745615
#    loaders:28回目    loss:0.12237023562192917
#    loaders:29回目    loss:0.11682815104722977
#    loaders:30回目    loss:0.015386978164315224
#    loaders:31回目    loss:0.007481207139790058
#    loaders:32回目    loss:0.01753554306924343
#    loaders:33回目    loss:0.07296233624219894
#    loaders:34回目    loss:0.00674310652539134
#    loaders:35回目    loss:0.09945375472307205
#    loaders:36回目    loss:0.02727869339287281
#    loaders:37回目    loss:0.03520147129893303
#    loaders:38回目    loss:0.011269764974713326
#    loaders:39回目    loss:0.007922387681901455
#    loaders:40回目    loss:0.04687123745679855
#    loaders:41回目    loss:0.047757573425769806
#    loaders:42回目    loss:0.005528517533093691
#    loaders:43回目    loss:0.05172843858599663
#    loaders:44回目    loss:0.047249145805835724
#    loaders:45回目    loss:0.010641179047524929
#    loaders:46回目    loss:0.03191622346639633
#    loaders:47回目    loss:0.030349360778927803
#    loaders:48回目    loss:0.015469648875296116
#    loaders:49回目    loss:0.0633530244231224
#    loaders:50回目    loss:0.015418685972690582
#    loaders:51回目    loss:0.008087612688541412
#    loaders:52回目    loss:0.015804709866642952
#    loaders:53回目    loss:0.11786147207021713
#    loaders:54回目    loss:0.10281074047088623
#    loaders:55回目    loss:0.09607931226491928
#    loaders:56回目    loss:0.0419175922870636
#    loaders:57回目    loss:0.12328744679689407
#    loaders:58回目    loss:0.04380781203508377
#    loaders:59回目    loss:0.010178725235164165
#    loaders:60回目    loss:0.017238784581422806
#    loaders:61回目    loss:0.010241169482469559
#    loaders:62回目    loss:0.016807889565825462
#    loaders:63回目    loss:0.1886989027261734
#    loaders:64回目    loss:0.023395031690597534
#    loaders:65回目    loss:0.01750943996012211
#    loaders:66回目    loss:0.024875542148947716
#    loaders:67回目    loss:0.012451090849936008
#    loaders:68回目    loss:0.03712376207113266
#    loaders:69回目    loss:0.006295166909694672
#    loaders:70回目    loss:0.02385351061820984
#    loaders:71回目    loss:0.042315784841775894
#    loaders:72回目    loss:0.07604978233575821
#    loaders:73回目    loss:0.04571332409977913
#    loaders:74回目    loss:0.1229911670088768
#    loaders:75回目    loss:0.024746065959334373
#    loaders:76回目    loss:0.01314510963857174
#    loaders:77回目    loss:0.010613853111863136
#    loaders:78回目    loss:0.051343876868486404
#    loaders:79回目    loss:0.0038090066518634558
#    loaders:80回目    loss:0.0038802362978458405
#    loaders:81回目    loss:0.034235768020153046
#    loaders:82回目    loss:0.03131749853491783
#    loaders:83回目    loss:0.020292745903134346
#    loaders:84回目    loss:0.05371921509504318
#    loaders:85回目    loss:0.019856663420796394
#    loaders:86回目    loss:0.02615070529282093
#    loaders:87回目    loss:0.042693790048360825
#    loaders:88回目    loss:0.04381238669157028
#    loaders:89回目    loss:0.019908592104911804
#    loaders:90回目    loss:0.07416778057813644
#    loaders:91回目    loss:0.006178653798997402
#    loaders:92回目    loss:0.057801034301519394
#    loaders:93回目    loss:0.08161680400371552
#    loaders:94回目    loss:0.020224278792738914
#    loaders:95回目    loss:0.07178662717342377
#    loaders:96回目    loss:0.026365309953689575
#    loaders:97回目    loss:0.013304013758897781
#    loaders:98回目    loss:0.021953068673610687
#    loaders:99回目    loss:0.014423592947423458
#    loaders:100回目    loss:0.030058419331908226
#    loaders:101回目    loss:0.04009729251265526
#    loaders:102回目    loss:0.022126149386167526
#    loaders:103回目    loss:0.02595262974500656
#    loaders:104回目    loss:0.0159451961517334
#    loaders:105回目    loss:0.07792408764362335
#    loaders:106回目    loss:0.006766775622963905
#    loaders:107回目    loss:0.06157175078988075
#    loaders:108回目    loss:0.061669085174798965
#    loaders:109回目    loss:0.022556837648153305
#    loaders:110回目    loss:0.04074624925851822
#    loaders:111回目    loss:0.033199477940797806
#    loaders:112回目    loss:0.02235839143395424
#    loaders:113回目    loss:0.0468398854136467
#    loaders:114回目    loss:0.03179261460900307
#    loaders:115回目    loss:0.04166819527745247
#    loaders:116回目    loss:0.014768888242542744
#    loaders:117回目    loss:0.021984051913022995
#    loaders:118回目    loss:0.024324558675289154
#    loaders:119回目    loss:0.05045294389128685
#    loaders:120回目    loss:0.13225769996643066
#    loaders:121回目    loss:0.009617658331990242
#    loaders:122回目    loss:0.01784011907875538
#    loaders:123回目    loss:0.11416241526603699
#    loaders:124回目    loss:0.06227697804570198
#    loaders:125回目    loss:0.05420088395476341
# EPOCH5回目 train Loss: 0.0401 Acc: 0.9881
# val:フェイズ
#    loaders:1回目    loss:0.21009474992752075
#    loaders:2回目    loss:0.16268190741539001
#    loaders:3回目    loss:0.2852567136287689
#    loaders:4回目    loss:0.07986240088939667
#    loaders:5回目    loss:0.005761443637311459
#    loaders:6回目    loss:0.3228878974914551
#    loaders:7回目    loss:0.28572869300842285
#    loaders:8回目    loss:0.24980391561985016
#    loaders:9回目    loss:0.2056877762079239
#    loaders:10回目    loss:0.18860511481761932
#    loaders:11回目    loss:0.13448411226272583
#    loaders:12回目    loss:0.1281692534685135
#    loaders:13回目    loss:0.12090720236301422
#    loaders:14回目    loss:0.03636115416884422
#    loaders:15回目    loss:0.04750216379761696
# EPOCH5回目 val Loss: 0.1577 Acc: 0.9080
# train:フェイズ
#    loaders:1回目    loss:0.013335793279111385
#    loaders:2回目    loss:0.03219218552112579
#    loaders:3回目    loss:0.014842513017356396
#    loaders:4回目    loss:0.025915173813700676
#    loaders:5回目    loss:0.042656172066926956
#    loaders:6回目    loss:0.04892829433083534
#    loaders:7回目    loss:0.04266153648495674
#    loaders:8回目    loss:0.04387877881526947
#    loaders:9回目    loss:0.08463829755783081
#    loaders:10回目    loss:0.02889660932123661
#    loaders:11回目    loss:0.005536339245736599
#    loaders:12回目    loss:0.033168233931064606
#    loaders:13回目    loss:0.041330624371767044
#    loaders:14回目    loss:0.04942682012915611
#    loaders:15回目    loss:0.00665672542527318
#    loaders:16回目    loss:0.017633240669965744
#    loaders:17回目    loss:0.033235274255275726
#    loaders:18回目    loss:0.0033531489316374063
#    loaders:19回目    loss:0.01683230511844158
#    loaders:20回目    loss:0.008556309156119823
#    loaders:21回目    loss:0.04769282042980194
#    loaders:22回目    loss:0.045797642320394516
#    loaders:23回目    loss:0.0198244396597147
#    loaders:24回目    loss:0.029999466612935066
#    loaders:25回目    loss:0.050165195018053055
#    loaders:26回目    loss:0.09331545978784561
#    loaders:27回目    loss:0.06754022091627121
#    loaders:28回目    loss:0.03340725228190422
#    loaders:29回目    loss:0.015325497835874557
#    loaders:30回目    loss:0.048382148146629333
#    loaders:31回目    loss:0.07094280421733856
#    loaders:32回目    loss:0.008632454089820385
#    loaders:33回目    loss:0.02214699238538742
#    loaders:34回目    loss:0.032268673181533813
#    loaders:35回目    loss:0.04637505114078522
#    loaders:36回目    loss:0.002378674689680338
#    loaders:37回目    loss:0.022707220166921616
#    loaders:38回目    loss:0.017208348959684372
#    loaders:39回目    loss:0.043619539588689804
#    loaders:40回目    loss:0.03461923822760582
#    loaders:41回目    loss:0.00713232159614563
#    loaders:42回目    loss:0.02479693852365017
#    loaders:43回目    loss:0.07017836719751358
#    loaders:44回目    loss:0.015303586609661579
#    loaders:45回目    loss:0.07809562236070633
#    loaders:46回目    loss:0.006249072030186653
#    loaders:47回目    loss:0.15948300063610077
#    loaders:48回目    loss:0.024161813780665398
#    loaders:49回目    loss:0.02143983356654644
#    loaders:50回目    loss:0.017641739919781685
#    loaders:51回目    loss:0.034015849232673645
#    loaders:52回目    loss:0.07382217049598694
#    loaders:53回目    loss:0.04961257427930832
#    loaders:54回目    loss:0.01625477522611618
#    loaders:55回目    loss:0.019775737076997757
#    loaders:56回目    loss:0.013282546773552895
#    loaders:57回目    loss:0.016530748456716537
#    loaders:58回目    loss:0.023990578949451447
#    loaders:59回目    loss:0.029820503666996956
#    loaders:60回目    loss:0.045123692601919174
#    loaders:61回目    loss:0.03310327231884003
#    loaders:62回目    loss:0.030412863940000534
#    loaders:63回目    loss:0.0902412012219429
#    loaders:64回目    loss:0.00895130168646574
#    loaders:65回目    loss:0.07927317917346954
#    loaders:66回目    loss:0.010111505165696144
#    loaders:67回目    loss:0.017962567508220673
#    loaders:68回目    loss:0.02524723671376705
#    loaders:69回目    loss:0.04792536795139313
#    loaders:70回目    loss:0.022176489233970642
#    loaders:71回目    loss:0.08484824001789093
#    loaders:72回目    loss:0.052159495651721954
#    loaders:73回目    loss:0.06302586942911148
#    loaders:74回目    loss:0.012668603099882603
#    loaders:75回目    loss:0.009083903394639492
#    loaders:76回目    loss:0.02418357878923416
#    loaders:77回目    loss:0.01272809412330389
#    loaders:78回目    loss:0.0956224650144577
#    loaders:79回目    loss:0.04620926454663277
#    loaders:80回目    loss:0.1700952649116516
#    loaders:81回目    loss:0.03806186094880104
#    loaders:82回目    loss:0.07114894688129425
#    loaders:83回目    loss:0.011653609573841095
#    loaders:84回目    loss:0.014908543787896633
#    loaders:85回目    loss:0.04507777839899063
#    loaders:86回目    loss:0.01730375550687313
#    loaders:87回目    loss:0.02177823707461357
#    loaders:88回目    loss:0.021804971620440483
#    loaders:89回目    loss:0.012053292244672775
#    loaders:90回目    loss:0.04557532072067261
#    loaders:91回目    loss:0.04862653464078903
#    loaders:92回目    loss:0.012657349929213524
#    loaders:93回目    loss:0.04141649603843689
#    loaders:94回目    loss:0.014856609515845776
#    loaders:95回目    loss:0.017350291833281517
#    loaders:96回目    loss:0.05405568704009056
#    loaders:97回目    loss:0.011996234767138958
#    loaders:98回目    loss:0.049231186509132385
#    loaders:99回目    loss:0.038343921303749084
#    loaders:100回目    loss:0.02515975758433342
#    loaders:101回目    loss:0.059319742023944855
#    loaders:102回目    loss:0.013176916167140007
#    loaders:103回目    loss:0.027043305337429047
#    loaders:104回目    loss:0.03454644978046417
#    loaders:105回目    loss:0.011225573718547821
#    loaders:106回目    loss:0.07108637690544128
#    loaders:107回目    loss:0.028746210038661957
#    loaders:108回目    loss:0.020061735063791275
#    loaders:109回目    loss:0.03228199854493141
#    loaders:110回目    loss:0.024375086650252342
#    loaders:111回目    loss:0.033984582871198654
#    loaders:112回目    loss:0.038868535310029984
#    loaders:113回目    loss:0.0024056953843683004
#    loaders:114回目    loss:0.01608903892338276
#    loaders:115回目    loss:0.0699634924530983
#    loaders:116回目    loss:0.025546692311763763
#    loaders:117回目    loss:0.0237957164645195
#    loaders:118回目    loss:0.005131480284035206
#    loaders:119回目    loss:0.032302986830472946
#    loaders:120回目    loss:0.053725793957710266
#    loaders:121回目    loss:0.02004077285528183
#    loaders:122回目    loss:0.08771594613790512
#    loaders:123回目    loss:0.0842609629034996
#    loaders:124回目    loss:0.04601043462753296
#    loaders:125回目    loss:0.0036072786897420883
# EPOCH6回目 train Loss: 0.0361 Acc: 0.9880
# val:フェイズ
#    loaders:1回目    loss:0.1405172199010849
#    loaders:2回目    loss:0.04054143652319908
#    loaders:3回目    loss:0.09397447854280472
#    loaders:4回目    loss:0.024615110829472542
#    loaders:5回目    loss:0.023108024150133133
#    loaders:6回目    loss:0.42115676403045654
#    loaders:7回目    loss:0.23777352273464203
#    loaders:8回目    loss:0.20917436480522156
#    loaders:9回目    loss:0.3223324716091156
#    loaders:10回目    loss:0.21354573965072632
#    loaders:11回目    loss:0.16377325356006622
#    loaders:12回目    loss:0.31106531620025635
#    loaders:13回目    loss:0.17368140816688538
#    loaders:14回目    loss:0.009765072725713253
#    loaders:15回目    loss:0.05809458717703819
# EPOCH6回目 val Loss: 0.1564 Acc: 0.9110
# Save File original_model_6.pth
# train:フェイズ
#    loaders:1回目    loss:0.016965370625257492
#    loaders:2回目    loss:0.018597649410367012
#    loaders:3回目    loss:0.01293650921434164
#    loaders:4回目    loss:0.026716062799096107
#    loaders:5回目    loss:0.0240619033575058
#    loaders:6回目    loss:0.007254274562001228
#    loaders:7回目    loss:0.05822943150997162
#    loaders:8回目    loss:0.006989825516939163
#    loaders:9回目    loss:0.11493118107318878
#    loaders:10回目    loss:0.008603012189269066
#    loaders:11回目    loss:0.01347772404551506
#    loaders:12回目    loss:0.002632085932418704
#    loaders:13回目    loss:0.049566615372896194
#    loaders:14回目    loss:0.0119475107640028
#    loaders:15回目    loss:0.01684553176164627
#    loaders:16回目    loss:0.021529465913772583
#    loaders:17回目    loss:0.08252453058958054
#    loaders:18回目    loss:0.008738655596971512
#    loaders:19回目    loss:0.07734643667936325
#    loaders:20回目    loss:0.01527560967952013
#    loaders:21回目    loss:0.05181552469730377
#    loaders:22回目    loss:0.00955606997013092
#    loaders:23回目    loss:0.01641758531332016
#    loaders:24回目    loss:0.005903247743844986
#    loaders:25回目    loss:0.011732799932360649
#    loaders:26回目    loss:0.031779490411281586
#    loaders:27回目    loss:0.0033269491977989674
#    loaders:28回目    loss:0.018897701054811478
#    loaders:29回目    loss:0.002722462872043252
#    loaders:30回目    loss:0.013159176334738731
#    loaders:31回目    loss:0.07548782974481583
#    loaders:32回目    loss:0.01773730106651783
#    loaders:33回目    loss:0.008187985979020596
#    loaders:34回目    loss:0.0036600481253117323
#    loaders:35回目    loss:0.03758725896477699
#    loaders:36回目    loss:0.012063037604093552
#    loaders:37回目    loss:0.03104771487414837
#    loaders:38回目    loss:0.02254193089902401
#    loaders:39回目    loss:0.08761835098266602
#    loaders:40回目    loss:0.06268511712551117
#    loaders:41回目    loss:0.016099901869893074
#    loaders:42回目    loss:0.02738814800977707
#    loaders:43回目    loss:0.10963447391986847
#    loaders:44回目    loss:0.02608952298760414
#    loaders:45回目    loss:0.030190102756023407
#    loaders:46回目    loss:0.008096862584352493
#    loaders:47回目    loss:0.019999243319034576
#    loaders:48回目    loss:0.0187874473631382
#    loaders:49回目    loss:0.06690515577793121
#    loaders:50回目    loss:0.02043157070875168
#    loaders:51回目    loss:0.06319428235292435
#    loaders:52回目    loss:0.006645066197961569
#    loaders:53回目    loss:0.017035149037837982
#    loaders:54回目    loss:0.048785608261823654
#    loaders:55回目    loss:0.017202964052557945
#    loaders:56回目    loss:0.024499990046024323
#    loaders:57回目    loss:0.008014132268726826
#    loaders:58回目    loss:0.010847672820091248
#    loaders:59回目    loss:0.014953183941543102
#    loaders:60回目    loss:0.006659490056335926
#    loaders:61回目    loss:0.043716005980968475
#    loaders:62回目    loss:0.013855942524969578
#    loaders:63回目    loss:0.05322571098804474
#    loaders:64回目    loss:0.015896573662757874
#    loaders:65回目    loss:0.009483758360147476
#    loaders:66回目    loss:0.048739343881607056
#    loaders:67回目    loss:0.004444933030754328
#    loaders:68回目    loss:0.010188732296228409
#    loaders:69回目    loss:0.0723787322640419
#    loaders:70回目    loss:0.01799517683684826
#    loaders:71回目    loss:0.02152635157108307
#    loaders:72回目    loss:0.03746791183948517
#    loaders:73回目    loss:0.012261825613677502
#    loaders:74回目    loss:0.032846849411726
#    loaders:75回目    loss:0.04399095103144646
#    loaders:76回目    loss:0.04260239377617836
#    loaders:77回目    loss:0.06349194049835205
#    loaders:78回目    loss:0.03557855263352394
# ...
#    loaders:85回目    loss:0.0019661213736981153
#    loaders:86回目    loss:0.014619383029639721
#    loaders:87回目    loss:0.0006431901128962636
#    loaders:88回目    loss:0.0033110901713371277
#    loaders:89回目    loss:0.014735013246536255
#    loaders:90回目    loss:0.001191563904285431
#    loaders:91回目    loss:0.00044488804996944964
#    loaders:92回目    loss:0.0003689287987072021
#    loaders:93回目    loss:0.0038119074888527393
#    loaders:94回目    loss:0.006560140289366245
#    loaders:95回目    loss:0.0017055358039215207
#    loaders:96回目    loss:0.0051126787438988686
#    loaders:97回目    loss:0.0014684235211461782
#    loaders:98回目    loss:0.00037422176683321595
#    loaders:99回目    loss:0.004932700656354427
#    loaders:100回目    loss:0.0006487598293460906
#    loaders:101回目    loss:0.019447755068540573
#    loaders:102回目    loss:0.0038014226593077183
#    loaders:103回目    loss:0.0008003902621567249
#    loaders:104回目    loss:0.019152505323290825
#    loaders:105回目    loss:0.010388948954641819
#    loaders:106回目    loss:0.016530876979231834
#    loaders:107回目    loss:0.003277548123151064
#    loaders:108回目    loss:0.0010644042631611228
#    loaders:109回目    loss:0.00025452571571804583
#    loaders:110回目    loss:0.002306909766048193
#    loaders:111回目    loss:0.004502524621784687
#    loaders:112回目    loss:0.000870484160259366
#    loaders:113回目    loss:0.0005962613504379988
#    loaders:114回目    loss:0.0018719882937148213
#    loaders:115回目    loss:0.004356745630502701
#    loaders:116回目    loss:0.0029986274894326925
#    loaders:117回目    loss:0.06577969342470169
#    loaders:118回目    loss:0.0005758944898843765
#    loaders:119回目    loss:0.005346029531210661
#    loaders:120回目    loss:0.002631004899740219
#    loaders:121回目    loss:0.000576040823943913
#    loaders:122回目    loss:0.010396229103207588
#    loaders:123回目    loss:0.001486268825829029
#    loaders:124回目    loss:0.0025687371380627155
#    loaders:125回目    loss:0.001819842611439526
# EPOCH22回目 train Loss: 0.0068 Acc: 0.9986
# val:フェイズ
#    loaders:1回目    loss:0.12384067475795746
#    loaders:2回目    loss:0.07441017776727676
#    loaders:3回目    loss:0.25584203004837036
#    loaders:4回目    loss:0.11856787651777267
#    loaders:5回目    loss:0.07821919769048691
#    loaders:6回目    loss:0.44812464714050293
#    loaders:7回目    loss:0.4873075485229492
#    loaders:8回目    loss:0.32846489548683167
#    loaders:9回目    loss:0.22025936841964722
#    loaders:10回目    loss:0.29953432083129883
#    loaders:11回目    loss:0.06068628653883934
#    loaders:12回目    loss:0.37909290194511414
#    loaders:13回目    loss:0.165564626455307
#    loaders:14回目    loss:0.06305605173110962
#    loaders:15回目    loss:0.004621744621545076
# EPOCH22回目 val Loss: 0.1989 Acc: 0.9060
# train:フェイズ
#    loaders:1回目    loss:0.0006210693391039968
#    loaders:2回目    loss:0.00314492080360651
#    loaders:3回目    loss:0.0004337772261351347
#    loaders:4回目    loss:0.0014536170056089759
#    loaders:5回目    loss:0.03333063796162605
#    loaders:6回目    loss:0.009445453062653542
#    loaders:7回目    loss:0.0010054570157080889
#    loaders:8回目    loss:0.0006907577626407146
#    loaders:9回目    loss:0.0021603619679808617
#    loaders:10回目    loss:0.0005568899214267731
#    loaders:11回目    loss:0.001611149637028575
#    loaders:12回目    loss:0.031132103875279427
#    loaders:13回目    loss:0.001499252044595778
#    loaders:14回目    loss:0.05807506665587425
#    loaders:15回目    loss:0.0005394583567976952
#    loaders:16回目    loss:0.001635119435377419
#    loaders:17回目    loss:0.000949180917814374
#    loaders:18回目    loss:0.01372715923935175
#    loaders:19回目    loss:0.0006882392335683107
#    loaders:20回目    loss:0.009796706028282642
#    loaders:21回目    loss:0.0057777720503509045
#    loaders:22回目    loss:0.001034011016599834
#    loaders:23回目    loss:0.0012590467231348157
#    loaders:24回目    loss:0.0028492696583271027
#    loaders:25回目    loss:0.002035110956057906
#    loaders:26回目    loss:0.000579421001020819
#    loaders:27回目    loss:0.0019266370218247175
#    loaders:28回目    loss:0.00024641884374432266
#    loaders:29回目    loss:0.05343853309750557
#    loaders:30回目    loss:0.0005830570589751005
#    loaders:31回目    loss:0.005758720450103283
#    loaders:32回目    loss:0.02107851766049862
#    loaders:33回目    loss:0.002005490940064192
#    loaders:34回目    loss:0.0034730848856270313
#    loaders:35回目    loss:0.0006419030833058059
#    loaders:36回目    loss:0.0035230754874646664
#    loaders:37回目    loss:0.0003989673568867147
#    loaders:38回目    loss:0.005621545948088169
#    loaders:39回目    loss:0.0007862368365749717
#    loaders:40回目    loss:0.006864012219011784
#    loaders:41回目    loss:0.0017724826466292143
#    loaders:42回目    loss:0.001591199659742415
#    loaders:43回目    loss:0.00026292959228157997
#    loaders:44回目    loss:0.021556800231337547
#    loaders:45回目    loss:0.005518628749996424
#    loaders:46回目    loss:0.011318022385239601
#    loaders:47回目    loss:0.0038560626562684774
#    loaders:48回目    loss:0.0006078357109799981
#    loaders:49回目    loss:0.011002026498317719
#    loaders:50回目    loss:0.0014480743557214737
#    loaders:51回目    loss:0.002290031872689724
#    loaders:52回目    loss:0.02880706638097763
#    loaders:53回目    loss:0.001210528425872326
#    loaders:54回目    loss:0.010738887824118137
#    loaders:55回目    loss:0.002098300028592348
#    loaders:56回目    loss:0.002080667996779084
#    loaders:57回目    loss:0.0038159480318427086
#    loaders:58回目    loss:0.0003562566707842052
#    loaders:59回目    loss:0.013462130911648273
#    loaders:60回目    loss:0.0063761211931705475
#    loaders:61回目    loss:0.005292234942317009
#    loaders:62回目    loss:0.005369298625737429
#    loaders:63回目    loss:0.0008948201430030167
#    loaders:64回目    loss:0.028745470568537712
#    loaders:65回目    loss:0.0017308926908299327
#    loaders:66回目    loss:0.005656134337186813
#    loaders:67回目    loss:0.005876766052097082
#    loaders:68回目    loss:0.0005369733553379774
#    loaders:69回目    loss:0.00415280694141984
#    loaders:70回目    loss:0.001337943016551435
#    loaders:71回目    loss:0.0008793051820248365
#    loaders:72回目    loss:0.0016580094816163182
#    loaders:73回目    loss:0.005741279572248459
#    loaders:74回目    loss:0.0070977164432406425
#    loaders:75回目    loss:0.0023495168425142765
#    loaders:76回目    loss:0.002653540577739477
#    loaders:77回目    loss:0.0014324630610644817
#    loaders:78回目    loss:0.0010676300153136253
#    loaders:79回目    loss:0.001180180930532515
#    loaders:80回目    loss:0.003494655480608344
#    loaders:81回目    loss:0.002002053428441286
#    loaders:82回目    loss:0.00317371916025877
#    loaders:83回目    loss:0.000833969097584486
#    loaders:84回目    loss:0.00018696273036766797
#    loaders:85回目    loss:0.008606418035924435
#    loaders:86回目    loss:0.0074729351326823235
#    loaders:87回目    loss:0.001718045910820365
#    loaders:88回目    loss:0.0004710944776888937
#    loaders:89回目    loss:0.0021382386330515146
#    loaders:90回目    loss:0.023795384913682938
#    loaders:91回目    loss:0.001500514685176313
#    loaders:92回目    loss:0.013592126779258251
#    loaders:93回目    loss:0.012678425759077072
#    loaders:94回目    loss:0.005040314979851246
#    loaders:95回目    loss:0.000446695281425491
#    loaders:96回目    loss:0.0007963112439028919
#    loaders:97回目    loss:0.0010185664286836982
#    loaders:98回目    loss:0.0010690591298043728
#    loaders:99回目    loss:0.0034314426593482494
#    loaders:100回目    loss:0.003776888595893979
#    loaders:101回目    loss:0.005452847573906183
#    loaders:102回目    loss:0.00045745036914013326
#    loaders:103回目    loss:0.0009167150710709393
#    loaders:104回目    loss:0.0007687221514061093
#    loaders:105回目    loss:0.0017088280292227864
#    loaders:106回目    loss:0.002357873832806945
#    loaders:107回目    loss:0.005314633250236511
#    loaders:108回目    loss:0.00839029811322689
#    loaders:109回目    loss:0.0015695634065195918
#    loaders:110回目    loss:0.000481677328934893
#    loaders:111回目    loss:0.00133645033929497
#    loaders:112回目    loss:0.003456095466390252
#    loaders:113回目    loss:0.0007185197900980711
#    loaders:114回目    loss:0.009096328169107437
#    loaders:115回目    loss:0.0022389974910765886
#    loaders:116回目    loss:0.004448445048183203
#    loaders:117回目    loss:0.0010457229800522327
#    loaders:118回目    loss:0.0035891386214643717
#    loaders:119回目    loss:0.003675045445561409
#    loaders:120回目    loss:0.0013269149931147695
#    loaders:121回目    loss:0.0013722211588174105
#    loaders:122回目    loss:0.0006130867404863238
#    loaders:123回目    loss:0.00038853997830301523
#    loaders:124回目    loss:0.0021224594675004482
#    loaders:125回目    loss:0.0005575927207246423
# EPOCH23回目 train Loss: 0.0053 Acc: 0.9989
# val:フェイズ
#    loaders:1回目    loss:0.19778259098529816
#    loaders:2回目    loss:0.10131195932626724
#    loaders:3回目    loss:0.2905462384223938
#    loaders:4回目    loss:0.02976737730205059
#    loaders:5回目    loss:0.014449463225901127
#    loaders:6回目    loss:0.2505551278591156
#    loaders:7回目    loss:0.37504446506500244
#    loaders:8回目    loss:0.33694812655448914
#    loaders:9回目    loss:0.20465202629566193
#    loaders:10回目    loss:0.33327746391296387
#    loaders:11回目    loss:0.21320673823356628
#    loaders:12回目    loss:0.2588495910167694
#    loaders:13回目    loss:0.11638248711824417
#    loaders:14回目    loss:0.055738866329193115
#    loaders:15回目    loss:0.01752767339348793
# EPOCH23回目 val Loss: 0.1789 Acc: 0.9130
# Save File original_model_23.pth
# train:フェイズ
#    loaders:1回目    loss:0.00427139550447464
#    loaders:2回目    loss:0.0002861899556592107
#    loaders:3回目    loss:0.003984374459832907
#    loaders:4回目    loss:0.001234210329130292
#    loaders:5回目    loss:0.0005353709566406906
#    loaders:6回目    loss:0.0006263557588681579
#    loaders:7回目    loss:0.0020471205934882164
#    loaders:8回目    loss:0.00040746168815530837
#    loaders:9回目    loss:0.0017223968170583248
#    loaders:10回目    loss:0.00013486240641213953
#    loaders:11回目    loss:0.0005584410973824561
#    loaders:12回目    loss:0.0006595197482965887
#    loaders:13回目    loss:0.0027015653904527426
#    loaders:14回目    loss:0.0013410887913778424
#    loaders:15回目    loss:0.007543814834207296
#    loaders:16回目    loss:0.0022841705940663815
#    loaders:17回目    loss:0.0009151773992925882
#    loaders:18回目    loss:0.0017361340578645468
#    loaders:19回目    loss:0.003119319910183549
#    loaders:20回目    loss:0.0007115225307643414
#    loaders:21回目    loss:0.010790887288749218
#    loaders:22回目    loss:0.0005395695334300399
#    loaders:23回目    loss:0.004488814622163773
#    loaders:24回目    loss:0.003955920692533255
#    loaders:25回目    loss:0.0005848624859936535
#    loaders:26回目    loss:0.0006006519543007016
#    loaders:27回目    loss:0.0012228343402966857
#    loaders:28回目    loss:0.026456091552972794
#    loaders:29回目    loss:0.003083537332713604
#    loaders:30回目    loss:0.0007922897348180413
#    loaders:31回目    loss:0.000952200498431921
#    loaders:32回目    loss:0.0011374779278412461
#    loaders:33回目    loss:0.006815267726778984
#    loaders:34回目    loss:0.019378991797566414
#    loaders:35回目    loss:0.0005526065942831337
#    loaders:36回目    loss:0.001011233078315854
#    loaders:37回目    loss:0.00036918101250194013
#    loaders:38回目    loss:0.0019501465139910579
#    loaders:39回目    loss:0.0005280412151478231
#    loaders:40回目    loss:0.0005142863956280053
#    loaders:41回目    loss:0.0019227792508900166
#    loaders:42回目    loss:0.011502966284751892
#    loaders:43回目    loss:0.0008177417912520468
#    loaders:44回目    loss:0.00037931028055027127
#    loaders:45回目    loss:0.002509491750970483
#    loaders:46回目    loss:0.002877655904740095
#    loaders:47回目    loss:0.003552180016413331
#    loaders:48回目    loss:0.011014826595783234
#    loaders:49回目    loss:0.00021431614004541188
#    loaders:50回目    loss:0.004427467938512564
#    loaders:51回目    loss:0.0025265123695135117
#    loaders:52回目    loss:0.00031706219306215644
#    loaders:53回目    loss:0.0003512691182550043
#    loaders:54回目    loss:0.000870480143930763
#    loaders:55回目    loss:0.0005519447731785476
#    loaders:56回目    loss:0.01261161919683218
#    loaders:57回目    loss:0.006500643212348223
#    loaders:58回目    loss:0.0002691859262995422
#    loaders:59回目    loss:0.002138972980901599
#    loaders:60回目    loss:0.0027099200524389744
#    loaders:61回目    loss:0.0013702651485800743
#    loaders:62回目    loss:0.004756290465593338
#    loaders:63回目    loss:0.00014091712364461273
#    loaders:64回目    loss:0.0012406673049554229
#    loaders:65回目    loss:0.003020281670615077
#    loaders:66回目    loss:0.001198485610075295
#    loaders:67回目    loss:0.0010197377996519208
#    loaders:68回目    loss:0.003541155718266964
#    loaders:69回目    loss:0.0033581615425646305
#    loaders:70回目    loss:0.00122697779443115
#    loaders:71回目    loss:0.0006007460178807378
#    loaders:72回目    loss:0.000937282049562782
#    loaders:73回目    loss:0.008990306407213211
#    loaders:74回目    loss:0.001281927339732647
#    loaders:75回目    loss:0.000482422299683094
#    loaders:76回目    loss:0.0004968926659785211
#    loaders:77回目    loss:0.0007251917850226164
#    loaders:78回目    loss:0.0007135962950997055
#    loaders:79回目    loss:0.0009421311551705003
#    loaders:80回目    loss:0.0008371178410016
#    loaders:81回目    loss:0.0018009103368967772
#    loaders:82回目    loss:0.002877501305192709
#    loaders:83回目    loss:0.005088036879897118
#    loaders:84回目    loss:0.00013814205885864794
#    loaders:85回目    loss:0.0014773939037695527
#    loaders:86回目    loss:0.003475221572443843
#    loaders:87回目    loss:0.0004807734803762287
#    loaders:88回目    loss:0.0029971387702971697
#    loaders:89回目    loss:0.002211992861703038
#    loaders:90回目    loss:0.00592854805290699
#    loaders:91回目    loss:0.001948299235664308
#    loaders:92回目    loss:0.0004903367953374982
#    loaders:93回目    loss:0.001991525525227189
#    loaders:94回目    loss:0.0007687407196499407
#    loaders:95回目    loss:0.0038804770447313786
#    loaders:96回目    loss:0.009886244311928749
#    loaders:97回目    loss:0.0015424240846186876
#    loaders:98回目    loss:0.00041244112071581185
#    loaders:99回目    loss:0.0006175094749778509
#    loaders:100回目    loss:0.0023286680225282907
#    loaders:101回目    loss:0.00504589919000864
#    loaders:102回目    loss:0.00023929918825160712
#    loaders:103回目    loss:0.004016655497252941
#    loaders:104回目    loss:0.001285314210690558
#    loaders:105回目    loss:0.0068837180733680725
#    loaders:106回目    loss:0.0009041798766702414
#    loaders:107回目    loss:0.0011187263298779726
#    loaders:108回目    loss:0.0009852421935647726
#    loaders:109回目    loss:0.0001975011546164751
#    loaders:110回目    loss:0.0008652486721985042
#    loaders:111回目    loss:0.007093189749866724
#    loaders:112回目    loss:0.004901789128780365
#    loaders:113回目    loss:0.00026127329329028726
#    loaders:114回目    loss:0.02697511948645115
#    loaders:115回目    loss:0.009844846092164516
#    loaders:116回目    loss:0.003248639637604356
#    loaders:117回目    loss:0.00028445737552829087
#    loaders:118回目    loss:0.00015478509885724634
#    loaders:119回目    loss:0.0011960630072280765
#    loaders:120回目    loss:0.00019500695634633303
#    loaders:121回目    loss:0.00025742329307831824
#    loaders:122回目    loss:0.0006376496748998761
#    loaders:123回目    loss:0.0009038425632752478
#    loaders:124回目    loss:0.00032867840491235256
#    loaders:125回目    loss:0.035489555448293686
# EPOCH24回目 train Loss: 0.0031 Acc: 0.9994
# val:フェイズ
#    loaders:1回目    loss:0.21644741296768188
#    loaders:2回目    loss:0.1186988353729248
#    loaders:3回目    loss:0.3175915777683258
#    loaders:4回目    loss:0.040598947554826736
#    loaders:5回目    loss:0.069032222032547
#    loaders:6回目    loss:0.315279483795166
#    loaders:7回目    loss:0.4228309392929077
#    loaders:8回目    loss:0.32430845499038696
#    loaders:9回目    loss:0.26002413034439087
#    loaders:10回目    loss:0.4173734486103058
#    loaders:11回目    loss:0.1518411636352539
#    loaders:12回目    loss:0.30148157477378845
#    loaders:13回目    loss:0.1090518906712532
#    loaders:14回目    loss:0.04518851637840271
#    loaders:15回目    loss:0.009164770133793354
# EPOCH24回目 val Loss: 0.1996 Acc: 0.9090
# Best val Acc: 0.913000
# [0.797    0.951125 0.9625   0.9745   0.986125 0.988125 0.988    0.989625
#  0.989875 0.991625 0.99225  0.993375 0.991875 0.99425  0.994875 0.995875
#  0.99625  0.995875 0.996625 0.996625 0.998375 0.997125 0.998625 0.998875
#  0.999375]
# [0.888 0.904 0.891 0.908 0.901 0.908 0.911 0.904 0.905 0.902 0.912 0.906
#  0.894 0.892 0.909 0.899 0.903 0.909 0.905 0.907 0.912 0.912 0.906 0.913
#  0.909]

# %%
#学習したモデルを使ってtestデータの推論を実施
import pandas as pd
import os
import zipfile
import torch
import torch.nn as nn
import torch.optim as optim
import albumentations
from torch.utils.data import Dataset
from torchvision import datasets, models, transforms
from PIL import Image, ImageFilter

work_dir           = '/content/sample_data'
save_dir           = '/content/drive/MyDrive/2024_AIContest2/Thema1/'
test_zip_file_path = '/content/sample_data/test_images.zip'
test_file_dir      = os.path.join(work_dir, 'test_images')
report_format_tsv  = os.path.join(work_dir, 'sample_submit.tsv')
best_model_path    = os.path.join(save_dir, 'pth/20250406_2031_original_model_23.pth')
output_file        = os.path.join(save_dir, 'output/20250406_out_submit_1.tsv')

TARGET_NUM = 10

# ZIPファイルを解凍する
def extract_zip(zip_file_path, extract_to):

    if not os.path.exists(test_file_dir):
        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            zip_ref.extractall(extract_to)

extract_zip(test_zip_file_path, work_dir)

#dataサイズ定義
dataset_sizes= {
    'train':len(image_datasets['train']),
    'val':len(image_datasets['val'])
}

#submit用dataset定義
class For_Submission_Datasets(Dataset):

    def __init__(self, data_transform):
        self.df = pd.read_csv(report_format_tsv ,sep='\t',names=['filename','target'])
        self.data_transform = data_transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):
        file = self.df['filename'][index]
        image = Image.open(test_file_dir +'/'+ file)
        image = self.data_transform(image)

        return image,file

#submit用dataset作成
subdataset = For_Submission_Datasets(data_transform=data_transforms['val'])

#submit用dataloaders作成
subdataloader = torch.utils.data.DataLoader(subdataset, batch_size=1, shuffle=False, num_workers=0, drop_last=True)

#精度の最も高いモデルをロード
#モデルの名前を適宜変更して、最も精度の高いモデルをロードしましょう
best_model = get_model(target_num = TARGET_NUM)
best_model.load_state_dict(torch.load(best_model_path, map_location=lambda storage, loc: storage), strict=True)

submit = pd.read_csv(report_format_tsv,sep='\t', header=None)
#print(submit)
#テストデータに対しての推論
pred = []
for i,(inputs, labels) in enumerate(subdataloader):
    inputs = inputs.to(DEVICE)
    best_model.eval()
    outputs = best_model(inputs)
    _, preds = torch.max(outputs, 1)
    pred.append(preds.item())

df_test = pd.read_csv(report_format_tsv ,sep='\t',names=['filename','target'])

df_test['pred'] = pred
#print(df_test)
submit[1] = pred

submit.to_csv(output_file ,sep='\t', index=False, header=False)
print(submit)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#                   0  1
# 0        test_0.jpg  6
# 1        test_1.jpg  7
# 2        test_2.jpg  5
# 3        test_3.jpg  0
# 4        test_4.jpg  3
# ...             ... ..
# 7995  test_7995.jpg  9
# 7996  test_7996.jpg  6
# 7997  test_7997.jpg  8
# 7998  test_7998.jpg  8
# 7999  test_7999.jpg  8
#
# [8000 rows x 2 columns]

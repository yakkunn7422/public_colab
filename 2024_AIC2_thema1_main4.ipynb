# %% [markdown]
# <a href="https://colab.research.google.com/github/yakkunn7422/public_colab/blob/main/2024_AIC2_thema1_main4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Googleドライブのマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -fr /content/sample_data/new_train_images
# !rm -fr /content/sample_data/test_images.zip
# !rm -fr /content/sample_data/train_images.zip
# !rm -fr /content/sample_data/train_master.tsv
# !rm -fr /content/sample_data/sample_submit.tsv
# !rm -fr /content/sample_data/resnet18-5c106cde.pth
# !rm -fr /content/sample_data/label_master.tsv

# %%
import os
print("カレントワーキングディレクトリは[" + os.getcwd() + "]です")
# Out:
# カレントワーキングディレクトリは[/content]です

# %%
# sample_data 配下にResnet18使う際のデータ一式を持ってくるコード

import os
import pandas as pd
import zipfile
import shutil
import numpy as np

#パラメータ
TRAIN_RATIO = 0.8



#trainイメージファイル、testイメージファイル等のファイル格納先
input_dir = '/content/drive/MyDrive/2024_AIContest2/Thema1'
work_dir =  '/content/sample_data'

#trainデータの解凍・成形先のディレクトリ
output_dir = os.path.join(work_dir, 'new_train_images')

#trainデータファイル名
zip_file_path = os.path.join(work_dir, 'train_images.zip')
#trainデータのラベルまとめファイル名
tsv_file_path = os.path.join(work_dir, 'train_master.tsv')

# ファイルをCOPYする
def simple_copy_files(src_dir, dst_dir):
    os.makedirs(dst_dir, exist_ok=True)  # コピー先ディレクトリを作成（既に存在する場合は何もしない）

    for file_name in os.listdir(src_dir):
        full_file_name = os.path.join(src_dir, file_name)
        if os.path.isfile(full_file_name):
            shutil.copy2(full_file_name, dst_dir)  # ファイルのコピー

# トレインとバリデーション用のディレクトリおよびその中のラベルごとのサブディレクトリを作成する
def create_directories(base_dir, labels):

    train_dir = os.path.join(base_dir, 'train')
    val_dir = os.path.join(base_dir, 'val')

    for dir_path in [train_dir, val_dir]:
        if not os.path.exists(dir_path):
            os.makedirs(dir_path)

    for label in labels:
        os.makedirs(os.path.join(train_dir, str(label)), exist_ok=True)
        os.makedirs(os.path.join(val_dir, str(label)), exist_ok=True)

    return train_dir, val_dir

# ZIPファイルを解凍する
def extract_zip(zip_file_path, extract_to):

    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)

# TSVファイルを読み込み、1行目を削除してデータフレームを準備する
def load_and_prepare_data(tsv_file_path):

    df = pd.read_csv(tsv_file_path, sep='\t', names=['filename', 'label_id'])
    df = df.iloc[1:].reset_index(drop=True)

    return df

# 画像ファイルをディレクトリに分配する
def distribute_images(df, image_dir, train_dir, val_dir, train_ratio=0.8):

    for label in df['label_id'].unique():
        label_images = df[df['label_id'] == label]['filename'].tolist()
        # シャッフルして分割

        np.random.shuffle(label_images)
        train_size = int(len(label_images) * train_ratio)
        train_images = label_images[:train_size]
        val_images = label_images[train_size:]

        for image_name in train_images:
            src_path = os.path.join(image_dir, image_name)
            dst_path = os.path.join(train_dir, str(label), image_name)
            shutil.copy(src_path, dst_path)

        for image_name in val_images:
            src_path = os.path.join(image_dir, image_name)
            dst_path = os.path.join(val_dir, str(label), image_name)
            shutil.copy(src_path, dst_path)

# ディレクトリ内のアイテムを探索し数を表示する
def count_files_recursive(directory):
    total_files = 0

    for root, dirs, files in os.walk(directory):
        files_count = len(files)
        subdir_relative = os.path.relpath(root, directory)
        print(f"Directory '{subdir_relative}' contains {files_count} files.")

        total_files += files_count

    print(f"Total files in '{directory}': {total_files}")

# メイン処理を実行する関数
def main(zip_file_path, tsv_file_path, output_dir, train_ratio=0.8):

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    df = load_and_prepare_data(tsv_file_path)

    extract_zip(zip_file_path, output_dir)

    labels = df['label_id'].unique()

    train_dir, val_dir = create_directories(output_dir, labels)
    image_dir = os.path.join(output_dir, 'train_images')

    distribute_images(df, image_dir, train_dir, val_dir, train_ratio)

    # 解凍後のディレクトリを削除
    if os.path.exists(image_dir):
        shutil.rmtree(image_dir)
        print(f"Deleted temporary directory: {image_dir}")

# 実行
# INPUTディレクトリのファイルをOUTPUTディレクトリにすべてCOPY
simple_copy_files(input_dir,work_dir)
# Train.zipファイル内の画像をtrain、val毎(割合い0.8)かつラベル毎のディレクトリに配置
main(zip_file_path, tsv_file_path, output_dir, train_ratio = TRAIN_RATIO)

count_files_recursive(output_dir)
# Out:
# Deleted temporary directory: /content/sample_data/new_train_images/train_images
# Directory '.' contains 0 files.
# Directory 'train' contains 0 files.
# Directory 'train/8' contains 400 files.
# Directory 'train/4' contains 400 files.
# Directory 'train/0' contains 400 files.
# Directory 'train/5' contains 400 files.
# Directory 'train/6' contains 400 files.
# Directory 'train/7' contains 400 files.
# Directory 'train/1' contains 400 files.
# Directory 'train/2' contains 400 files.
# Directory 'train/3' contains 400 files.
# Directory 'train/9' contains 400 files.
# Directory 'val' contains 0 files.
# Directory 'val/8' contains 100 files.
# Directory 'val/4' contains 100 files.
# Directory 'val/0' contains 100 files.
# Directory 'val/5' contains 100 files.
# Directory 'val/6' contains 100 files.
# Directory 'val/7' contains 100 files.
# Directory 'val/1' contains 100 files.
# Directory 'val/2' contains 100 files.
# Directory 'val/3' contains 100 files.
# Directory 'val/9' contains 100 files.
# Total files in '/content/sample_data/new_train_images': 5000

# %%
# Resnet18で学習
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import zipfile
import torch
import torch.nn as nn
import torch.optim as optim
import albumentations
from torch.utils.data import Dataset
from torchvision import datasets, models, transforms
from PIL import Image, ImageFilter

input_dir = '/content/drive/MyDrive/2024_AIContest2/Thema1'
work_dir =  '/content/sample_data'


#定数設定
DEVICE= "cuda"
TARGET_NUM = 10
BATCH_SIZE = 128
LEARNING_RATE = 0.005
EPOCH = 40
TRANSFER_LEARNING = False
MODEL_LEARNING = True

#transforms定義
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(256),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
}

#dataset作成
image_datasets = {
    'train': datasets.ImageFolder('/content/sample_data/new_train_images/train',data_transforms['train']),
    'val': datasets.ImageFolder('/content/sample_data/new_train_images/val',data_transforms['val'])
}

#dataloaders作成
image_dataloaders = {
    'train': torch.utils.data.DataLoader(image_datasets['train'], batch_size=BATCH_SIZE, shuffle=True, num_workers=0, drop_last=True),
    'val': torch.utils.data.DataLoader(image_datasets['val'], batch_size=BATCH_SIZE, shuffle=False, num_workers=0, drop_last=True),
}

#dataサイズ定義
dataset_sizes= {
    'train':len(image_datasets['train']),
    'val':len(image_datasets['val'])
}

if not MODEL_LEARNING:
    print("処理を停止します。")
    sys.exit()  # プログラムを終了

#ResNet18モデル定義
def get_model(target_num,isPretrained=False):

    if(isPretrained):
        model_ft = models.resnet18(pretrained=False)
        model_ft.load_state_dict(torch.load(os.path.join(work_dir, 'resnet18-5c106cde.pth'), map_location=lambda storage, loc: storage), strict=True)
    else:
        model_ft = models.resnet18(pretrained=False)

    model_ft.fc = nn.Linear(512, target_num)
    model_ft = model_ft.to(DEVICE)
    return model_ft

#モデルのインスタンス作成 転移学習なし（FALSE）
model_ft = get_model(target_num=TARGET_NUM,isPretrained=TRANSFER_LEARNING)

#最適化関数定義
optimizer = optim.SGD(model_ft.parameters(),lr=LEARNING_RATE, momentum=0.9)

#loss関数定義
criterion = nn.CrossEntropyLoss()

#モデル訓練用関数
def train_model(model, criterion, optimizer, num_epochs=5,is_saved = False):
    best_acc = 0.0


    train_arr1 = np.zeros(EPOCH)
    val_arr1   = np.zeros(EPOCH)

    # エポック数だけ下記工程の繰り返し
    for epoch in range(num_epochs):

        for phase in ['train', 'val']:
            print('{}:フェイズ'.format(phase))

            # 訓練フェイズと検証フェイズの切り替え
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            # dataloadersからバッチサイズだけデータ取り出し、下記工程（1−5）の繰り返し
            for i,(inputs, labels) in enumerate(image_dataloaders[phase]):
                inputs = inputs.to(DEVICE)
                labels = labels.to(DEVICE)

                # 1. optimizerの勾配初期化
                optimizer.zero_grad()

                # 2.モデルに入力データをinputし、outputを取り出す
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)

                # 3. outputと正解ラベルから、lossを算出
                loss = criterion(outputs, labels)
                print('   loaders:{}回目'.format(i+1)  ,'   loss:{}'.format(loss))

                if phase == 'train':
                    # 4. 誤差逆伝播法により勾配の算出
                    loss.backward()
                    # 5. optimizerのパラメータ更新
                    optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            print('EPOCH{}回目 {} Loss: {:.4f} Acc: {:.4f}'.format(epoch, phase, epoch_loss, epoch_acc))

            if phase == 'train':
                train_arr1[epoch]=epoch_acc
            else:
                val_arr1[epoch]=epoch_acc

            # C. 今までのエポックでの精度よりも高い場合はモデルの保存
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                if(is_saved):
                    print('Save File original_model_{}.pth'.format(epoch))
                    torch.save(model.state_dict(), '/content/drive/MyDrive/2024_AIContest2/Thema1/pth/original_model_{}.pth'.format(epoch))


    print('Best val Acc: {:4f}'.format(best_acc))
    print(train_arr1)
    print(val_arr1)
    train_ser1 = pd.Series(train_arr1,name='train_acc')
    result_data = pd.DataFrame(train_ser1)
    result_data['val_acc']=val_arr1
    result_data.plot()
    plt.show()

train_model(model = model_ft,criterion = criterion,optimizer = optimizer,num_epochs=EPOCH,is_saved = True)
# Out:
# train:フェイズ
#    loaders:1回目    loss:2.420100688934326
#    loaders:2回目    loss:2.333249568939209
#    loaders:3回目    loss:2.328274726867676
#    loaders:4回目    loss:2.26544189453125
#    loaders:5回目    loss:2.2438957691192627
#    loaders:6回目    loss:2.3153388500213623
#    loaders:7回目    loss:2.3423821926116943
#    loaders:8回目    loss:2.3037140369415283
#    loaders:9回目    loss:2.2503409385681152
#    loaders:10回目    loss:2.1969597339630127
#    loaders:11回目    loss:2.1064109802246094
#    loaders:12回目    loss:2.170905828475952
#    loaders:13回目    loss:2.0460190773010254
#    loaders:14回目    loss:2.082411766052246
#    loaders:15回目    loss:2.149055004119873
#    loaders:16回目    loss:1.9756622314453125
#    loaders:17回目    loss:1.9802265167236328
#    loaders:18回目    loss:1.9447367191314697
#    loaders:19回目    loss:1.9689642190933228
#    loaders:20回目    loss:1.9133654832839966
#    loaders:21回目    loss:1.8807399272918701
#    loaders:22回目    loss:1.8887584209442139
#    loaders:23回目    loss:1.8958462476730347
#    loaders:24回目    loss:1.8233425617218018
#    loaders:25回目    loss:1.8866419792175293
#    loaders:26回目    loss:1.8132508993148804
#    loaders:27回目    loss:1.9121383428573608
#    loaders:28回目    loss:1.8625164031982422
#    loaders:29回目    loss:1.6323708295822144
#    loaders:30回目    loss:1.7659426927566528
#    loaders:31回目    loss:1.8335886001586914
#    loaders:6回目    loss:1.9637327194213867
#    loaders:7回目    loss:1.9449656009674072
# EPOCH10回目 val Loss: 2.0087 Acc: 0.2990
# train:フェイズ
#    loaders:1回目    loss:0.7556760907173157
#    loaders:2回目    loss:1.0945444107055664
#    loaders:3回目    loss:0.9218831062316895
#    loaders:4回目    loss:0.8272597193717957
#    loaders:5回目    loss:0.931572675704956
#    loaders:6回目    loss:0.9443944096565247
#    loaders:7回目    loss:0.8840665817260742
#    loaders:8回目    loss:0.8487999439239502
#    loaders:9回目    loss:0.8694868683815002
#    loaders:10回目    loss:1.0169047117233276
#    loaders:11回目    loss:0.9392107725143433
#    loaders:12回目    loss:0.9098919034004211
#    loaders:13回目    loss:0.9507007598876953
#    loaders:14回目    loss:0.9743574857711792
#    loaders:15回目    loss:0.9458893537521362
#    loaders:16回目    loss:0.8597875237464905
#    loaders:17回目    loss:0.8976972103118896
#    loaders:18回目    loss:0.9368131756782532
#    loaders:19回目    loss:0.9239795804023743
#    loaders:20回目    loss:0.959394633769989
#    loaders:21回目    loss:0.858772873878479
#    loaders:22回目    loss:0.9479283094406128
#    loaders:23回目    loss:0.8759518265724182
#    loaders:24回目    loss:0.8044829368591309
#    loaders:25回目    loss:0.8574249744415283
#    loaders:26回目    loss:0.8950746059417725
#    loaders:27回目    loss:0.7667044997215271
#    loaders:28回目    loss:0.9488339424133301
#    loaders:29回目    loss:0.9628081321716309
#    loaders:30回目    loss:0.8305541276931763
#    loaders:31回目    loss:0.9879546165466309
# EPOCH11回目 train Loss: 0.9001 Acc: 0.6673
# val:フェイズ
#    loaders:1回目    loss:1.4080344438552856
#    loaders:2回目    loss:1.5448275804519653
#    loaders:3回目    loss:1.5981208086013794
#    loaders:4回目    loss:1.3748029470443726
#    loaders:5回目    loss:2.1051716804504395
#    loaders:6回目    loss:1.8554083108901978
#    loaders:7回目    loss:0.8355699777603149
# EPOCH11回目 val Loss: 1.3724 Acc: 0.3900
# train:フェイズ
#    loaders:1回目    loss:0.8697715401649475
#    loaders:2回目    loss:0.6789883375167847
#    loaders:3回目    loss:0.7833482027053833
#    loaders:4回目    loss:0.8503350019454956
#    loaders:5回目    loss:0.7788172364234924
#    loaders:6回目    loss:0.7886533737182617
#    loaders:7回目    loss:0.8417520523071289
#    loaders:8回目    loss:0.6766350269317627
#    loaders:9回目    loss:0.885238528251648
#    loaders:10回目    loss:0.7634345889091492
#    loaders:11回目    loss:0.7132925391197205
#    loaders:12回目    loss:0.8588453531265259
#    loaders:13回目    loss:0.830742359161377
#    loaders:14回目    loss:0.8998580574989319
#    loaders:15回目    loss:0.8031182885169983
#    loaders:16回目    loss:0.7810196280479431
#    loaders:17回目    loss:0.7459603548049927
#    loaders:18回目    loss:0.8574353456497192
#    loaders:19回目    loss:0.7810306549072266
#    loaders:20回目    loss:1.00925874710083
#    loaders:21回目    loss:0.8711495399475098
#    loaders:22回目    loss:0.8784014582633972
#    loaders:23回目    loss:0.986140787601471
#    loaders:24回目    loss:0.8749489784240723
#    loaders:25回目    loss:0.89374178647995
#    loaders:26回目    loss:0.8055232167243958
#    loaders:27回目    loss:0.8467304706573486
#    loaders:28回目    loss:0.9685039520263672
#    loaders:29回目    loss:0.7803438901901245
#    loaders:30回目    loss:0.8474283218383789
#    loaders:31回目    loss:0.8306275010108948
# EPOCH12回目 train Loss: 0.8250 Acc: 0.6943
# val:フェイズ
#    loaders:1回目    loss:1.0422126054763794
#    loaders:2回目    loss:1.2947909832000732
#    loaders:3回目    loss:1.583533525466919
#    loaders:4回目    loss:2.0453295707702637
#    loaders:5回目    loss:1.013973593711853
#    loaders:6回目    loss:1.2316986322402954
#    loaders:7回目    loss:1.7112513780593872
# EPOCH12回目 val Loss: 1.2701 Acc: 0.4680
# Save File original_model_12.pth
# train:フェイズ
#    loaders:1回目    loss:0.6871578693389893
#    loaders:2回目    loss:0.7139429450035095
#    loaders:3回目    loss:0.9449377655982971
#    loaders:4回目    loss:0.7072104811668396
#    loaders:5回目    loss:0.7857007384300232
#    loaders:6回目    loss:0.7310225367546082
#    loaders:7回目    loss:0.749640941619873
#    loaders:8回目    loss:0.6559007167816162
#    loaders:9回目    loss:0.8292567133903503
#    loaders:10回目    loss:0.655189573764801
#    loaders:11回目    loss:0.7606487274169922
#    loaders:12回目    loss:0.8259744048118591
#    loaders:13回目    loss:0.7601414918899536
#    loaders:14回目    loss:0.7955800890922546
#    loaders:15回目    loss:0.7078754901885986
#    loaders:16回目    loss:0.7533417344093323
#    loaders:17回目    loss:0.917858898639679
#    loaders:18回目    loss:0.676324725151062
#    loaders:19回目    loss:0.7375425696372986
#    loaders:20回目    loss:0.9288684725761414
#    loaders:21回目    loss:0.8336628675460815
#    loaders:22回目    loss:0.7616944909095764
#    loaders:23回目    loss:0.9586040377616882
#    loaders:24回目    loss:0.8258873820304871
#    loaders:25回目    loss:0.7209598422050476
#    loaders:26回目    loss:0.8998117446899414
#    loaders:27回目    loss:0.6897323727607727
#    loaders:28回目    loss:0.7811018228530884
#    loaders:29回目    loss:0.7828353643417358
#    loaders:30回目    loss:0.9074467420578003
#    loaders:31回目    loss:0.6109614968299866
# EPOCH13回目 train Loss: 0.7711 Acc: 0.7143
# val:フェイズ
#    loaders:1回目    loss:0.9392412900924683
#    loaders:2回目    loss:0.7353407740592957
#    loaders:3回目    loss:1.695542812347412
#    loaders:4回目    loss:1.8853739500045776
#    loaders:5回目    loss:1.5326770544052124
#    loaders:6回目    loss:1.2583391666412354
#    loaders:7回目    loss:1.654767632484436
# EPOCH13回目 val Loss: 1.2418 Acc: 0.4560
# train:フェイズ
#    loaders:1回目    loss:0.7532962560653687
#    loaders:2回目    loss:0.701833188533783
#    loaders:3回目    loss:0.7095980048179626
#    loaders:4回目    loss:0.6900888085365295
#    loaders:5回目    loss:0.7377868890762329
#    loaders:6回目    loss:0.6811057925224304
#    loaders:7回目    loss:0.792615532875061
#    loaders:8回目    loss:0.6552618145942688
#    loaders:9回目    loss:0.6489686369895935
#    loaders:10回目    loss:0.7492586970329285
#    loaders:11回目    loss:0.7082569599151611
#    loaders:12回目    loss:0.6989161372184753
#    loaders:13回目    loss:0.7543798089027405
#    loaders:14回目    loss:0.727627694606781
#    loaders:15回目    loss:0.6351590156555176
#    loaders:16回目    loss:0.6609879732131958
#    loaders:17回目    loss:0.7939872741699219
#    loaders:18回目    loss:0.7758052945137024
#    loaders:19回目    loss:0.773621678352356
#    loaders:20回目    loss:0.7159637808799744
#    loaders:21回目    loss:0.6771662831306458
#    loaders:22回目    loss:0.7160187363624573
#    loaders:23回目    loss:0.8235911726951599
#    loaders:24回目    loss:0.7141236066818237
#    loaders:25回目    loss:0.8370767831802368
#    loaders:26回目    loss:0.8048151731491089
#    loaders:27回目    loss:0.7262042164802551
#    loaders:28回目    loss:0.7665069103240967
#    loaders:29回目    loss:0.7720332145690918
#    loaders:30回目    loss:0.6675581932067871
#    loaders:31回目    loss:0.7626619338989258
# EPOCH14回目 train Loss: 0.7242 Acc: 0.7345
# val:フェイズ
#    loaders:1回目    loss:1.779313564300537
#    loaders:2回目    loss:2.9458885192871094
#    loaders:3回目    loss:2.5555613040924072
#    loaders:4回目    loss:1.2483291625976562
#    loaders:5回目    loss:1.630022644996643
#    loaders:6回目    loss:2.0718436241149902
#    loaders:7回目    loss:0.9184206128120422
# EPOCH14回目 val Loss: 1.6831 Acc: 0.3900
# train:フェイズ
#    loaders:1回目    loss:0.7315782904624939
#    loaders:2回目    loss:0.6489904522895813
#    loaders:3回目    loss:0.6756009459495544
#    loaders:4回目    loss:0.7650904059410095
#    loaders:5回目    loss:0.7851274013519287
#    loaders:6回目    loss:0.6972388029098511
#    loaders:7回目    loss:0.6751111745834351
#    loaders:8回目    loss:0.7788547277450562
#    loaders:9回目    loss:0.780830979347229
#    loaders:10回目    loss:0.8224244117736816
#    loaders:11回目    loss:0.6683581471443176
#    loaders:12回目    loss:0.5627571940422058
#    loaders:13回目    loss:0.6579686999320984
#    loaders:14回目    loss:0.6651802062988281
#    loaders:15回目    loss:0.6366817951202393
#    loaders:16回目    loss:0.6084269285202026
#    loaders:17回目    loss:0.6205434799194336
#    loaders:18回目    loss:0.6930188536643982
#    loaders:19回目    loss:0.6361103057861328
#    loaders:20回目    loss:0.6076940298080444
#    loaders:21回目    loss:0.5035186409950256
#    loaders:22回目    loss:0.5797936320304871
#    loaders:23回目    loss:0.6312634348869324
#    loaders:24回目    loss:0.5119625926017761
#    loaders:25回目    loss:0.6989322304725647
#    loaders:26回目    loss:0.6385625004768372
#    loaders:27回目    loss:0.7006310224533081
#    loaders:28回目    loss:0.734346866607666
#    loaders:29回目    loss:0.6766208410263062
#    loaders:30回目    loss:0.6672624945640564
#    loaders:31回目    loss:0.7161049246788025
# EPOCH15回目 train Loss: 0.6649 Acc: 0.7628
# val:フェイズ
#    loaders:1回目    loss:1.6450326442718506
#    loaders:2回目    loss:1.7309194803237915
#    loaders:3回目    loss:1.8897895812988281
#    loaders:4回目    loss:1.4787310361862183
#    loaders:5回目    loss:1.6333026885986328
#    loaders:6回目    loss:1.8786394596099854
#    loaders:7回目    loss:0.8238580822944641
# EPOCH15回目 val Loss: 1.4183 Acc: 0.4390
# train:フェイズ
#    loaders:1回目    loss:0.5594058632850647
#    loaders:2回目    loss:0.7726714611053467
#    loaders:3回目    loss:0.5469006299972534
#    loaders:4回目    loss:0.5468239188194275
#    loaders:5回目    loss:0.5554502010345459
#    loaders:6回目    loss:0.6042271852493286
#    loaders:7回目    loss:0.6318910717964172
#    loaders:8回目    loss:0.7040761113166809
#    loaders:9回目    loss:0.6332693099975586
#    loaders:10回目    loss:0.6493270993232727
#    loaders:11回目    loss:0.5717611908912659
#    loaders:12回目    loss:0.6452910900115967
#    loaders:13回目    loss:0.6940966248512268
#    loaders:14回目    loss:0.6149245500564575
#    loaders:15回目    loss:0.6553018093109131
#    loaders:16回目    loss:0.5455291271209717
#    loaders:17回目    loss:0.5570943355560303
#    loaders:18回目    loss:0.5890082716941833
#    loaders:19回目    loss:0.5642631649971008
#    loaders:20回目    loss:0.6175247430801392
#    loaders:21回目    loss:0.5875334739685059
#    loaders:22回目    loss:0.5538565516471863
#    loaders:23回目    loss:0.6094298958778381
#    loaders:24回目    loss:0.5765882730484009
#    loaders:25回目    loss:0.5431604981422424
#    loaders:26回目    loss:0.6325194239616394
#    loaders:27回目    loss:0.553255558013916
#    loaders:28回目    loss:0.5247288942337036
#    loaders:29回目    loss:0.5264437198638916
#    loaders:30回目    loss:0.43510702252388
#    loaders:31回目    loss:0.519760251045227
# EPOCH16回目 train Loss: 0.5863 Acc: 0.7933
# val:フェイズ
#    loaders:1回目    loss:0.3767646551132202
#    loaders:2回目    loss:0.5815257430076599
#    loaders:3回目    loss:2.077388286590576
#    loaders:4回目    loss:1.9598534107208252
#    loaders:5回目    loss:2.1790547370910645
#    loaders:6回目    loss:2.055896282196045
#    loaders:7回目    loss:1.692954182624817
# EPOCH16回目 val Loss: 1.3982 Acc: 0.4330
# train:フェイズ
#    loaders:1回目    loss:0.5529138445854187
#    loaders:2回目    loss:0.6503996849060059
#    loaders:3回目    loss:0.4724733233451843
#    loaders:4回目    loss:0.5244751572608948
#    loaders:5回目    loss:0.5083468556404114
#    loaders:6回目    loss:0.4280172288417816
#    loaders:7回目    loss:0.4404159486293793
#    loaders:8回目    loss:0.6494272351264954
#    loaders:9回目    loss:0.5017654299736023
#    loaders:10回目    loss:0.5737420320510864
#    loaders:11回目    loss:0.7177245616912842
#    loaders:12回目    loss:0.5519262552261353
#    loaders:13回目    loss:0.45910388231277466
#    loaders:14回目    loss:0.6268340349197388
#    loaders:15回目    loss:0.5079676508903503
#    loaders:16回目    loss:0.5892370343208313
#    loaders:17回目    loss:0.4009142518043518
#    loaders:18回目    loss:0.5343921780586243
#    loaders:19回目    loss:0.5265016555786133
#    loaders:20回目    loss:0.4834836423397064
#    loaders:21回目    loss:0.4508570432662964
#    loaders:22回目    loss:0.3614038825035095
#    loaders:23回目    loss:0.5652620196342468
#    loaders:24回目    loss:0.4835525453090668
#    loaders:25回目    loss:0.6753904223442078
#    loaders:26回目    loss:0.46884065866470337
#    loaders:27回目    loss:0.5193312764167786
#    loaders:28回目    loss:0.6411352157592773
#    loaders:29回目    loss:0.5452964901924133
#    loaders:30回目    loss:0.523124635219574
#    loaders:31回目    loss:0.5844091176986694
# EPOCH17回目 train Loss: 0.5286 Acc: 0.8110
# val:フェイズ
#    loaders:1回目    loss:1.305657148361206
#    loaders:2回目    loss:1.6481890678405762
#    loaders:3回目    loss:1.8980505466461182
#    loaders:4回目    loss:1.4201771020889282
#    loaders:5回目    loss:1.7560948133468628
#    loaders:6回目    loss:1.55514395236969
#    loaders:7回目    loss:1.3064448833465576
# EPOCH17回目 val Loss: 1.3939 Acc: 0.4460
# train:フェイズ
#    loaders:1回目    loss:0.4772491455078125
#    loaders:2回目    loss:0.41687414050102234
#    loaders:3回目    loss:0.40326204895973206
#    loaders:4回目    loss:0.4207141697406769
#    loaders:5回目    loss:0.49890443682670593
#    loaders:6回目    loss:0.47762495279312134
#    loaders:7回目    loss:0.4096713066101074
#    loaders:8回目    loss:0.5571424961090088
#    loaders:9回目    loss:0.488798588514328
#    loaders:10回目    loss:0.4242977201938629
#    loaders:11回目    loss:0.4582681655883789
#    loaders:12回目    loss:0.45211997628211975
#    loaders:13回目    loss:0.4287106692790985
#    loaders:14回目    loss:0.46972447633743286
#    loaders:15回目    loss:0.3898700773715973
#    loaders:16回目    loss:0.48172301054000854
#    loaders:17回目    loss:0.46287575364112854
#    loaders:18回目    loss:0.4462180733680725
#    loaders:19回目    loss:0.4636213183403015
#    loaders:20回目    loss:0.4289202094078064
#    loaders:21回目    loss:0.4931172728538513
#    loaders:22回目    loss:0.4592876136302948
#    loaders:23回目    loss:0.4540526866912842
#    loaders:24回目    loss:0.37495508790016174
#    loaders:25回目    loss:0.5232611298561096
#    loaders:26回目    loss:0.4508506655693054
#    loaders:27回目    loss:0.4277594983577728
#    loaders:28回目    loss:0.5174949765205383
#    loaders:29回目    loss:0.4919508397579193
#    loaders:30回目    loss:0.4661181569099426
#    loaders:31回目    loss:0.6023455262184143
# EPOCH18回目 train Loss: 0.4582 Acc: 0.8385
# val:フェイズ
#    loaders:1回目    loss:0.6420157551765442
#    loaders:2回目    loss:0.6342797875404358
#    loaders:3回目    loss:2.09967041015625
#    loaders:4回目    loss:1.8828097581863403
#    loaders:5回目    loss:1.7197308540344238
#    loaders:6回目    loss:1.1477971076965332
#    loaders:7回目    loss:2.7307465076446533
# EPOCH18回目 val Loss: 1.3897 Acc: 0.4910
# Save File original_model_18.pth
# train:フェイズ
#    loaders:1回目    loss:0.3813425898551941
#    loaders:2回目    loss:0.405502587556839
#    loaders:3回目    loss:0.34733304381370544
#    loaders:4回目    loss:0.49151232838630676
#    loaders:5回目    loss:0.36231690645217896
#    loaders:6回目    loss:0.3294526934623718
#    loaders:7回目    loss:0.4831164479255676
#    loaders:8回目    loss:0.49082571268081665
#    loaders:9回目    loss:0.3816278874874115
#    loaders:10回目    loss:0.3685896694660187
#    loaders:11回目    loss:0.6809046864509583
#    loaders:12回目    loss:0.43643954396247864
#    loaders:13回目    loss:0.3796997666358948
#    loaders:14回目    loss:0.30217257142066956
#    loaders:15回目    loss:0.3585208058357239
#    loaders:16回目    loss:0.38718608021736145
#    loaders:17回目    loss:0.5394084453582764
#    loaders:18回目    loss:0.37774068117141724
#    loaders:19回目    loss:0.3932533264160156
#    loaders:20回目    loss:0.5249331593513489
#    loaders:21回目    loss:0.43934622406959534
#    loaders:22回目    loss:0.4923761487007141
#    loaders:23回目    loss:0.35706496238708496
#    loaders:24回目    loss:0.539600670337677
#    loaders:25回目    loss:0.3939282298088074
#    loaders:26回目    loss:0.5253406167030334
#    loaders:27回目    loss:0.4081295132637024
#    loaders:28回目    loss:0.28236502408981323
#    loaders:29回目    loss:0.3984113335609436
#    loaders:30回目    loss:0.40078288316726685
#    loaders:31回目    loss:0.3905992805957794
# EPOCH19回目 train Loss: 0.4176 Acc: 0.8598
# val:フェイズ
#    loaders:1回目    loss:1.336148738861084
#    loaders:2回目    loss:0.9817023873329163
#    loaders:3回目    loss:1.1913578510284424
#    loaders:4回目    loss:2.3308215141296387
#    loaders:5回目    loss:1.4484031200408936
#    loaders:6回目    loss:1.7149020433425903
#    loaders:7回目    loss:1.6201664209365845
# EPOCH19回目 val Loss: 1.3598 Acc: 0.4780
# train:フェイズ
#    loaders:1回目    loss:0.19854077696800232
#    loaders:2回目    loss:0.3260136544704437
#    loaders:3回目    loss:0.35534387826919556
#    loaders:4回目    loss:0.4100326895713806
#    loaders:5回目    loss:0.3860117793083191
#    loaders:6回目    loss:0.3388007581233978
#    loaders:7回目    loss:0.346027135848999
#    loaders:8回目    loss:0.3286054730415344
#    loaders:9回目    loss:0.41457945108413696
#    loaders:10回目    loss:0.29598867893218994
#    loaders:11回目    loss:0.4263850450515747
#    loaders:12回目    loss:0.38290828466415405
#    loaders:13回目    loss:0.4395923614501953
#    loaders:14回目    loss:0.2531851530075073
#    loaders:15回目    loss:0.38975659012794495
#    loaders:16回目    loss:0.37675729393959045
#    loaders:17回目    loss:0.2925572097301483
#    loaders:18回目    loss:0.39760151505470276
#    loaders:19回目    loss:0.31585174798965454
#    loaders:20回目    loss:0.335798978805542
#    loaders:21回目    loss:0.33472740650177
#    loaders:22回目    loss:0.34921661019325256
#    loaders:23回目    loss:0.3031842112541199
#    loaders:24回目    loss:0.34423473477363586
#    loaders:25回目    loss:0.2688148617744446
#    loaders:26回目    loss:0.34393081068992615
#    loaders:27回目    loss:0.38334476947784424
#    loaders:28回目    loss:0.3591780662536621
#    loaders:29回目    loss:0.23692190647125244
#    loaders:30回目    loss:0.3962719440460205
#    loaders:31回目    loss:0.34473446011543274
# EPOCH20回目 train Loss: 0.3416 Acc: 0.8908
# val:フェイズ
#    loaders:1回目    loss:1.0555131435394287
#    loaders:2回目    loss:1.2723774909973145
#    loaders:3回目    loss:1.7656514644622803
#    loaders:4回目    loss:3.247941732406616
#    loaders:5回目    loss:1.7241127490997314
#    loaders:6回目    loss:1.3410004377365112
#    loaders:7回目    loss:1.6553795337677002
# EPOCH20回目 val Loss: 1.5439 Acc: 0.4580
# train:フェイズ
#    loaders:1回目    loss:0.24443063139915466
#    loaders:2回目    loss:0.2026074379682541
#    loaders:3回目    loss:0.4250556230545044
#    loaders:4回目    loss:0.34259164333343506
#    loaders:5回目    loss:0.2722092568874359
#    loaders:6回目    loss:0.2231338620185852
#    loaders:7回目    loss:0.22612585127353668
#    loaders:8回目    loss:0.2953527867794037
#    loaders:9回目    loss:0.1931130439043045
#    loaders:10回目    loss:0.36657223105430603
#    loaders:11回目    loss:0.2478913515806198
#    loaders:12回目    loss:0.3402124047279358
#    loaders:13回目    loss:0.2428022027015686
#    loaders:14回目    loss:0.23607151210308075
#    loaders:15回目    loss:0.2899063229560852
#    loaders:16回目    loss:0.36555740237236023
#    loaders:17回目    loss:0.3133006691932678
#    loaders:18回目    loss:0.20225249230861664
#    loaders:19回目    loss:0.2647537887096405
#    loaders:20回目    loss:0.3437153995037079
#    loaders:21回目    loss:0.35239937901496887
#    loaders:22回目    loss:0.27684831619262695
#    loaders:23回目    loss:0.31945767998695374
#    loaders:24回目    loss:0.4065186083316803
#    loaders:25回目    loss:0.4915062487125397
#    loaders:26回目    loss:0.29274266958236694
#    loaders:27回目    loss:0.3811033368110657
#    loaders:28回目    loss:0.3082027733325958
#    loaders:29回目    loss:0.4968683123588562
#    loaders:30回目    loss:0.4282383620738983
#    loaders:31回目    loss:0.313471257686615
# EPOCH21回目 train Loss: 0.3106 Acc: 0.8985
# val:フェイズ
#    loaders:1回目    loss:1.2708524465560913
#    loaders:2回目    loss:0.7766990661621094
#    loaders:3回目    loss:1.0408909320831299
#    loaders:4回目    loss:2.5708796977996826
#    loaders:5回目    loss:3.233323812484741
#    loaders:6回目    loss:2.5866870880126953
#    loaders:7回目    loss:1.325137734413147
# EPOCH21回目 val Loss: 1.6390 Acc: 0.4540
# train:フェイズ
#    loaders:1回目    loss:0.2710024416446686
#    loaders:2回目    loss:0.31574711203575134
#    loaders:3回目    loss:0.46238839626312256
#    loaders:4回目    loss:0.2523086667060852
#    loaders:5回目    loss:0.3032029867172241
#    loaders:6回目    loss:0.3059541583061218
#    loaders:7回目    loss:0.31840917468070984
#    loaders:8回目    loss:0.3258427083492279
#    loaders:9回目    loss:0.22125406563282013
#    loaders:10回目    loss:0.3145676255226135
#    loaders:11回目    loss:0.4800339937210083
#    loaders:12回目    loss:0.29436859488487244
#    loaders:13回目    loss:0.33349472284317017
#    loaders:14回目    loss:0.235968679189682
#    loaders:15回目    loss:0.39294350147247314
#    loaders:16回目    loss:0.34278517961502075
#    loaders:17回目    loss:0.37627241015434265
#    loaders:18回目    loss:0.3238985240459442
#    loaders:19回目    loss:0.3607814610004425
#    loaders:20回目    loss:0.3153138756752014
#    loaders:21回目    loss:0.2596225440502167
#    loaders:22回目    loss:0.20568551123142242
#    loaders:23回目    loss:0.2660026252269745
#    loaders:24回目    loss:0.2860327363014221
#    loaders:25回目    loss:0.4616395831108093
#    loaders:26回目    loss:0.2981311082839966
#    loaders:27回目    loss:0.2775130569934845
#    loaders:28回目    loss:0.39255157113075256
#    loaders:29回目    loss:0.3375500738620758
#    loaders:30回目    loss:0.35732677578926086
#    loaders:31回目    loss:0.2878689467906952
# EPOCH22回目 train Loss: 0.3192 Acc: 0.8905
# val:フェイズ
#    loaders:1回目    loss:2.9674336910247803
#    loaders:2回目    loss:2.0946526527404785
#    loaders:3回目    loss:1.219416618347168
#    loaders:4回目    loss:3.2304391860961914
#    loaders:5回目    loss:3.6212668418884277
#    loaders:6回目    loss:2.4214563369750977
#    loaders:7回目    loss:1.028432011604309
# EPOCH22回目 val Loss: 2.1226 Acc: 0.4050
# train:フェイズ
#    loaders:1回目    loss:0.22213374078273773
#    loaders:2回目    loss:0.2388230562210083
#    loaders:3回目    loss:0.3047562837600708
#    loaders:4回目    loss:0.22932066023349762
#    loaders:5回目    loss:0.27449971437454224
#    loaders:6回目    loss:0.2178952544927597
#    loaders:7回目    loss:0.18508543074131012
#    loaders:8回目    loss:0.24925704300403595
#    loaders:9回目    loss:0.18166270852088928
#    loaders:10回目    loss:0.25660067796707153
#    loaders:11回目    loss:0.2303515374660492
#    loaders:12回目    loss:0.25735560059547424
#    loaders:13回目    loss:0.32865050435066223
#    loaders:14回目    loss:0.22045938670635223
#    loaders:15回目    loss:0.21507076919078827
#    loaders:16回目    loss:0.20890887081623077
#    loaders:17回目    loss:0.2575051188468933
#    loaders:18回目    loss:0.26197609305381775
#    loaders:19回目    loss:0.23528146743774414
#    loaders:20回目    loss:0.37073448300361633
#    loaders:21回目    loss:0.1756439357995987
#    loaders:22回目    loss:0.2271653413772583
#    loaders:23回目    loss:0.2101156860589981
#    loaders:24回目    loss:0.27171823382377625
#    loaders:25回目    loss:0.24674560129642487
#    loaders:26回目    loss:0.17226098477840424
#    loaders:27回目    loss:0.22666214406490326
#    loaders:28回目    loss:0.31946489214897156
#    loaders:29回目    loss:0.30458930134773254
#    loaders:30回目    loss:0.21214671432971954
#    loaders:31回目    loss:0.2505471706390381
# EPOCH23回目 train Loss: 0.2420 Acc: 0.9210
# val:フェイズ
#    loaders:1回目    loss:1.8669185638427734
#    loaders:2回目    loss:1.6390503644943237
#    loaders:3回目    loss:3.026548147201538
#    loaders:4回目    loss:4.019395351409912
#    loaders:5回目    loss:1.7555607557296753
#    loaders:6回目    loss:0.85624760389328
#    loaders:7回目    loss:2.421233892440796
# EPOCH23回目 val Loss: 1.9949 Acc: 0.4300
# train:フェイズ
#    loaders:1回目    loss:0.16475041210651398
#    loaders:2回目    loss:0.2831144332885742
#    loaders:3回目    loss:0.14101818203926086
#    loaders:4回目    loss:0.2264145463705063
#    loaders:5回目    loss:0.2520157992839813
#    loaders:6回目    loss:0.27088454365730286
#    loaders:7回目    loss:0.16736625134944916
#    loaders:8回目    loss:0.18863143026828766
#    loaders:9回目    loss:0.12068354338407516
#    loaders:10回目    loss:0.20041505992412567
#    loaders:11回目    loss:0.20115096867084503
#    loaders:12回目    loss:0.19735151529312134
#    loaders:13回目    loss:0.21393892168998718
#    loaders:14回目    loss:0.14154498279094696
#    loaders:15回目    loss:0.1755145937204361
#    loaders:16回目    loss:0.13609109818935394
#    loaders:17回目    loss:0.18305887281894684
#    loaders:18回目    loss:0.19203463196754456
#    loaders:19回目    loss:0.2460911124944687
#    loaders:20回目    loss:0.188555508852005
#    loaders:21回目    loss:0.16115429997444153
#    loaders:22回目    loss:0.1513098031282425
#    loaders:23回目    loss:0.21442896127700806
#    loaders:24回目    loss:0.22326233983039856
#    loaders:25回目    loss:0.16299094259738922
#    loaders:26回目    loss:0.16099269688129425
#    loaders:27回目    loss:0.21043983101844788
#    loaders:28回目    loss:0.23560385406017303
#    loaders:29回目    loss:0.2043950855731964
#    loaders:30回目    loss:0.18252147734165192
#    loaders:31回目    loss:0.25883370637893677
# EPOCH24回目 train Loss: 0.1938 Acc: 0.9373
# val:フェイズ
#    loaders:1回目    loss:1.7804418802261353
#    loaders:2回目    loss:0.931243896484375
#    loaders:3回目    loss:2.4664645195007324
#    loaders:4回目    loss:3.322359085083008
#    loaders:5回目    loss:2.5875110626220703
#    loaders:6回目    loss:1.620880126953125
#    loaders:7回目    loss:2.78607439994812
# EPOCH24回目 val Loss: 1.9834 Acc: 0.4110
# train:フェイズ
#    loaders:1回目    loss:0.14214079082012177
#    loaders:2回目    loss:0.15611208975315094
#    loaders:3回目    loss:0.135403111577034
#    loaders:4回目    loss:0.17481295764446259
#    loaders:5回目    loss:0.14499157667160034
#    loaders:6回目    loss:0.14252601563930511
#    loaders:7回目    loss:0.15535865724086761
#    loaders:8回目    loss:0.19297648966312408
#    loaders:9回目    loss:0.1262666881084442
#    loaders:10回目    loss:0.15646407008171082
#    loaders:11回目    loss:0.1483353227376938
#    loaders:12回目    loss:0.11802632361650467
#    loaders:13回目    loss:0.13514089584350586
#    loaders:14回目    loss:0.20967493951320648
#    loaders:15回目    loss:0.1554066389799118
#    loaders:16回目    loss:0.13787847757339478
#    loaders:17回目    loss:0.1484355330467224
#    loaders:18回目    loss:0.1372445821762085
#    loaders:19回目    loss:0.14356113970279694
#    loaders:20回目    loss:0.12213384360074997
#    loaders:21回目    loss:0.12677700817584991
#    loaders:22回目    loss:0.1684873104095459
#    loaders:23回目    loss:0.13762250542640686
#    loaders:24回目    loss:0.1341693252325058
#    loaders:25回目    loss:0.15413729846477509
#    loaders:26回目    loss:0.15848518908023834
#    loaders:27回目    loss:0.093934066593647
#    loaders:28回目    loss:0.10754066705703735
#    loaders:29回目    loss:0.1846071183681488
#    loaders:30回目    loss:0.16188080608844757
#    loaders:31回目    loss:0.09955336898565292
# EPOCH25回目 train Loss: 0.1443 Acc: 0.9550
# val:フェイズ
#    loaders:1回目    loss:2.4010961055755615
#    loaders:2回目    loss:1.8483085632324219
#    loaders:3回目    loss:1.5587774515151978
#    loaders:4回目    loss:1.7357659339904785
#    loaders:5回目    loss:1.721771001815796
#    loaders:6回目    loss:2.5876128673553467
#    loaders:7回目    loss:1.564237117767334
# EPOCH25回目 val Loss: 1.7174 Acc: 0.4480
# train:フェイズ
#    loaders:1回目    loss:0.2183908075094223
#    loaders:2回目    loss:0.09154431521892548
#    loaders:3回目    loss:0.15226642787456512
#    loaders:4回目    loss:0.12387988716363907
#    loaders:5回目    loss:0.14154385030269623
#    loaders:6回目    loss:0.09625306725502014
#    loaders:7回目    loss:0.08809351921081543
#    loaders:8回目    loss:0.11523663252592087
#    loaders:9回目    loss:0.11515400558710098
#    loaders:10回目    loss:0.1246921643614769
#    loaders:11回目    loss:0.08107778429985046
#    loaders:12回目    loss:0.08141513913869858
#    loaders:13回目    loss:0.06208232417702675
#    loaders:14回目    loss:0.08885025233030319
#    loaders:15回目    loss:0.11607963591814041
#    loaders:16回目    loss:0.08686397224664688
#    loaders:17回目    loss:0.1006203442811966
#    loaders:18回目    loss:0.1567523181438446
#    loaders:19回目    loss:0.07918615639209747
#    loaders:20回目    loss:0.09618669003248215
#    loaders:21回目    loss:0.0860288143157959
#    loaders:22回目    loss:0.06711450964212418
#    loaders:23回目    loss:0.07378233969211578
#    loaders:24回目    loss:0.141170471906662
#    loaders:25回目    loss:0.11732254177331924
#    loaders:26回目    loss:0.17616894841194153
#    loaders:27回目    loss:0.08774300664663315
#    loaders:28回目    loss:0.15653899312019348
#    loaders:29回目    loss:0.08985079824924469
#    loaders:30回目    loss:0.09270601719617844
#    loaders:31回目    loss:0.13794641196727753
# EPOCH26回目 train Loss: 0.1102 Acc: 0.9673
# val:フェイズ
#    loaders:1回目    loss:1.0916917324066162
#    loaders:2回目    loss:0.8486408591270447
#    loaders:3回目    loss:2.302960157394409
#    loaders:4回目    loss:1.9255266189575195
#    loaders:5回目    loss:1.3693312406539917
#    loaders:6回目    loss:2.3200762271881104
#    loaders:7回目    loss:1.3693138360977173
# EPOCH26回目 val Loss: 1.4371 Acc: 0.4970
# Save File original_model_26.pth
# train:フェイズ
#    loaders:1回目    loss:0.0656730979681015
#    loaders:2回目    loss:0.08013580739498138
#    loaders:3回目    loss:0.06969580799341202
#    loaders:4回目    loss:0.124580517411232
#    loaders:5回目    loss:0.07988209277391434
#    loaders:6回目    loss:0.0978710874915123
#    loaders:7回目    loss:0.07513943314552307
#    loaders:8回目    loss:0.1377381682395935
#    loaders:9回目    loss:0.0970430076122284
#    loaders:10回目    loss:0.12406796216964722
#    loaders:11回目    loss:0.0879364162683487
#    loaders:12回目    loss:0.08929657191038132
#    loaders:13回目    loss:0.1233452633023262
#    loaders:14回目    loss:0.0932498574256897
#    loaders:15回目    loss:0.07151411473751068
#    loaders:16回目    loss:0.10492467880249023
#    loaders:17回目    loss:0.1053633913397789
#    loaders:18回目    loss:0.11787837743759155
#    loaders:19回目    loss:0.06951728463172913
#    loaders:20回目    loss:0.05515377223491669
#    loaders:21回目    loss:0.1400899589061737
#    loaders:22回目    loss:0.053706493228673935
#    loaders:23回目    loss:0.05790227651596069
#    loaders:24回目    loss:0.060083188116550446
#    loaders:25回目    loss:0.12163740396499634
#    loaders:26回目    loss:0.08098837733268738
#    loaders:27回目    loss:0.08649270236492157
#    loaders:28回目    loss:0.08889304101467133
#    loaders:29回目    loss:0.1483878642320633
#    loaders:30回目    loss:0.1137843206524849
#    loaders:31回目    loss:0.14005118608474731
# ...
#    loaders:16回目    loss:0.027328217402100563
#    loaders:17回目    loss:0.011876853182911873
#    loaders:18回目    loss:0.016103219240903854
#    loaders:19回目    loss:0.015448623336851597
#    loaders:20回目    loss:0.015210485085844994
#    loaders:21回目    loss:0.01972358487546444
#    loaders:22回目    loss:0.017965132370591164
#    loaders:23回目    loss:0.01776043139398098
#    loaders:24回目    loss:0.01770099252462387
#    loaders:25回目    loss:0.030556155368685722
#    loaders:26回目    loss:0.018748601898550987
#    loaders:27回目    loss:0.0182441845536232
#    loaders:28回目    loss:0.014026491902768612
#    loaders:29回目    loss:0.015780119225382805
#    loaders:30回目    loss:0.02035597898066044
#    loaders:31回目    loss:0.009164690040051937
# EPOCH31回目 train Loss: 0.0188 Acc: 0.9915
# val:フェイズ
#    loaders:1回目    loss:0.9343259334564209
#    loaders:2回目    loss:1.240596055984497
#    loaders:3回目    loss:2.4815330505371094
#    loaders:4回目    loss:2.207650899887085
#    loaders:5回目    loss:1.7120801210403442
#    loaders:6回目    loss:1.2346069812774658
#    loaders:7回目    loss:1.6312201023101807
# EPOCH31回目 val Loss: 1.4646 Acc: 0.5270
# Save File original_model_31.pth
# train:フェイズ
#    loaders:1回目    loss:0.01646898314356804
#    loaders:2回目    loss:0.009126557037234306
#    loaders:3回目    loss:0.009729432873427868
#    loaders:4回目    loss:0.011546739377081394
#    loaders:5回目    loss:0.01221497356891632
#    loaders:6回目    loss:0.01943075843155384
#    loaders:7回目    loss:0.009316651150584221
#    loaders:8回目    loss:0.00795387290418148
#    loaders:9回目    loss:0.013867657631635666
#    loaders:10回目    loss:0.02002739906311035
#    loaders:11回目    loss:0.010757445357739925
#    loaders:12回目    loss:0.015454762615263462
#    loaders:13回目    loss:0.011196532286703587
#    loaders:14回目    loss:0.015652835369110107
#    loaders:15回目    loss:0.009497707709670067
#    loaders:16回目    loss:0.00843735970556736
#    loaders:17回目    loss:0.021924573928117752
#    loaders:18回目    loss:0.011614394374191761
#    loaders:19回目    loss:0.02182607538998127
#    loaders:20回目    loss:0.010716949589550495
#    loaders:21回目    loss:0.014713328331708908
#    loaders:22回目    loss:0.017257172614336014
#    loaders:23回目    loss:0.013157309964299202
#    loaders:24回目    loss:0.009810772724449635
#    loaders:25回目    loss:0.022782903164625168
#    loaders:26回目    loss:0.021442780271172523
#    loaders:27回目    loss:0.008594853803515434
#    loaders:28回目    loss:0.011876038275659084
#    loaders:29回目    loss:0.011701798997819424
#    loaders:30回目    loss:0.014758521690964699
#    loaders:31回目    loss:0.015410283580422401
# EPOCH32回目 train Loss: 0.0137 Acc: 0.9915
# val:フェイズ
#    loaders:1回目    loss:0.8365573287010193
#    loaders:2回目    loss:0.9911478161811829
#    loaders:3回目    loss:1.8311189413070679
#    loaders:4回目    loss:1.8998539447784424
#    loaders:5回目    loss:1.8257046937942505
#    loaders:6回目    loss:1.709226369857788
#    loaders:7回目    loss:1.2663038969039917
# EPOCH32回目 val Loss: 1.3261 Acc: 0.5400
# Save File original_model_32.pth
# train:フェイズ
#    loaders:1回目    loss:0.010375013574957848
#    loaders:2回目    loss:0.009444109164178371
#    loaders:3回目    loss:0.011460763402283192
#    loaders:4回目    loss:0.0139217060059309
#    loaders:5回目    loss:0.008233215659856796
#    loaders:6回目    loss:0.01776598021388054
#    loaders:7回目    loss:0.012374872341752052
#    loaders:8回目    loss:0.014739273115992546
#    loaders:9回目    loss:0.005777673330157995
#    loaders:10回目    loss:0.013981204479932785
#    loaders:11回目    loss:0.009095066227018833
#    loaders:12回目    loss:0.009888098575174809
#    loaders:13回目    loss:0.0077015249989926815
#    loaders:14回目    loss:0.012790722772479057
#    loaders:15回目    loss:0.008307894691824913
#    loaders:16回目    loss:0.01154966652393341
#    loaders:17回目    loss:0.01062432024627924
#    loaders:18回目    loss:0.00981039647012949
#    loaders:19回目    loss:0.008598120883107185
#    loaders:20回目    loss:0.006592690013349056
#    loaders:21回目    loss:0.00998533796519041
#    loaders:22回目    loss:0.013065489940345287
#    loaders:23回目    loss:0.012248550541698933
#    loaders:24回目    loss:0.01295821089297533
#    loaders:25回目    loss:0.011479818262159824
#    loaders:26回目    loss:0.0100104920566082
#    loaders:27回目    loss:0.009013314731419086
#    loaders:28回目    loss:0.009232347831130028
#    loaders:29回目    loss:0.008849176578223705
#    loaders:30回目    loss:0.006252487655729055
#    loaders:31回目    loss:0.006327574606984854
# EPOCH33回目 train Loss: 0.0103 Acc: 0.9920
# val:フェイズ
#    loaders:1回目    loss:0.9760949611663818
#    loaders:2回目    loss:1.1519298553466797
#    loaders:3回目    loss:1.9843974113464355
#    loaders:4回目    loss:1.8712047338485718
#    loaders:5回目    loss:1.889387845993042
#    loaders:6回目    loss:1.640149474143982
#    loaders:7回目    loss:1.3621553182601929
# EPOCH33回目 val Loss: 1.3920 Acc: 0.5330
# train:フェイズ
#    loaders:1回目    loss:0.00696897879242897
#    loaders:2回目    loss:0.006825545337051153
#    loaders:3回目    loss:0.007200388703495264
#    loaders:4回目    loss:0.007862294092774391
#    loaders:5回目    loss:0.009498045779764652
#    loaders:6回目    loss:0.009145556949079037
#    loaders:7回目    loss:0.010605225339531898
#    loaders:8回目    loss:0.012789411470293999
#    loaders:9回目    loss:0.006173846311867237
#    loaders:10回目    loss:0.0074991160072386265
#    loaders:11回目    loss:0.007329866290092468
#    loaders:12回目    loss:0.008597836829721928
#    loaders:13回目    loss:0.017658693715929985
#    loaders:14回目    loss:0.005770966876298189
#    loaders:15回目    loss:0.009228979237377644
#    loaders:16回目    loss:0.005496272351592779
#    loaders:17回目    loss:0.007482602261006832
#    loaders:18回目    loss:0.006216974928975105
#    loaders:19回目    loss:0.0058895293623209
#    loaders:20回目    loss:0.0073358952067792416
#    loaders:21回目    loss:0.013351322151720524
#    loaders:22回目    loss:0.011955494992434978
#    loaders:23回目    loss:0.008620114997029305
#    loaders:24回目    loss:0.0118119390681386
#    loaders:25回目    loss:0.0061632199212908745
#    loaders:26回目    loss:0.005691261030733585
#    loaders:27回目    loss:0.0062143560498952866
#    loaders:28回目    loss:0.006536650471389294
#    loaders:29回目    loss:0.006095033138990402
#    loaders:30回目    loss:0.00473890732973814
#    loaders:31回目    loss:0.007070742081850767
# EPOCH34回目 train Loss: 0.0081 Acc: 0.9920
# val:フェイズ
#    loaders:1回目    loss:1.0503287315368652
#    loaders:2回目    loss:0.976793110370636
#    loaders:3回目    loss:2.188199996948242
#    loaders:4回目    loss:1.9949612617492676
#    loaders:5回目    loss:1.7800016403198242
#    loaders:6回目    loss:1.4500676393508911
#    loaders:7回目    loss:1.1728405952453613
# EPOCH34回目 val Loss: 1.3585 Acc: 0.5310
# train:フェイズ
#    loaders:1回目    loss:0.0050923083908855915
#    loaders:2回目    loss:0.00623489310964942
#    loaders:3回目    loss:0.007002933416515589
#    loaders:4回目    loss:0.004514864645898342
#    loaders:5回目    loss:0.010098731145262718
#    loaders:6回目    loss:0.0045665716752409935
#    loaders:7回目    loss:0.006968176923692226
#    loaders:8回目    loss:0.006066757719963789
#    loaders:9回目    loss:0.007300938479602337
#    loaders:10回目    loss:0.0044469102285802364
#    loaders:11回目    loss:0.005600566044449806
#    loaders:12回目    loss:0.0046290126629173756
#    loaders:13回目    loss:0.005571877118200064
#    loaders:14回目    loss:0.007012753281742334
#    loaders:15回目    loss:0.0077941641211509705
#    loaders:16回目    loss:0.006146128289401531
#    loaders:17回目    loss:0.005054728128015995
#    loaders:18回目    loss:0.00610021548345685
#    loaders:19回目    loss:0.005474903155118227
#    loaders:20回目    loss:0.0038884144742041826
#    loaders:21回目    loss:0.008185414597392082
#    loaders:22回目    loss:0.00884904433041811
#    loaders:23回目    loss:0.005021389108151197
#    loaders:24回目    loss:0.004285325761884451
#    loaders:25回目    loss:0.005890315398573875
#    loaders:26回目    loss:0.004574720282107592
#    loaders:27回目    loss:0.007550354581326246
#    loaders:28回目    loss:0.029383040964603424
#    loaders:29回目    loss:0.00521836057305336
#    loaders:30回目    loss:0.005219197832047939
#    loaders:31回目    loss:0.007559396326541901
# EPOCH35回目 train Loss: 0.0068 Acc: 0.9918
# val:フェイズ
#    loaders:1回目    loss:0.9507876634597778
#    loaders:2回目    loss:1.1337465047836304
#    loaders:3回目    loss:2.0182130336761475
#    loaders:4回目    loss:1.9636309146881104
#    loaders:5回目    loss:1.8849786520004272
#    loaders:6回目    loss:1.4382256269454956
#    loaders:7回目    loss:1.343422770500183
# EPOCH35回目 val Loss: 1.3738 Acc: 0.5380
# train:フェイズ
#    loaders:1回目    loss:0.0045086536556482315
#    loaders:2回目    loss:0.004426930099725723
#    loaders:3回目    loss:0.009186798706650734
#    loaders:4回目    loss:0.006022071465849876
#    loaders:5回目    loss:0.009775086306035519
#    loaders:6回目    loss:0.005137525498867035
#    loaders:7回目    loss:0.005510035436600447
#    loaders:8回目    loss:0.004527680110186338
#    loaders:9回目    loss:0.005378606729209423
#    loaders:10回目    loss:0.004440611228346825
#    loaders:11回目    loss:0.004898931831121445
#    loaders:12回目    loss:0.004900800995528698
#    loaders:13回目    loss:0.006234556902199984
#    loaders:14回目    loss:0.00864869449287653
#    loaders:15回目    loss:0.005297658499330282
#    loaders:16回目    loss:0.0074237859807908535
#    loaders:17回目    loss:0.008904694579541683
#    loaders:18回目    loss:0.004939944949001074
#    loaders:19回目    loss:0.005598736926913261
#    loaders:20回目    loss:0.0049027749337255955
#    loaders:21回目    loss:0.0050325109623372555
#    loaders:22回目    loss:0.00558161037042737
#    loaders:23回目    loss:0.006400966551154852
#    loaders:24回目    loss:0.006136699113994837
#    loaders:25回目    loss:0.0047158547677099705
#    loaders:26回目    loss:0.006003016140311956
#    loaders:27回目    loss:0.003991089761257172
#    loaders:28回目    loss:0.006864004302769899
#    loaders:29回目    loss:0.008011522702872753
#    loaders:30回目    loss:0.007254765368998051
#    loaders:31回目    loss:0.003697603475302458
# EPOCH36回目 train Loss: 0.0059 Acc: 0.9920
# val:フェイズ
#    loaders:1回目    loss:1.0353692770004272
#    loaders:2回目    loss:1.2059543132781982
#    loaders:3回目    loss:2.1794493198394775
#    loaders:4回目    loss:1.9666742086410522
#    loaders:5回目    loss:1.7794363498687744
#    loaders:6回目    loss:1.6158920526504517
#    loaders:7回目    loss:1.2646613121032715
# EPOCH36回目 val Loss: 1.4141 Acc: 0.5310
# train:フェイズ
#    loaders:1回目    loss:0.0036082081496715546
#    loaders:2回目    loss:0.007964735850691795
#    loaders:3回目    loss:0.007559418212622404
#    loaders:4回目    loss:0.003964499570429325
#    loaders:5回目    loss:0.004871311131864786
#    loaders:6回目    loss:0.005023648962378502
#    loaders:7回目    loss:0.005173232406377792
#    loaders:8回目    loss:0.0064000338315963745
#    loaders:9回目    loss:0.00497619342058897
#    loaders:10回目    loss:0.0048394822515547276
#    loaders:11回目    loss:0.006848463788628578
#    loaders:12回目    loss:0.005207591224461794
#    loaders:13回目    loss:0.006744356360286474
#    loaders:14回目    loss:0.005787201225757599
#    loaders:15回目    loss:0.0038060517981648445
#    loaders:16回目    loss:0.004975298419594765
#    loaders:17回目    loss:0.003567266510799527
#    loaders:18回目    loss:0.0059104799292981625
#    loaders:19回目    loss:0.0050365314818918705
#    loaders:20回目    loss:0.004886390175670385
#    loaders:21回目    loss:0.005083794239908457
#    loaders:22回目    loss:0.003493541618809104
#    loaders:23回目    loss:0.006555451545864344
#    loaders:24回目    loss:0.005417428910732269
#    loaders:25回目    loss:0.006958647631108761
#    loaders:26回目    loss:0.004386513028293848
#    loaders:27回目    loss:0.0056753759272396564
#    loaders:28回目    loss:0.006103499326854944
#    loaders:29回目    loss:0.00474594859406352
#    loaders:30回目    loss:0.004668242298066616
#    loaders:31回目    loss:0.005010696593672037
# EPOCH37回目 train Loss: 0.0053 Acc: 0.9920
# val:フェイズ
#    loaders:1回目    loss:0.8854610323905945
#    loaders:2回目    loss:1.0457267761230469
#    loaders:3回目    loss:2.123335599899292
#    loaders:4回目    loss:1.8870126008987427
#    loaders:5回目    loss:1.7761096954345703
#    loaders:6回目    loss:1.6319568157196045
#    loaders:7回目    loss:1.3920952081680298
# EPOCH37回目 val Loss: 1.3749 Acc: 0.5330
# train:フェイズ
#    loaders:1回目    loss:0.0034532546997070312
#    loaders:2回目    loss:0.0036933948285877705
#    loaders:3回目    loss:0.010692392475903034
#    loaders:4回目    loss:0.004276655614376068
#    loaders:5回目    loss:0.0071841017343103886
#    loaders:6回目    loss:0.004180070012807846
#    loaders:7回目    loss:0.00965429563075304
#    loaders:8回目    loss:0.004340461455285549
#    loaders:9回目    loss:0.0028950946871191263
#    loaders:10回目    loss:0.004206253215670586
#    loaders:11回目    loss:0.007882354781031609
#    loaders:12回目    loss:0.006939983926713467
#    loaders:13回目    loss:0.004287180490791798
#    loaders:14回目    loss:0.003622234333306551
#    loaders:15回目    loss:0.0034939676988869905
#    loaders:16回目    loss:0.0030005639418959618
#    loaders:17回目    loss:0.004540698137134314
#    loaders:18回目    loss:0.004629466682672501
#    loaders:19回目    loss:0.007773527409881353
#    loaders:20回目    loss:0.004680262878537178
#    loaders:21回目    loss:0.004016641061753035
#    loaders:22回目    loss:0.0059159607626497746
#    loaders:23回目    loss:0.0027481119614094496
#    loaders:24回目    loss:0.01154148206114769
#    loaders:25回目    loss:0.0028379899449646473
#    loaders:26回目    loss:0.004816500004380941
#    loaders:27回目    loss:0.004473286680877209
#    loaders:28回目    loss:0.0037917708978056908
#    loaders:29回目    loss:0.00652819499373436
#    loaders:30回目    loss:0.0037216930650174618
#    loaders:31回目    loss:0.00458481814712286
# EPOCH38回目 train Loss: 0.0051 Acc: 0.9920
# val:フェイズ
#    loaders:1回目    loss:0.8987963199615479
#    loaders:2回目    loss:1.0051748752593994
#    loaders:3回目    loss:2.094346284866333
#    loaders:4回目    loss:2.003358840942383
#    loaders:5回目    loss:1.7729663848876953
#    loaders:6回目    loss:1.6281077861785889
#    loaders:7回目    loss:1.3216829299926758
# EPOCH38回目 val Loss: 1.3727 Acc: 0.5340
# train:フェイズ
#    loaders:1回目    loss:0.002757544629275799
#    loaders:2回目    loss:0.0067100804299116135
#    loaders:3回目    loss:0.003106089308857918
#    loaders:4回目    loss:0.01271620113402605
#    loaders:5回目    loss:0.003866660874336958
#    loaders:6回目    loss:0.0033855449873954058
#    loaders:7回目    loss:0.0047836825251579285
#    loaders:8回目    loss:0.00419777212664485
#    loaders:9回目    loss:0.007507757283747196
#    loaders:10回目    loss:0.004146339371800423
#    loaders:11回目    loss:0.004165478982031345
#    loaders:12回目    loss:0.004579393658787012
#    loaders:13回目    loss:0.003446711925789714
#    loaders:14回目    loss:0.0030300815124064684
#    loaders:15回目    loss:0.00497900415211916
#    loaders:16回目    loss:0.0047407858073711395
#    loaders:17回目    loss:0.003379975911229849
#    loaders:18回目    loss:0.009754269383847713
#    loaders:19回目    loss:0.00595591776072979
#    loaders:20回目    loss:0.005559369921684265
#    loaders:21回目    loss:0.0043814899399876595
#    loaders:22回目    loss:0.005452062468975782
#    loaders:23回目    loss:0.0038141265977174044
#    loaders:24回目    loss:0.005920328199863434
#    loaders:25回目    loss:0.0034221564419567585
#    loaders:26回目    loss:0.0030830546747893095
#    loaders:27回目    loss:0.00527797220274806
#    loaders:28回目    loss:0.0037075297441333532
#    loaders:29回目    loss:0.006124496925622225
#    loaders:30回目    loss:0.004311276134103537
#    loaders:31回目    loss:0.004158237017691135
# EPOCH39回目 train Loss: 0.0049 Acc: 0.9920
# val:フェイズ
#    loaders:1回目    loss:1.0672448873519897
#    loaders:2回目    loss:1.148083209991455
#    loaders:3回目    loss:2.3137054443359375
#    loaders:4回目    loss:2.1664979457855225
#    loaders:5回目    loss:1.792081594467163
#    loaders:6回目    loss:1.4109125137329102
#    loaders:7回目    loss:1.397972822189331
# EPOCH39回目 val Loss: 1.4460 Acc: 0.5220
# Best val Acc: 0.540000
# [0.215   0.32675 0.3655  0.4185  0.4635  0.50775 0.5315  0.5575  0.5795
#  0.60925 0.63775 0.66725 0.69425 0.71425 0.7345  0.76275 0.79325 0.811
#  0.8385  0.85975 0.89075 0.8985  0.8905  0.921   0.93725 0.955   0.96725
#  0.97    0.977   0.982   0.98625 0.9915  0.9915  0.992   0.992   0.99175
#  0.992   0.992   0.992   0.992  ]
# [0.144 0.271 0.273 0.271 0.354 0.372 0.366 0.371 0.417 0.423 0.299 0.39
#  0.468 0.456 0.39  0.439 0.433 0.446 0.491 0.478 0.458 0.454 0.405 0.43
#  0.411 0.448 0.497 0.49  0.499 0.497 0.489 0.527 0.54  0.533 0.531 0.538
#  0.531 0.533 0.534 0.522]

# %%
#学習したモデルを使ってtestデータの推論を実施
import pandas as pd
import os
import zipfile
import torch
import torch.nn as nn
import torch.optim as optim
import albumentations
from torch.utils.data import Dataset
from torchvision import datasets, models, transforms
from PIL import Image, ImageFilter

work_dir           = '/content/sample_data'
save_dir           = '/content/drive/MyDrive/2024_AIContest2/Thema1/'
test_zip_file_path = '/content/sample_data/test_images.zip'
test_file_dir      = os.path.join(work_dir, 'test_images')
report_format_tsv  = os.path.join(work_dir, 'sample_submit.tsv')
best_model_path    = os.path.join(save_dir, 'pth/20250317_original_model_14.pth')
output_file        = os.path.join(save_dir, 'output/20250317_out_submit_14.tsv')

TARGET_NUM = 10

# ZIPファイルを解凍する
def extract_zip(zip_file_path, extract_to):

    if not os.path.exists(test_file_dir):
        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            zip_ref.extractall(extract_to)

extract_zip(test_zip_file_path, work_dir)

#dataサイズ定義
dataset_sizes= {
    'train':len(image_datasets['train']),
    'val':len(image_datasets['val'])
}

#submit用dataset定義
class For_Submission_Datasets(Dataset):

    def __init__(self, data_transform):
        self.df = pd.read_csv(report_format_tsv ,sep='\t',names=['filename','target'])
        self.data_transform = data_transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):
        file = self.df['filename'][index]
        image = Image.open(test_file_dir +'/'+ file)
        image = self.data_transform(image)

        return image,file

#submit用dataset作成
subdataset = For_Submission_Datasets(data_transform=data_transforms['val'])

#submit用dataloaders作成
subdataloader = torch.utils.data.DataLoader(subdataset, batch_size=1, shuffle=False, num_workers=0, drop_last=True)

#精度の最も高いモデルをロード
#モデルの名前を適宜変更して、最も精度の高いモデルをロードしましょう
best_model = get_model(target_num = TARGET_NUM)
best_model.load_state_dict(torch.load(best_model_path, map_location=lambda storage, loc: storage), strict=True)

submit = pd.read_csv(report_format_tsv,sep='\t', header=None)
#print(submit)
#テストデータに対しての推論
pred = []
for i,(inputs, labels) in enumerate(subdataloader):
    inputs = inputs.to(DEVICE)
    best_model.eval()
    outputs = best_model(inputs)
    _, preds = torch.max(outputs, 1)
    pred.append(preds.item())

df_test = pd.read_csv(report_format_tsv ,sep='\t',names=['filename','target'])

df_test['pred'] = pred
#print(df_test)
submit[1] = pred

submit.to_csv(output_file ,sep='\t', index=False, header=False)
print(submit)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#                   0  1
# 0        test_0.jpg  6
# 1        test_1.jpg  5
# 2        test_2.jpg  0
# 3        test_3.jpg  8
# 4        test_4.jpg  7
# ...             ... ..
# 7995  test_7995.jpg  2
# 7996  test_7996.jpg  6
# 7997  test_7997.jpg  8
# 7998  test_7998.jpg  8
# 7999  test_7999.jpg  8
#
# [8000 rows x 2 columns]
